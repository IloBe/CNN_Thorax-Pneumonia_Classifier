# %% [markdown]
# # Capstone Project - Machine Learning Nanodegree
#
# ## Convolutional Neural Networks - Thorax-Pneumonia Classifier
#
# ---
#
# ### Introduction
#
# In this notebook, we are developing a deep learning classification algorithm. Specific models learn a mapping between input features and class labels. The coding shall accept any future (posterior-anterior, anterior-posterior orientations) X-ray chest image as input for estimation of having a pneumonia chest image or not. Regarding the underlying dataset, we are solving such binary classification question for .jpeg compressed X-ray chest images mostly from children. This dataset used for analysis comes from [Kaggle](https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia/version/2). Such kind of analysis result improves the medical diagnostic workflow. As a future improvement, the algorithm could be used for all human age categories and X-ray orientations including lateral chest images, but such images are not available by now.
#
# ![Image Samples](images/lung_images_pair_small.PNG)
#
#
# For official companies the medical software development happened as part of a regulatory domain. So, let us assume, we would like to use the algorithm as a component of an official product. Then notified bodies would proof the algorithm and its concept regarding quality and regulatory aspects. From technical point of view, working with medical images the CNN concept is the state-of-the-art approach. On the other hand, for getting an official permission and its discussion, the comparison and benchmark of several network architectures and parameter changes together with explanations would help. So, let us do this now, but have in mind that because of technical constraints this solution is not the best one. With better hardware conditions, several neural network optimisations are possible. E.g. it is expected to have a test accuracy much higher 90%.
#
#
# For implementation on Windows OS, we use Python 3.6 with Keras and TensorFlow as backend. For plotting the network architecture the pydot library and Graphviz2.38 shall be installed and properly configured (see [readme](https://github.com/IloBe/CNN_Thorax-Pneumonia_Classifier/blob/master/README.md)).
#
# ---
#
# ### Navigation Content
#
# * [Step 0](#step0): Import Libraries and Reproducibility
# * [Step 1](#step1): Import Chest Dataset
# * [Step 2](#step2): Data Exploration
# * [Step 3](#step3): Data Pre-Processing
# * [Step 4](#step4): Create a CNN Model from the Scratch (Basic Model)
# * [Step 5](#step5): Last Basic Model with Augmentation
# * [Step 6](#step6): Such Basic Model with Adam as Optimiser
# * [Step 7](#step7): Last Basic Model with Adam and Augmentation
# * [Step 8](#step8): Create an improved CNN Model with Adam
# * [Step 9](#step9): Last improved CNN Model with Augmentation
# * [Step 10](#step10): Create a ResNet CNN Model with Transfer Learning
# * [Step 11](#step11): Fine-tuned Transfer Learning ResNet CNN Model with Augmentation
# * [Step 12](#step12): Create an InceptionV3 CNN Model with Transfer Learning
# * [Step 13](#step13): Evaluation
# * [Step 14](#step14): Benchmark and Conclusion
#
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Libraries and Reproducibility
#
# ### Import Libraries
# Import libraries needed to implement the algorithm for this Chest image classifier. Finally, set random seed to make the results reproducible. Note: running this code the first time, a message pops up that TensorFlow backend is used.

# %%
from sklearn.datasets import load_files 
from sklearn import metrics
from glob import glob
from tqdm import tqdm
from PIL import ImageFile

from keras.utils import np_utils, plot_model
from keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from keras import backend as K

from models.Model import Model
from Evaluation_Class import Evaluation_Class

import seaborn as sns
sns.set_style('darkgrid')

import matplotlib.patches as mpatches
import matplotlib.pyplot as plt                        
# %matplotlib inline 

import pandas as pd
import numpy as np
import random as rn
import tensorflow as tf
import pydot

import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Make the Code Reproducible
#
# According Keras documentation this additional coding is necessary to make the results reproducible.

# %%
# The below is necessary for starting Numpy generated random numbers
# in a well-defined initial state.
np.random.seed(42)

# The below is necessary for starting core Python generated random numbers
# in a well-defined state.
rn.seed(1042)

# Force TensorFlow to use single thread.
# Multiple threads are a potential source of non-reproducible results.
# For further details, see: https://stackoverflow.com/questions/42022950/
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1,
                              inter_op_parallelism_threads=1)

# The below tf.set_random_seed() will make random number generation
# in the TensorFlow backend have a well-defined initial state.
# For further details, see:
# https://www.tensorflow.org/api_docs/python/tf/set_random_seed
tf.set_random_seed(1234)

sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Import Chest Dataset
#
# In the code cell below, we import a dataset of chest images. The images distributions of the training, validation and testing sets are stored as .csv files.
#
# We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `chest_names` - list of string-valued chest names (NORMAL, PNEUMONIA) for translating labels

# %%
# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    chest_files = np.array(data['filenames'])
    chest_targets = np_utils.to_categorical(np.array(data['target']), 2)
    return chest_files, chest_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('data/chest_xray/train')
valid_files, valid_targets = load_dataset('data/chest_xray/val')
test_files, test_targets = load_dataset('data/chest_xray/test')

# load list of chest names (NORMAL, PNEUMONIA)
chest_names = [item[20:-1] for item in sorted(glob("data/chest_xray/train/*/"))]

# %%
print(valid_files)
# Out:
# ['data/chest_xray/val/PNEUMONIA/person274_bacteria_1290.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1332_virus_2300.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person350_virus_725.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person485_virus_988.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1234-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person878_bacteria_2801.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person716_bacteria_2617.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person326_bacteria_1505.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1120-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person971_bacteria_2896.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person487_virus_991.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0906-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person389_virus_778.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1227_bacteria_3182.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1262_bacteria_3220.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person816_bacteria_2727.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person369_virus_750.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person392_virus_782.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person84_virus_157.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1102-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person290_virus_594.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person318_bacteria_1474.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person443_virus_908.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person308_bacteria_1443.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person154_virus_305.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person484_virus_986.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1535_bacteria_4017.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1437-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0851-0001-0002.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person467_virus_961.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person281_bacteria_1328.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0875-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0977-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person258_bacteria_1207.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person468_virus_963.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person764_bacteria_2668.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person277_bacteria_1300.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person124_virus_251.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1194-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0846-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1106-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person421_bacteria_1852.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person800_bacteria_2706.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person730_bacteria_2632.jpeg'
#  'data/chest_xray/val/NORMAL/IM-0496-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person417_bacteria_1842.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person277_bacteria_1304.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1716_bacteria_4533.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person956_bacteria_2881.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person967_bacteria_2892.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person937_bacteria_2862.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1949_bacteria_4880.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person977_bacteria_2902.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person534_bacteria_2252.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person640_bacteria_2532.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1502_bacteria_3924.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person488_virus_992.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1214_bacteria_3166.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person281_bacteria_1329.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person354_virus_729.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1269-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1037_bacteria_2971.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person978_bacteria_2904.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person669_virus_1255.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person274_bacteria_1289.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person953_bacteria_2878.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person75_bacteria_364.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1318_virus_2274.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person848_bacteria_2769.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1019-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person319_bacteria_1480.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1258-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person705_virus_1302.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1325_bacteria_3366.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person745_bacteria_2648.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1023-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1333_virus_2301.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1039-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person778_bacteria_2682.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1086-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0815-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1253_bacteria_3211.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person88_virus_164.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1225_bacteria_3180.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person487_bacteria_2058.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0818-0001-0002.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person753_bacteria_2656.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0819-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person727_bacteria_2629.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person799_bacteria_2705.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person391_virus_781.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person162_virus_320.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person813_bacteria_2723.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person922_bacteria_2847.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person712_bacteria_2613.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person331_bacteria_1528.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1709_bacteria_4524.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1162_bacteria_3107.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person303_bacteria_1431.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1028-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person140_virus_284.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person663_virus_1248.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person253_bacteria_1154.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person945_bacteria_2870.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1052-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person280_bacteria_1320.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person299_bacteria_1419.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person902_bacteria_2827.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1022-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person138_virus_282.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person294_bacteria_1383.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person296_bacteria_1392.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1702_bacteria_4509.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1103_virus_1825.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person313_bacteria_1460.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person267_bacteria_1250.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person826_bacteria_2737.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person743_bacteria_2646.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1319_virus_2276.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1315_bacteria_3322.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1008-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person334_bacteria_1545.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1015-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1096-0001-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0922-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0994-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person987_bacteria_2914.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person887_bacteria_2811.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0809-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person281_bacteria_1326.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0811-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person331_virus_684.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1369_virus_2356.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1116_virus_1841.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0911-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1059-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0904-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1347_virus_2323.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0873-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person319_bacteria_1479.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person266_bacteria_1241.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1048-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person355_virus_730.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1946_bacteria_4874.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1145-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person463_virus_953.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person759_bacteria_2663.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1730_bacteria_4559.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person907_bacteria_2832.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person872_bacteria_2795.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person933_bacteria_2858.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person483_virus_985.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person615_virus_1184.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person366_virus_746.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1951_bacteria_4882.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person295_bacteria_1389.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person835_bacteria_2749.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person955_bacteria_2880.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person3_bacteria_13.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1436-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person341_virus_699.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1047-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person422_virus_867.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person776_bacteria_2680.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person814_bacteria_2725.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person794_bacteria_2700.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1189-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person336_bacteria_1549.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1221-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person883_bacteria_2807.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person332_bacteria_1538.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person306_virus_628.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1206-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0892-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1279_bacteria_3242.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1331_bacteria_3380.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1310_bacteria_3295.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person291_bacteria_1374.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person266_bacteria_1240.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person480_virus_981.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person77_bacteria_376.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person419_virus_861.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1055-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person333_bacteria_1540.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person262_bacteria_1226.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person124_virus_244.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1261-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person645_bacteria_2537.jpeg'
#  'data/chest_xray/val/NORMAL/IM-0508-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person735_bacteria_2638.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0887-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1286_bacteria_3249.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person258_bacteria_1210.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person292_virus_599.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0941-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person103_virus_190.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1946_bacteria_4875.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1427-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person368_virus_748.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person334_bacteria_1542.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1411_bacteria_3599.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person257_virus_538.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person104_virus_191.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1368_virus_2353.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person942_bacteria_2867.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1110_virus_1835.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person291_bacteria_1376.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person101_virus_187.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person409_virus_816.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person307_virus_629.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1243_bacteria_3199.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person162_virus_319.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person909_bacteria_2834.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person293_virus_604.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1171_bacteria_3118.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person365_virus_745.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person260_bacteria_1222.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person734_bacteria_2637.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person755_bacteria_2659.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person454_virus_938.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1222_bacteria_3177.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0956-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person930_bacteria_2855.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1340_bacteria_3405.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0967-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0993-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1240-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1170-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1040-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1367_virus_2351.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1723_bacteria_4548.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1405_bacteria_3566.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person903_bacteria_2828.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person300_bacteria_1422.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person957_bacteria_2882.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person768_bacteria_2672.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person402_virus_799.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1438-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person610_bacteria_2475.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person257_bacteria_1199.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0995-0001-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person726_bacteria_2628.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person296_bacteria_1396.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person605_bacteria_2464.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1094-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1244_bacteria_3200.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person934_bacteria_2859.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0975-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person311_bacteria_1453.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0936-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1507_bacteria_3945.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person479_virus_978.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person419_virus_857.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1014-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person740_bacteria_2643.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person855_bacteria_2777.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person257_bacteria_1195.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0925-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person403_virus_803.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person317_bacteria_1471.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1320_bacteria_3340.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person75_bacteria_365.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person422_virus_868.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1247_bacteria_3203.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1954_bacteria_4886.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1430-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person437_bacteria_1884.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person427_virus_875.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person924_bacteria_2849.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person255_bacteria_1182.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person625_bacteria_2499.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person160_virus_316.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person255_bacteria_1161.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1905_bacteria_4801.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person276_bacteria_1298.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person299_bacteria_1414.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1056-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0917-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person256_bacteria_1189.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person259_bacteria_1217.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1186_bacteria_3135.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person100_virus_184.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person135_virus_270.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person862_bacteria_2784.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person703_bacteria_2602.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0983-0001-0002.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person309_virus_631.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person464_virus_954.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1122-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person336_bacteria_1552.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person600_bacteria_2456.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0868-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person325_bacteria_1497.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person739_bacteria_2642.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person974_bacteria_2899.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person264_virus_547.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1336_virus_2306.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1155-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person97_virus_180.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person911_bacteria_2836.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1442-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1305_bacteria_3271.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1313_virus_2264.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0880-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person417_bacteria_1841.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1440-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person88_virus_161.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person124_virus_237.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person279_bacteria_1316.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person299_bacteria_1416.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person465_virus_957.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person720_bacteria_2622.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person291_bacteria_1377.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person630_bacteria_2512.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0895-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person332_bacteria_1536.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person307_bacteria_1441.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person263_bacteria_1227.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person620_bacteria_2492.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0806-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person77_bacteria_375.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1165_bacteria_3111.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person316_bacteria_1470.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person322_bacteria_1494.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1111-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1526_bacteria_3986.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person505_virus_1017.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person931_bacteria_2856.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person310_virus_633.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person331_bacteria_1530.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person803_bacteria_2710.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1508_bacteria_3949.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person841_bacteria_2761.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1136-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person351_virus_726.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person298_bacteria_1411.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0848-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person491_virus_997.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1173-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person306_bacteria_1439.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0976-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person936_bacteria_2861.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1027-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0983-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person307_bacteria_1442.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1011-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1950_bacteria_4881.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person710_bacteria_2611.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person709_bacteria_2608.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person74_bacteria_363.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1123_virus_1848.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person258_bacteria_1212.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1044-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person531_bacteria_2235.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1192_bacteria_3141.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1540_bacteria_4023.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0915-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0989-0001.jpeg'
#  'data/chest_xray/val/NORMAL/IM-0483-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1770_bacteria_4613.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person774_bacteria_2678.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1247-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person482_virus_984.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person342_virus_701.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person952_bacteria_2877.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person149_virus_299.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person296_bacteria_1397.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1228-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person890_bacteria_2814.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1232-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person827_bacteria_2738.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1368_virus_2354.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1064-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person343_virus_704.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1004-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person456_virus_943.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person662_virus_1246.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1947_bacteria_4876.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person315_bacteria_1466.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person264_bacteria_1231.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1300_bacteria_3264.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1259_bacteria_3217.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person433_virus_882.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1505_virus_2615.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person489_virus_995.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1195_bacteria_3144.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person847_bacteria_2767.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person983_bacteria_2910.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person300_bacteria_1421.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person415_virus_847.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1880_bacteria_4765.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1167-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1111_virus_1836.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person802_bacteria_2708.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person889_bacteria_2813.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person725_bacteria_2627.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1198-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1152-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person306_bacteria_1440.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1106_virus_1829.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person492_virus_998.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person327_bacteria_1508.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1025-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person407_virus_812.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person298_bacteria_1410.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person700_bacteria_2599.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person837_bacteria_2754.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0988-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1431-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person730_virus_1351.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person88_virus_167.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person309_bacteria_1447.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person834_bacteria_2748.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0978-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person733_bacteria_2635.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1018-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person809_bacteria_2717.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1176_bacteria_3124.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person326_virus_677.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0926-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person151_virus_302.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person635_bacteria_2526.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1345_bacteria_3422.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1311_virus_2259.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person288_virus_587.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1799_bacteria_4647.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0945-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0951-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1175_bacteria_3122.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1527_virus_2661.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person904_bacteria_2829.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person325_bacteria_1501.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person834_bacteria_2747.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person751_bacteria_2654.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person874_bacteria_2797.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1288_bacteria_3251.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person321_bacteria_1487.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person893_bacteria_2818.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person142_virus_288.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1256-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person442_virus_906.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person854_bacteria_2776.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person436_virus_886.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1713_bacteria_4530.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person287_virus_586.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1049_bacteria_2983.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person75_bacteria_368.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person305_bacteria_1435.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1094-0001-0002.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person428_virus_876.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0919-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1348_virus_2324.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person442_virus_905.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person943_bacteria_2868.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1405_bacteria_3567.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person946_bacteria_2871.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0981-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1698_bacteria_4497.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person372_virus_755.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person749_bacteria_2652.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1187-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1067-0001-0001.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1181-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person328_bacteria_1513.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person281_bacteria_1331.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person313_bacteria_1459.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1952_bacteria_4883.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-0822-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person494_virus_1000.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1706_bacteria_4516.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person294_bacteria_1380.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person413_bacteria_1829.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person162_virus_322.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1103_bacteria_3044.jpeg'
#  'data/chest_xray/val/NORMAL/NORMAL2-IM-1002-0001.jpeg'
#  'data/chest_xray/val/PNEUMONIA/person1403_bacteria_3557.jpeg']

# %%
# store the dataset files as csv, so, distribution of train-validation-test datasets are reproducible
# file names have to be changed according the used specific datasets distribution

train_df = pd.DataFrame(train_files)
valid_df = pd.DataFrame(valid_files)
test_df = pd.DataFrame(test_files)

train_df.to_csv(path_or_buf="./requirements/train_V2_70-10-20.csv", index=False)
valid_df.to_csv(path_or_buf="./requirements/valid_V2_70-10-20.csv", index=False)
test_df.to_csv(path_or_buf="./requirements/test_V2_70-10-20.csv", index=False)

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Data Exploration
#
# Some statistical information about the dataset of chest images.

# %%
def get_percentage(total, other):
    return (other*100)/total

# %%
# print statistics about the dataset
# print('There are {} total chest categories, called: {}, {}.'.format(len(chest_names),chest_names[0],chest_names[1]))
print('There are %d total chest categories' % len(chest_names))  # there are only 2
total = len(np.hstack([train_files, valid_files, test_files]))
print('There are %s total chest images.\n' % (total))
print('There are %d training chest images: %.3f%%' % (len(train_files),
                                                      get_percentage(total, len(train_files))))
print('There are %d validation chest images: %.3f%%' % (len(valid_files),
                                                        get_percentage(total, len(valid_files))))
print('There are %d test chest images: %.3f%%'% (len(test_files),
                                                 get_percentage(total, len(test_files))))
# Out:
# There are 2 total chest categories
# There are 5857 total chest images.
#
# There are 4224 training chest images: 72.119%
# There are 476 validation chest images: 8.127%
# There are 1157 test chest images: 19.754%

# %% [markdown]
# **Note:**<br>
# According the original dataset 89.07% are training images and only 10.66% are test images. This doesn't fit to the rule-of-thumb to use a training/testing separation of 70/30 or 80/20 percent.
# But first, we will have look how the results for the different CNN are working with this original dataset.
#
# As another distribution, as basic for creating the 60-20-20 data version of training-validation-test sets:<br>
# Therefore, this distribution has been changed to the 80/20 ratio. Regarding the second separation of being normal or pneumonia ones (resp. root cause virus or bacteria), the same distribution ratio as before has been choosen. The images moved to the other directories have been selected randomly.
#
# Regarding modified data distribution V2, creating approximately a 70-10-20 % distribution of training-validation-testing sets:<br>
# 80% training images = 4684.8  => 4685, from that amount nearly 10% for validation set  => therefore by division of 32: 132 x 32 = 4224 images are available for the new data training set<br>
# 20% test images = 1171.2,  but some are moved to the validation set now. In the original dataset no virus chest images are included to the validation set. Now there are some and some more bacteria chest images.
#
# How are the categories labelled? Regarding the images, for the different training, testing and validation pneumonia data samples, the images are labelled with 'virus' and 'bacteria' as root cause. This information is part of the image name text string. How many are there from each root cause category? The categories are ...

# %%
# What kind of chest categories exist?
chest_names
# Out:
# ['n/NORMAL', 'n/PNEUMONIA']

# %% [markdown]
# What is the structure of the files from the different directories, means how many images from each category are available in the train, validation and test directories?

# %%
def get_category_counter(file):
    ''' delivers the amount of normal or pneumonia images '''
    counter_normal = 0
    counter_pneumonia = 0
    file_array = file
    pneumonia_files = []
        
    for item in file_array[:]:
        if 'NORMAL' in item:
            counter_normal += 1
        else: # PNEUMONIA case
            # add item to array and increase counter
            pneumonia_files.append(item)
            counter_pneumonia += 1
               
    return counter_normal, counter_pneumonia, pneumonia_files

count_train_normal, count_train_pneumonia, train_pneumonia_files = get_category_counter(train_files)
count_valid_normal, count_valid_pneumonia, valid_pneumonia_files = get_category_counter(valid_files)
count_test_normal, count_test_pneumonia, test_pneumonia_files = get_category_counter(test_files)

print("--- Train files ---")        
print("{} normal chest images.".format(count_train_normal))
print("{} pneumonia chest images.".format(count_train_pneumonia))

print("\n--- Validation files ---")        
print("{} normal chest images.".format(count_valid_normal))
print("{} pneumonia chest images.".format(count_valid_pneumonia))

print("\n--- Test files ---")        
print("{} normal chest images.".format(count_test_normal))
print("{} pneumonia chest images.".format(count_test_pneumonia))
# Out:
# --- Train files ---
# 1049 normal chest images.
# 3175 pneumonia chest images.
#
# --- Validation files ---
# 111 normal chest images.
# 365 pneumonia chest images.
#
# --- Test files ---
# 423 normal chest images.
# 734 pneumonia chest images.

# %%
# Visualise all the findings
locations = [0, 1, 2, 3, 4, 5]
colors = ['darkgreen', 'darkblue', 'darkgreen', 'darkblue', 'darkgreen', 'darkblue']
hights = [count_train_normal, count_train_pneumonia, count_valid_normal, count_valid_pneumonia,
         count_test_normal, count_test_pneumonia]
width = 0.65
label_list = ['Train Normal', 'Train Pneumonia', 'Validation Normal', 'Validation Pneumonia',
              'Test Normal', 'Test Pneumonia']
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

plt.yticks(np.arange(0, 4000, 250))
labels = ax.set_xticklabels(label_list, rotation=70, fontsize='small')
plt.bar(locations, hights, width, color=colors, tick_label=labels, alpha=0.8)
plt.ylim([0, 4000])
plt.title('Absolute Chest Images by Categories', fontsize=15)
plt.xlabel('Categories separated by sample directories', fontsize=13)
green_patch = mpatches.Patch(color='darkgreen', label='NORMAL', alpha=0.8)
blue_patch = mpatches.Patch(color='darkblue', label='PNEUMONIA', alpha=0.8)
plt.legend(handles = [green_patch, blue_patch])

# %% [markdown]
# **Note:**<br>
# In each set there are much more Pneumonia cases compared to the non-Pneumonia ones, especially for the training set. So, there is a kind of imbalance.

# %%
# For simpler usage, first we have to put the data in a dictionary.
# {'train' : {'Normal' : count_train_normal,
#             'Pneumonia' : count_train_pneumonia},
#  'valid' : {'Normal' : count_valid_normal,
#             'Pneumonia' : count_valid_pneumonia}, 
#  'test' : {'Normal' : count_test_normal, 
#            'Pneumonia' : count_test_pneumonia}}

categories_counter_data = {"Sample" : ["train", "valid", "test"],
                           "Normal" : [count_train_normal, count_valid_normal, count_test_normal],
                           "Pneumonia" : [count_train_pneumonia, count_valid_pneumonia, count_test_pneumonia]}

df_categories = pd.DataFrame(data = categories_counter_data, index = ["train", "valid", "test"])

# %%
# Add the amount difference for each category and directory to the dataframe
df_categories['Difference'] = df_categories['Normal'] - df_categories['Pneumonia']

# %%
# Visualise the differences compared to category and sample directories,
# therefore use the absolute values of the differences as well to see them on the same positive level
df_categories['Difference_abs'] = df_categories['Difference'] * (-1)
df_categories.head()
# Out:
#        Normal  Pneumonia Sample  Difference  Difference_abs
# train    1049       3175  train       -2126            2126
# valid     111        365  valid        -254             254
# test      423        734   test        -311             311

# %% [markdown]
# Now, the relationship of the amount difference between the normal and pneumonia samples are visualised.

# %%
#locations = [0, 1, 2}
x_labels = ['Train', 'Valid', 'Test']

df_categories.plot(title='Category Differences Compared to Sample Directories', kind='bar', tick_label=x_labels, alpha=0.9)

# %% [markdown]
# The training set (x label: train) has much more pneumonia cases compared to the normal ones, this is not the case for the testing samples (x label: test) of normal and pneumonia chest images. They look much more balanced. The validation samples (x label: valid) are small, but more balanced as well.
#
# **Additional question** regarding the different sample directories: How many of the pneumonia chest images have virus or bacteria as _root cause_?

# %%
def get_rootcause_counter(files):
    ''' delivers the amount of bacteria or virus pneumonia images '''
    counter_virus = 0
    counter_bacteria = 0
    file_array = files
    
    
    for item in file_array:
        if 'virus' in item:
            counter_virus += 1
        elif 'bacteria' in item:
            counter_bacteria += 1
        else:
            print('{} does not include a root cause in its file name string (virus or bac.')
            
    return counter_virus, counter_bacteria

count_train_virus, count_train_bacteria = get_rootcause_counter(train_pneumonia_files)
count_valid_virus, count_valid_bacteria = get_rootcause_counter(valid_pneumonia_files)
count_test_virus, count_test_bacteria = get_rootcause_counter(test_pneumonia_files)

print("--- Train pneumonia files ---")        
print("{} virus chest images.".format(count_train_virus))
print("{} bacteria chest images.".format(count_train_bacteria))

print("\n--- Validation pneumonia files ---")        
print("{} virus chest images.".format(count_valid_virus))
print("{} bacteria chest images.".format(count_valid_bacteria))

print("\n--- Test pneumonia files ---")        
print("{} virus chest images.".format(count_test_virus))
print("{} bacteria chest images.".format(count_test_bacteria))
# Out:
# --- Train pneumonia files ---
# 1124 virus chest images.
# 2051 bacteria chest images.
#
# --- Validation pneumonia files ---
# 114 virus chest images.
# 251 bacteria chest images.
#
# --- Test pneumonia files ---
# 255 virus chest images.
# 479 bacteria chest images.

# %% [markdown]
# **Note:**<br>
# In the future, having more pneumonia chest images with further root causes (not only virus and bacteria root causes exist), the algorithm can be improved doing a multi-class classification between normal and pneumonia ones, where the pneumonia ones are differentiated by their root cause from the scratch.

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: Data Pre-Processing
#
# Keras is using TensorFlow as backend, means as tensor manipulation. According the TensorFlow [guide](https://www.tensorflow.org/guide/tensors), a "tensor is a generalization of vectors and matrices to potentially higher dimensions. Internally, TensorFlow represents tensors as n-dimensional arrays of base datatypes."
#
# Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input with shape
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively. The channels value is 1, if the image is a grey-scale image and 3 otherwise.
#
#
# The `path_to_tensor` function below takes a string-valued file path to a grey-scale chest image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with grey-scale images, each image has one [channel](https://www.tensorflow.org/api_docs/python/tf/summary/image).  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in the dataset.

# %%
def path_to_tensor(img_path):
    # loads grey-scale image as PIL.Image.Image type
    img = load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# We rescale the images by dividing every pixel in every image by 255.

# %%
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 4224/4224 [01:24<00:00, 49.87it/s]
# 100%|██████████| 476/476 [00:09<00:00, 57.81it/s]
# 100%|██████████| 1157/1157 [00:23<00:00, 51.36it/s]

# %%
print('The tensor shape of the images is:')
print('Train dataset shape: {}'.format(train_tensors.shape))
print('Validation dataset shape: {}'.format(valid_tensors.shape))
print('Test dataset shape: {}'.format(test_tensors.shape))
# Out:
# The tensor shape of the images is:
# Train dataset shape: (4224, 224, 224, 3)
# Validation dataset shape: (476, 224, 224, 3)
# Test dataset shape: (1157, 224, 224, 3)

# %% [markdown]
# <a id='step4'></a>
# ## Step 4: Create a CNN Model from the Scratch (Basic Model)
#
# ### Model Implementation
#
# Start creating a basic model with 5 blocks of Convolutional, MaxPooling and Dropout sublayers as hidden layer components. As flatten layer GlobalAveragePooling2D is used. The output Dense layer for the 2 resulting categories NORMAL and PNEUMONIA is using 'softmax' as activation function.

# %%
# Define the base model architecture.
# Start with the basic model
base_model_class = Model("Basic", "Basic_CNN_Model", "accuracy")
# Out:
# --- Build model summary of Basic_CNN_Model: ---
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 224, 224, 16)      208
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 112, 112, 16)      0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 112, 112, 32)      2080
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 56, 56, 64)        8256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 128)       32896
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 14, 256)       131328
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 7, 7, 256)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 7, 7, 256)         0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 175,282
# Trainable params: 175,282
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model
#
# As optimiser 'rmsprop' with loss function 'binary_crossentropy' and 'accuracy' metric is used. The weights of the model layers will be updated during training.

# %%
base_model_class = base_model_class.get_class()
# Is it the expected class?
base_model_class

# %%
# use with general optimiser 'rmsprop'
base_model = base_model_class.get_model()
base_model_class.compile_model(model=base_model, optimizer='rmsprop',
                               loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model
#
# Model training with use of checkpointing to save the model that attains the best validation loss. The following hyperparameters are set:
# - `epochs` is set to a number of iterations including the point where the network stops learning or start overfitting
# - `batch_size` is set to a common minimal size of memory: 32; if your machine is better use 64, 128, 256, ...
#
# For the modified V2 dataset: train on 132 x 32 = 4224 samples  (batch size of 32)

# %%
# specify the number of epochs used to train the model

base_model_history = base_model_class.train_model(model=base_model, epochs=20, batch_size=32,
                                           filepath='./saved_models/base_model_weights.best.from_scratch.hdf5',
                                           train_tensors=train_tensors, train_targets=train_targets,
                                           valid_tensors=valid_tensors, valid_targets=valid_targets)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 4224 samples, validate on 476 samples
# Epoch 1/20
#  - 313s - loss: 3.8770 - acc: 0.7379 - val_loss: 2.5792 - val_acc: 0.7668
#
# Epoch 00001: val_loss improved from inf to 2.57919, saving model to ./saved_models/base_model_weights.best.from_scratch.hdf5
# Epoch 2/20
#  - 313s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.5828 - val_acc: 0.7668
#
# Epoch 00002: val_loss did not improve from 2.57919
# Epoch 3/20
#  - 312s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.8341 - val_acc: 0.7668
#
# Epoch 00003: val_loss did not improve from 2.57919
# Epoch 4/20
#  - 311s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.8641 - val_acc: 0.7668
#
# Epoch 00004: val_loss did not improve from 2.57919
# Epoch 5/20
#  - 311s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.8641 - val_acc: 0.7668
#
# Epoch 00005: val_loss did not improve from 2.57919
# Epoch 6/20
#  - 311s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.8641 - val_acc: 0.7668
#
# Epoch 00006: val_loss did not improve from 2.57919
# Epoch 7/20
#  - 311s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.8641 - val_acc: 0.7668
#
# Epoch 00007: val_loss did not improve from 2.57919
# Epoch 8/20
#  - 311s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.8945 - val_acc: 0.7668
#
# Epoch 00008: val_loss did not improve from 2.57919
# Epoch 9/20
#  - 310s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.8945 - val_acc: 0.7668
#
# Epoch 00009: val_loss did not improve from 2.57919
# Epoch 10/20
#  - 311s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.8945 - val_acc: 0.7668
#
# Epoch 00010: val_loss did not improve from 2.57919
# Epoch 11/20
#  - 311s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.8945 - val_acc: 0.7668
#
# Epoch 00011: val_loss did not improve from 2.57919
# Epoch 12/20
#  - 312s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.8945 - val_acc: 0.7668
#
# Epoch 00012: val_loss did not improve from 2.57919
# Epoch 13/20
#  - 312s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.8945 - val_acc: 0.7668
#
# Epoch 00013: val_loss did not improve from 2.57919
# Epoch 14/20
#  - 312s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.8945 - val_acc: 0.7668
#
# Epoch 00014: val_loss did not improve from 2.57919
# Epoch 15/20
#  - 312s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.8945 - val_acc: 0.7668
#
# Epoch 00015: val_loss did not improve from 2.57919
# Epoch 16/20
#  - 312s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.8945 - val_acc: 0.7668
#
# Epoch 00016: val_loss did not improve from 2.57919
# Epoch 17/20
#  - 312s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.8945 - val_acc: 0.7668
#
# Epoch 00017: val_loss did not improve from 2.57919
# Epoch 18/20
#  - 312s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.9268 - val_acc: 0.7668
#
# Epoch 00018: val_loss did not improve from 2.57919
# Epoch 19/20
#  - 312s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.9268 - val_acc: 0.7668
#
# Epoch 00019: val_loss did not improve from 2.57919
# Epoch 20/20
#  - 312s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.9268 - val_acc: 0.7668
#
# Epoch 00020: val_loss did not improve from 2.57919

# %% [markdown]
# **Note:**<br>
# As visible on all results, the model shows high overfitting and no real learning, it cannot be used for the given task. Would this change by using this model architecture with the augmentation concept?

# %% [markdown]
# <a id='step5'></a>
# ## Step 5 Last Basic Model with Augmentation
#
# ### Model Implementation and Training
#
# We are using image data augmentation to decrease the amount of images of our training dataset, and see if there is an improvement to reduce the existing misclassification error. This concept shall improve the performance and the generalisation ability of our network. We want to prevent overfitting. Keras offers already a process to do this, using its ImageDataGenerator object class. The original images are rotated, shifted, zoomed, flipped etc. and by doing this, creating new image mutations. So, the range of images for each epoch increases and the propability that the algorithm sees the same images more than once is much reduced.
#
# Generator handling according the given Keras example using .flow() functionality together with the already created pre-processed tensors instances. With such tensors rescaling by /255 has already happened. The .flow() command generates batches of randomly transformed images.
#
# The generator parameters are set according the image properties, having chest images. E.g. huge zooming or rotation would make no sense, but horizontal flip is fine.
#
# In general according augmentation information, have a look to the associated Keras classification [article](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html).

# %%
train_data_generator = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    rescale=1.,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.05,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='nearest')

validation_generator = ImageDataGenerator(rescale=1)

# %%
batch_size = 32
training_data = train_data_generator.flow(train_tensors, train_targets, batch_size=batch_size)
validation_data = validation_generator.flow(valid_tensors, valid_targets, batch_size=batch_size)

# %%
model = Model("Basic", "Basic_CNN_Model", "accuracy")
aug_base_model_class = model.get_class()
# Out:
# --- Build model summary of Basic_CNN_Model: ---
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 224, 224, 16)      208
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 112, 112, 16)      0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 112, 112, 32)      2080
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 56, 56, 32)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 56, 56, 64)        8256
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 28, 28, 128)       32896
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 14, 14, 256)       131328
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 7, 7, 256)         0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 7, 7, 256)         0
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 175,282
# Trainable params: 175,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
aug_base_model = aug_base_model_class.get_model()
aug_base_model_class.compile_model(model=aug_base_model, optimizer='rmsprop',
                                   loss='binary_crossentropy', metrics=['accuracy'])

# %%
epochs = 20  # first try
aug_base_model_history = aug_base_model_class.augmentation_train_model(model=aug_base_model,
                                  filepath='./saved_models/base_model_weights.best.withAugmentation.hdf5',
                                  training_data=training_data, validation_data=validation_data,
                                  epochs=epochs, batch_size=batch_size,
                                  train_tensors=train_tensors, valid_tensors=valid_tensors)
# Out:
# Epoch 1/20
#  - 317s - loss: 3.9843 - acc: 0.7410 - val_loss: 2.3328 - val_acc: 0.7746
#
# Epoch 00001: val_loss improved from inf to 2.33278, saving model to ./saved_models/base_model_weights.best.withAugmentation.hdf5
# Epoch 2/20
#  - 308s - loss: 3.9810 - acc: 0.7517 - val_loss: 2.5624 - val_acc: 0.7545
#
# Epoch 00002: val_loss did not improve from 2.33278
# Epoch 3/20
#  - 313s - loss: 4.1403 - acc: 0.7417 - val_loss: 3.8631 - val_acc: 0.7590
#
# Epoch 00003: val_loss did not improve from 2.33278
# Epoch 4/20
#  - 316s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.6104 - val_acc: 0.7748
#
# Epoch 00004: val_loss did not improve from 2.33278
# Epoch 5/20
#  - 313s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.6104 - val_acc: 0.7748
#
# Epoch 00005: val_loss did not improve from 2.33278
# Epoch 6/20
#  - 317s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7909 - val_acc: 0.7635
#
# Epoch 00006: val_loss did not improve from 2.33278
# Epoch 7/20
#  - 312s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.6826 - val_acc: 0.7703
#
# Epoch 00007: val_loss did not improve from 2.33278
# Epoch 8/20
#  - 322s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7548 - val_acc: 0.7658
#
# Epoch 00008: val_loss did not improve from 2.33278
# Epoch 9/20
#  - 310s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7548 - val_acc: 0.7658
#
# Epoch 00009: val_loss did not improve from 2.33278
# Epoch 10/20
#  - 324s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.6826 - val_acc: 0.7703
#
# Epoch 00010: val_loss did not improve from 2.33278
# Epoch 11/20
#  - 312s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.8992 - val_acc: 0.7568
#
# Epoch 00011: val_loss did not improve from 2.33278
# Epoch 12/20
#  - 312s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.6104 - val_acc: 0.7748
#
# Epoch 00012: val_loss did not improve from 2.33278
# Epoch 13/20
#  - 309s - loss: 3.9810 - acc: 0.7517 - val_loss: 4.0437 - val_acc: 0.7477
#
# Epoch 00013: val_loss did not improve from 2.33278
# Epoch 14/20
#  - 331s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.5382 - val_acc: 0.7793
#
# Epoch 00014: val_loss did not improve from 2.33278
# Epoch 15/20
#  - 320s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.6826 - val_acc: 0.7703
#
# Epoch 00015: val_loss did not improve from 2.33278
# Epoch 16/20
#  - 323s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.8644 - val_acc: 0.7589
#
# Epoch 00016: val_loss did not improve from 2.33278
# Epoch 17/20
#  - 317s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.6826 - val_acc: 0.7703
#
# Epoch 00017: val_loss did not improve from 2.33278
# Epoch 18/20
#  - 320s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.5021 - val_acc: 0.7815
#
# Epoch 00018: val_loss did not improve from 2.33278
# Epoch 19/20
#  - 312s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.8992 - val_acc: 0.7568
#
# Epoch 00019: val_loss did not improve from 2.33278
# Epoch 20/20
#  - 310s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7187 - val_acc: 0.7680
#
# Epoch 00020: val_loss did not improve from 2.33278

# %% [markdown]
# <a id='step6'></a>
# ## Step 6: Such Basic Model with Adam as Optimiser
#
# Adam is another adaptive gradient descent algorithm. It updates the RMSProp optimiser and shall improve the task performance. Less manual tuning of the hyperparameters for the learning rate schedule is necessary.
#
# ### Compile and Train the Model

# %%
# Start creating as new instance with the basic model
model = Model("Basic", "Basic_CNN_Model", "accuracy")
adam_base_model_class = model.get_class()
adam_base_model = adam_base_model_class.get_model()
adam_base_model  # must be Sequential instance
# Out:
# --- Build model summary of Basic_CNN_Model: ---
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 224, 224, 16)      208
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 112, 112, 16)      0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 112, 112, 32)      2080
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 56, 56, 32)        0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 56, 56, 64)        8256
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 28, 28, 128)       32896
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 14, 14, 256)       131328
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 7, 7, 256)         0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 7, 7, 256)         0
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 175,282
# Trainable params: 175,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
# adam defaults:
# keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
# learn with decay to avoid overfitting, decay=1e-6
adam_base_model_class.set_Adam_params()
adam_base_model_class.compile_model(model=adam_base_model, optimizer='Adam', loss='binary_crossentropy',
                                    metrics=['accuracy'])
adam_base_model = adam_base_model_class.get_model()

# %%
# train the model with call of train function
adam_base_model_history = adam_base_model_class.train_model(model=adam_base_model, epochs=20, batch_size = 32,
                                  filepath='./saved_models/base_model_weights_withAdam.best.from_scratch.hdf5',
                                  train_tensors=train_tensors, train_targets=train_targets,
                                  valid_tensors=valid_tensors, valid_targets=valid_targets)
# Out:
# Train on 4224 samples, validate on 476 samples
# Epoch 1/20
#  - 305s - loss: 0.5294 - acc: 0.7557 - val_loss: 0.3860 - val_acc: 0.8067
#
# Epoch 00001: val_loss improved from inf to 0.38598, saving model to ./saved_models/base_model_weights_withAdam.best.from_scratch.hdf5
# Epoch 2/20
#  - 303s - loss: 0.3705 - acc: 0.8163 - val_loss: 0.3855 - val_acc: 0.8214
#
# Epoch 00002: val_loss improved from 0.38598 to 0.38547, saving model to ./saved_models/base_model_weights_withAdam.best.from_scratch.hdf5
# Epoch 3/20
#  - 302s - loss: 0.3414 - acc: 0.8376 - val_loss: 0.3823 - val_acc: 0.8382
#
# Epoch 00003: val_loss improved from 0.38547 to 0.38226, saving model to ./saved_models/base_model_weights_withAdam.best.from_scratch.hdf5
# Epoch 4/20
#  - 303s - loss: 0.3285 - acc: 0.8456 - val_loss: 0.3725 - val_acc: 0.8424
#
# Epoch 00004: val_loss improved from 0.38226 to 0.37247, saving model to ./saved_models/base_model_weights_withAdam.best.from_scratch.hdf5
# Epoch 5/20
#  - 303s - loss: 0.3074 - acc: 0.8539 - val_loss: 0.3367 - val_acc: 0.8550
#
# Epoch 00005: val_loss improved from 0.37247 to 0.33671, saving model to ./saved_models/base_model_weights_withAdam.best.from_scratch.hdf5
# Epoch 6/20
#  - 304s - loss: 0.2871 - acc: 0.8719 - val_loss: 0.2907 - val_acc: 0.8845
#
# Epoch 00006: val_loss improved from 0.33671 to 0.29067, saving model to ./saved_models/base_model_weights_withAdam.best.from_scratch.hdf5
# Epoch 7/20
#  - 303s - loss: 0.2741 - acc: 0.8688 - val_loss: 0.2828 - val_acc: 0.8613
#
# Epoch 00007: val_loss improved from 0.29067 to 0.28276, saving model to ./saved_models/base_model_weights_withAdam.best.from_scratch.hdf5
# Epoch 8/20
#  - 303s - loss: 0.2566 - acc: 0.8861 - val_loss: 0.2791 - val_acc: 0.8887
#
# Epoch 00008: val_loss improved from 0.28276 to 0.27915, saving model to ./saved_models/base_model_weights_withAdam.best.from_scratch.hdf5
# Epoch 9/20
#  - 304s - loss: 0.2426 - acc: 0.8923 - val_loss: 0.2363 - val_acc: 0.9097
#
# Epoch 00009: val_loss improved from 0.27915 to 0.23633, saving model to ./saved_models/base_model_weights_withAdam.best.from_scratch.hdf5
# Epoch 10/20
#  - 303s - loss: 0.2384 - acc: 0.8935 - val_loss: 0.2583 - val_acc: 0.8634
#
# Epoch 00010: val_loss did not improve from 0.23633
# Epoch 11/20
#  - 303s - loss: 0.2320 - acc: 0.9039 - val_loss: 0.2405 - val_acc: 0.9055
#
# Epoch 00011: val_loss did not improve from 0.23633
# Epoch 12/20
#  - 303s - loss: 0.2106 - acc: 0.9103 - val_loss: 0.2222 - val_acc: 0.8845
#
# Epoch 00012: val_loss improved from 0.23633 to 0.22223, saving model to ./saved_models/base_model_weights_withAdam.best.from_scratch.hdf5
# Epoch 13/20
#  - 303s - loss: 0.2228 - acc: 0.9041 - val_loss: 0.1911 - val_acc: 0.9265
#
# Epoch 00013: val_loss improved from 0.22223 to 0.19112, saving model to ./saved_models/base_model_weights_withAdam.best.from_scratch.hdf5
# Epoch 14/20
#  - 304s - loss: 0.2044 - acc: 0.9077 - val_loss: 0.1760 - val_acc: 0.9349
#
# Epoch 00014: val_loss improved from 0.19112 to 0.17599, saving model to ./saved_models/base_model_weights_withAdam.best.from_scratch.hdf5
# Epoch 15/20
#  - 304s - loss: 0.1837 - acc: 0.9190 - val_loss: 0.2169 - val_acc: 0.9202
#
# Epoch 00015: val_loss did not improve from 0.17599
# Epoch 16/20
#  - 303s - loss: 0.1941 - acc: 0.9195 - val_loss: 0.1731 - val_acc: 0.9286
#
# Epoch 00016: val_loss improved from 0.17599 to 0.17315, saving model to ./saved_models/base_model_weights_withAdam.best.from_scratch.hdf5
# Epoch 17/20
#  - 303s - loss: 0.1751 - acc: 0.9273 - val_loss: 0.1343 - val_acc: 0.9559
#
# Epoch 00017: val_loss improved from 0.17315 to 0.13433, saving model to ./saved_models/base_model_weights_withAdam.best.from_scratch.hdf5
# Epoch 18/20
#  - 303s - loss: 0.1726 - acc: 0.9252 - val_loss: 0.1461 - val_acc: 0.9559
#
# Epoch 00018: val_loss did not improve from 0.13433
# Epoch 19/20
#  - 303s - loss: 0.1531 - acc: 0.9401 - val_loss: 0.1528 - val_acc: 0.9454
#
# Epoch 00019: val_loss did not improve from 0.13433
# Epoch 20/20
#  - 303s - loss: 0.1525 - acc: 0.9408 - val_loss: 0.1328 - val_acc: 0.9517
#
# Epoch 00020: val_loss improved from 0.13433 to 0.13283, saving model to ./saved_models/base_model_weights_withAdam.best.from_scratch.hdf5

# %% [markdown]
# <a id='step7'></a>
# ## Step 7: Last Basic Model with Adam and Augmentation
#
# ### Model Implementation and Training

# %%
# create new instance
model = Model("Basic", "Basic_CNN_Model", "accuracy")
adam_aug_base_model_class = model.get_class()
adam_aug_base_model = adam_aug_base_model_class.get_model()
# Out:
# --- Build model summary of Basic_CNN_Model: ---
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 224, 224, 16)      208
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 112, 112, 16)      0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 112, 112, 32)      2080
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 56, 56, 32)        0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 56, 56, 64)        8256
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 28, 28, 128)       32896
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 14, 14, 256)       131328
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 7, 7, 256)         0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 7, 7, 256)         0
# _________________________________________________________________
# global_average_pooling2d_5 ( (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 175,282
# Trainable params: 175,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
adam_aug_base_model_class.set_Adam_params()
adam_aug_base_model_class.compile_model(model=adam_aug_base_model, optimizer='Adam', loss='binary_crossentropy',
                                    metrics=['accuracy'])
adam_aug_base_model = adam_aug_base_model_class.get_model()

# %%
epochs = 20
#  still the same: batch_size = 32

# use the same generator instance and flow data as before ...
adam_aug_base_model_history = adam_aug_base_model_class.augmentation_train_model(model=adam_aug_base_model,
                                  filepath='./saved_models/Adam_base_model_weights.best.withAugmentation.hdf5',
                                  training_data=training_data, validation_data=validation_data,
                                  epochs=epochs, batch_size=batch_size,
                                  train_tensors=train_tensors, valid_tensors=valid_tensors)
# Out:
# Epoch 1/20
#  - 306s - loss: 0.5483 - acc: 0.7476 - val_loss: 0.5931 - val_acc: 0.7387
#
# Epoch 00001: val_loss improved from inf to 0.59309, saving model to ./saved_models/Adam_base_model_weights.best.withAugmentation.hdf5
# Epoch 2/20
#  - 305s - loss: 0.4392 - acc: 0.7498 - val_loss: 0.5822 - val_acc: 0.7523
#
# Epoch 00002: val_loss improved from 0.59309 to 0.58224, saving model to ./saved_models/Adam_base_model_weights.best.withAugmentation.hdf5
# Epoch 3/20
#  - 320s - loss: 0.3674 - acc: 0.8068 - val_loss: 0.4350 - val_acc: 0.7793
#
# Epoch 00003: val_loss improved from 0.58224 to 0.43497, saving model to ./saved_models/Adam_base_model_weights.best.withAugmentation.hdf5
# Epoch 4/20
#  - 304s - loss: 0.3508 - acc: 0.8435 - val_loss: 0.4029 - val_acc: 0.8243
#
# Epoch 00004: val_loss improved from 0.43497 to 0.40286, saving model to ./saved_models/Adam_base_model_weights.best.withAugmentation.hdf5
# Epoch 5/20
#  - 307s - loss: 0.3261 - acc: 0.8575 - val_loss: 0.3813 - val_acc: 0.8063
#
# Epoch 00005: val_loss improved from 0.40286 to 0.38130, saving model to ./saved_models/Adam_base_model_weights.best.withAugmentation.hdf5
# Epoch 6/20
#  - 309s - loss: 0.3319 - acc: 0.8487 - val_loss: 0.3934 - val_acc: 0.8266
#
# Epoch 00006: val_loss did not improve from 0.38130
# Epoch 7/20
#  - 308s - loss: 0.3162 - acc: 0.8615 - val_loss: 0.3978 - val_acc: 0.8147
#
# Epoch 00007: val_loss did not improve from 0.38130
# Epoch 8/20
#  - 328s - loss: 0.2975 - acc: 0.8703 - val_loss: 0.3692 - val_acc: 0.8086
#
# Epoch 00008: val_loss improved from 0.38130 to 0.36923, saving model to ./saved_models/Adam_base_model_weights.best.withAugmentation.hdf5
# Epoch 9/20
#  - 312s - loss: 0.2864 - acc: 0.8764 - val_loss: 0.4654 - val_acc: 0.8018
#
# Epoch 00009: val_loss did not improve from 0.36923
# Epoch 10/20
#  - 307s - loss: 0.2780 - acc: 0.8854 - val_loss: 0.3255 - val_acc: 0.8604
#
# Epoch 00010: val_loss improved from 0.36923 to 0.32548, saving model to ./saved_models/Adam_base_model_weights.best.withAugmentation.hdf5
# Epoch 11/20
#  - 308s - loss: 0.2755 - acc: 0.8840 - val_loss: 0.4610 - val_acc: 0.7838
#
# Epoch 00011: val_loss did not improve from 0.32548
# Epoch 12/20
#  - 328s - loss: 0.2754 - acc: 0.8793 - val_loss: 0.4242 - val_acc: 0.8086
#
# Epoch 00012: val_loss did not improve from 0.32548
# Epoch 13/20
#  - 326s - loss: 0.2522 - acc: 0.8887 - val_loss: 0.4636 - val_acc: 0.7905
#
# Epoch 00013: val_loss did not improve from 0.32548
# Epoch 14/20
#  - 303s - loss: 0.2682 - acc: 0.8854 - val_loss: 0.4221 - val_acc: 0.7838
#
# Epoch 00014: val_loss did not improve from 0.32548
# Epoch 15/20
#  - 301s - loss: 0.2432 - acc: 0.8965 - val_loss: 0.3925 - val_acc: 0.8198
#
# Epoch 00015: val_loss did not improve from 0.32548
# Epoch 16/20
#  - 304s - loss: 0.2460 - acc: 0.8982 - val_loss: 0.6483 - val_acc: 0.7342
#
# Epoch 00016: val_loss did not improve from 0.32548
# Epoch 17/20
#  - 303s - loss: 0.2318 - acc: 0.9039 - val_loss: 0.3158 - val_acc: 0.8694
#
# Epoch 00017: val_loss improved from 0.32548 to 0.31581, saving model to ./saved_models/Adam_base_model_weights.best.withAugmentation.hdf5
# Epoch 18/20
#  - 313s - loss: 0.2357 - acc: 0.9020 - val_loss: 0.3530 - val_acc: 0.8333
#
# Epoch 00018: val_loss did not improve from 0.31581
# Epoch 19/20
#  - 310s - loss: 0.2369 - acc: 0.9036 - val_loss: 0.3867 - val_acc: 0.8356
#
# Epoch 00019: val_loss did not improve from 0.31581
# Epoch 20/20
#  - 313s - loss: 0.2206 - acc: 0.9091 - val_loss: 0.3733 - val_acc: 0.8221
#
# Epoch 00020: val_loss did not improve from 0.31581

# %% [markdown]
# <a id='step8'></a>
# ## Step 8: Create an improved CNN Model with Adam
#
# Now, we train a model having more hidden layers - a more complex architecture - using Adam as optimiser at once, what kind of result will be calculated compared to the last basic model after having done the augmentation improvement? The Adam optimiser is used for learning with binary crossentropy loss function.
#
# Afterwards, we apply the augmentation concept on this improved model and see what kind of performance difference will appear. Is there an improvement compared to the model architecture before?
#
# To know more about improved model architectures the following [paper](https://www.cv-foundation.org/openaccess/content_cvpr_2015/papers/Szegedy_Going_Deeper_With_2015_CVPR_paper.pdf) is available:
# 'Going Deeper with Convolutions'
#
#
# ### Model Implementation

# %%
# Define the improved model architecture.
improved_model = Model("Improved", "Improved_CNN_Model", "accuracy")
improved_model_class = improved_model.get_class()
# Out:
# --- Build model summary of Improved_CNN_Model: ---
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_26 (Conv2D)           (None, 224, 224, 16)      208
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 112, 112, 16)      0
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 112, 112, 32)      2080
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 111, 111, 32)      4128
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 56, 56, 32)        0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 56, 56, 64)        8256
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 55, 55, 64)        16448
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 28, 28, 128)       32896
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 27, 27, 128)       65664
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 14, 14, 256)       131328
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 13, 13, 256)       262400
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 7, 7, 256)         0
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 7, 7, 512)         524800
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 6, 6, 512)         1049088
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 3, 3, 512)         0
# _________________________________________________________________
# global_average_pooling2d_6 ( (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 2,098,322
# Trainable params: 2,098,322
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
# first try: use Adam optimiser with decay=1e-6 
improved_model = improved_model_class.get_model()
improved_model_class.set_Adam_params()
improved_model_class.compile_model(model=improved_model, optimizer='Adam', loss='binary_crossentropy',
                                   metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
epochs = 20
batch_size = 32
improved_model_adam = improved_model_class.get_model()
improved_model_history = improved_model_class.train_model(model=improved_model_adam,
                                           epochs=epochs, batch_size=batch_size,
                                           filepath='./saved_models/improved_model_weights.best.withAdam.hdf5',
                                           train_tensors=train_tensors, train_targets=train_targets,
                                           valid_tensors=valid_tensors, valid_targets=valid_targets)
# Out:
# Train on 4224 samples, validate on 476 samples
# Epoch 1/20
#  - 587s - loss: 3.8847 - acc: 0.7453 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00001: val_loss improved from inf to 3.73814, saving model to ./saved_models/improved_model_weights.best.withAdam.hdf5
# Epoch 2/20
#  - 573s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00002: val_loss did not improve from 3.73814
# Epoch 3/20
#  - 572s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00003: val_loss did not improve from 3.73814
# Epoch 4/20
#  - 572s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00004: val_loss did not improve from 3.73814
# Epoch 5/20
#  - 575s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00005: val_loss did not improve from 3.73814
# Epoch 6/20
#  - 573s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00006: val_loss did not improve from 3.73814
# Epoch 7/20
#  - 573s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00007: val_loss did not improve from 3.73814
# Epoch 8/20
#  - 574s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00008: val_loss did not improve from 3.73814
# Epoch 9/20
#  - 575s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00009: val_loss did not improve from 3.73814
# Epoch 10/20
#  - 574s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00010: val_loss did not improve from 3.73814
# Epoch 11/20
#  - 575s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00011: val_loss did not improve from 3.73814
# Epoch 12/20
#  - 575s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00012: val_loss did not improve from 3.73814
# Epoch 13/20
#  - 575s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00013: val_loss did not improve from 3.73814
# Epoch 14/20
#  - 575s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00014: val_loss did not improve from 3.73814
# Epoch 15/20
#  - 574s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00015: val_loss did not improve from 3.73814
# Epoch 16/20
#  - 574s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00016: val_loss did not improve from 3.73814
# Epoch 17/20
#  - 574s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00017: val_loss did not improve from 3.73814
# Epoch 18/20
#  - 574s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00018: val_loss did not improve from 3.73814
# Epoch 19/20
#  - 574s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00019: val_loss did not improve from 3.73814
# Epoch 20/20
#  - 574s - loss: 3.9810 - acc: 0.7517 - val_loss: 3.7381 - val_acc: 0.7668
#
# Epoch 00020: val_loss did not improve from 3.73814

# %%
# plot the improved model to a file and store it for further usage (only first time)
#plot_model(improved_model_adam, to_file='./saved_models/improved_model_withAdam.png')

# %% [markdown]
# <a id='step9'></a>
# ## Step 9:  Last improved CNN Model with Augmentation
#
# We use the same ImageDataGenerator instance and flow function results as before.

# %%
# new instance learning on the same dataset with augmentation
improved_model_aug = Model("Improved", "Improved_CNN_Model", "accuracy")
improved_model_aug_class = improved_model_aug.get_class()
# Out:
# --- Build model summary of Improved_CNN_Model: ---
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_37 (Conv2D)           (None, 224, 224, 16)      208
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 112, 112, 16)      0
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 112, 112, 32)      2080
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 111, 111, 32)      4128
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 56, 56, 32)        0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 56, 56, 64)        8256
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 55, 55, 64)        16448
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 28, 28, 128)       32896
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 27, 27, 128)       65664
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 14, 14, 256)       131328
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 13, 13, 256)       262400
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 7, 7, 256)         0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 7, 7, 512)         524800
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 6, 6, 512)         1049088
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 3, 3, 512)         0
# _________________________________________________________________
# global_average_pooling2d_7 ( (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 2,098,322
# Trainable params: 2,098,322
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
improved_model_aug = improved_model_aug_class.get_model()
improved_model_aug_class.set_Adam_params(lr=1e-4) # there has been no real learning improvement with the former model
improved_model_aug_class.compile_model(model=improved_model_aug, optimizer='Adam', loss='binary_crossentropy',
                                       metrics=['accuracy'])

# %% [markdown]
# ### Training with Augmentation

# %%
# because the former model does not learn during its training sequence, reduce to 15
# the learning rate is already reduced to lr=1e-4 compared to the default value lr=0.001 used before with the former model
epochs = 15  
batch_size = 32
# generator and generator flow data, training and validation data are the same as before

improved_model_aug_history = improved_model_aug_class.augmentation_train_model(model=improved_model_aug,
                                filepath='./saved_models/improved_model_weights.best.withAugmentation.hdf5', 
                                training_data=training_data, validation_data=validation_data,
                                epochs=epochs, batch_size=batch_size,
                                train_tensors=train_tensors, valid_tensors=valid_tensors)
# Out:
# Epoch 1/15
#  - 589s - loss: 0.5741 - acc: 0.7493 - val_loss: 0.6595 - val_acc: 0.7545
#
# Epoch 00001: val_loss improved from inf to 0.65949, saving model to ./saved_models/improved_model_weights.best.withAugmentation.hdf5
# Epoch 2/15
#  - 584s - loss: 0.5684 - acc: 0.7491 - val_loss: 0.6391 - val_acc: 0.7725
#
# Epoch 00002: val_loss improved from 0.65949 to 0.63911, saving model to ./saved_models/improved_model_weights.best.withAugmentation.hdf5
# Epoch 3/15
#  - 584s - loss: 0.5519 - acc: 0.7554 - val_loss: 0.5750 - val_acc: 0.7613
#
# Epoch 00003: val_loss improved from 0.63911 to 0.57505, saving model to ./saved_models/improved_model_weights.best.withAugmentation.hdf5
# Epoch 4/15
#  - 581s - loss: 0.5001 - acc: 0.7467 - val_loss: 0.5970 - val_acc: 0.7545
#
# Epoch 00004: val_loss did not improve from 0.57505
# Epoch 5/15
#  - 588s - loss: 0.4414 - acc: 0.7526 - val_loss: 0.4663 - val_acc: 0.7703
#
# Epoch 00005: val_loss improved from 0.57505 to 0.46627, saving model to ./saved_models/improved_model_weights.best.withAugmentation.hdf5
# Epoch 6/15
#  - 582s - loss: 0.4126 - acc: 0.7585 - val_loss: 0.4303 - val_acc: 0.7477
#
# Epoch 00006: val_loss improved from 0.46627 to 0.43031, saving model to ./saved_models/improved_model_weights.best.withAugmentation.hdf5
# Epoch 7/15
#  - 581s - loss: 0.3994 - acc: 0.7824 - val_loss: 0.4932 - val_acc: 0.7140
#
# Epoch 00007: val_loss did not improve from 0.43031
# Epoch 8/15
#  - 583s - loss: 0.3757 - acc: 0.8158 - val_loss: 0.5623 - val_acc: 0.6779
#
# Epoch 00008: val_loss did not improve from 0.43031
# Epoch 9/15
#  - 587s - loss: 0.3704 - acc: 0.8127 - val_loss: 0.4723 - val_acc: 0.7590
#
# Epoch 00009: val_loss did not improve from 0.43031
# Epoch 10/15
#  - 584s - loss: 0.3578 - acc: 0.8355 - val_loss: 0.5187 - val_acc: 0.6959
#
# Epoch 00010: val_loss did not improve from 0.43031
# Epoch 11/15
#  - 582s - loss: 0.3398 - acc: 0.8350 - val_loss: 0.5551 - val_acc: 0.6667
#
# Epoch 00011: val_loss did not improve from 0.43031
# Epoch 12/15
#  - 590s - loss: 0.3458 - acc: 0.8442 - val_loss: 0.4817 - val_acc: 0.7770
#
# Epoch 00012: val_loss did not improve from 0.43031
# Epoch 13/15
#  - 594s - loss: 0.3126 - acc: 0.8527 - val_loss: 0.5738 - val_acc: 0.7612
#
# Epoch 00013: val_loss did not improve from 0.43031
# Epoch 14/15
#  - 582s - loss: 0.3082 - acc: 0.8617 - val_loss: 0.3899 - val_acc: 0.8829
#
# Epoch 00014: val_loss improved from 0.43031 to 0.38987, saving model to ./saved_models/improved_model_weights.best.withAugmentation.hdf5
# Epoch 15/15
#  - 583s - loss: 0.2864 - acc: 0.8755 - val_loss: 0.4318 - val_acc: 0.7838
#
# Epoch 00015: val_loss did not improve from 0.38987

# %% [markdown]
# <a id='step10'></a>
# ## Step 10: Create a ResNet CNN Model with Transfer Learning
#
# As sense of transfer learning, Goodfellow et al mentioned in their 'Deep Learning' book "Situation where what has been learned in one setting is exploited to improve generalization in another setting."
#
# We don't have a huge dataset for the given pneumonia classification and more generalised, even not for all human age and X-ray orientation categories. The existing dataset is a specific one for a specific task, therefore we need technical help to improve the classification performance having a good, proper learning result, especially thinking at the 'new, available' image examples of the future.
#
# With a pre-trained model, we use its knowledge even from another domain and task (like for image tasks a pre-trained model from the huge ImageNet database including a lot of different object categories), to let our network learn the new problem. This knowledge transfer is possible, because all images share some same features, like e.g. edges, shapes, zooming or rotation. The common features are learned in the hidden layers from the beginning, the more specific task ones are learned at the end of the hidden layer blocks. To improve our specific classification task we can change the network there and let the first part as learned with the ImageNet database. We don't need our network to learn from scratch. We can freeze such hidden-layer convolutional subblocks and its outputs are the input of the specific classifier block at the end of the network.
#
# Technically, how to do this is e.g. explained in the Keras [documentation](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html).
#
#
# ### Model Implementation and Compilation
#
# First, we create a pre-trained ResNet50 CNN model and freeze the convolution blocks, so that we can use it as an image feature extractor to get the bottleneck features. ResNet is a short name for residual network. It includes a lot of subblocks with BatchNormalization layers.

# %%
basic_resNet_model = Model("Transfer", "Transfer_ResNet_CNN_Model", "accuracy")
#print(resNet_model)
basic_resNet_model_class = basic_resNet_model.get_class()
#print(resNet_model_class)
input_shape = (224, 224, 3) # see info after tensor creation above
basic_resNet_model_class.build_model_feature_extractor(input_shape=input_shape)
# Out:
# /usr/local/lib/python3.5/dist-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# --- Build model summary of RestNet Transfer_CNN_Model as feature extractor: ---
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_38 (MaxPooling2D) (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 56, 56, 64)   4160        max_pooling2d_38[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 56, 56, 256)  16640       max_pooling2d_38[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 56, 56, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 56, 56, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 56, 56, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 56, 56, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 56, 56, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 56, 56, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 56, 56, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 56, 56, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 56, 56, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 28, 28, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 28, 28, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 28, 28, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 28, 28, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 28, 28, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 28, 28, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 28, 28, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 28, 28, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 28, 28, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 28, 28, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 28, 28, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 28, 28, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 28, 28, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 14, 14, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 14, 14, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 14, 14, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 14, 14, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 14, 14, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 14, 14, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 14, 14, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 14, 14, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 14, 14, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 14, 14, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 14, 14, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 14, 14, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 14, 14, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 14, 14, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 14, 14, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 14, 14, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 14, 14, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 14, 14, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 14, 14, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 14, 14, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 14, 14, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 14, 14, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 14, 14, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 14, 14, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 14, 14, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 14, 14, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 14, 14, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 7, 7, 512)    524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 7, 7, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 7, 7, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 7, 7, 2048)   2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 7, 7, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 7, 7, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 7, 7, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 7, 7, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 7, 7, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, 7, 2048)   0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 7, 7, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 7, 7, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 7, 7, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 7, 7, 2048)   0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 7, 7, 2048)   0           add_16[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 2048)         0           activation_49[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 0
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
# plot the transfer model to a file and store it for further usage
basic_resNet_model = basic_resNet_model_class.get_model()

# plotting only first time
#plot_model(basic_resNet_model, to_file='./saved_models/resNet_transfer_model_withoutTopLayer.png')

# %%
# print the status
pd.set_option('max_colwidth', -1)
layers = [(layer, layer.name, layer.trainable) for layer in basic_resNet_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
#                                                                    Layer Type  \
# 0    <keras.engine.input_layer.InputLayer object at 0x7f6aa0258828>
# 1    <keras.layers.convolutional.ZeroPadding2D object at 0x7f6a6ae5a0b8>
# 2    <keras.layers.convolutional.Conv2D object at 0x7f6a6ae5a160>
# 3    <keras.layers.normalization.BatchNormalization object at 0x7f6a6add0908>
# 4    <keras.layers.core.Activation object at 0x7f6a6add0198>
# 5    <keras.layers.convolutional.ZeroPadding2D object at 0x7f6a6ad5f438>
# 6    <keras.layers.pooling.MaxPooling2D object at 0x7f6a6ad95c18>
# 7    <keras.layers.convolutional.Conv2D object at 0x7f6a6adedf28>
# 8    <keras.layers.normalization.BatchNormalization object at 0x7f6a6acb30f0>
# 9    <keras.layers.core.Activation object at 0x7f6a6acb3400>
# 10   <keras.layers.convolutional.Conv2D object at 0x7f6a6ac404a8>
# 11   <keras.layers.normalization.BatchNormalization object at 0x7f6a6ac0dba8>
# 12   <keras.layers.core.Activation object at 0x7f6a6ac0dd30>
# 13   <keras.layers.convolutional.Conv2D object at 0x7f6a6abb1240>
# 14   <keras.layers.convolutional.Conv2D object at 0x7f6a6ab7cdd8>
# 15   <keras.layers.normalization.BatchNormalization object at 0x7f6a6ab7c4a8>
# 16   <keras.layers.normalization.BatchNormalization object at 0x7f6a6aab7fd0>
# 17   <keras.layers.merge.Add object at 0x7f6a6aa65ef0>
# 18   <keras.layers.core.Activation object at 0x7f6a6a990278>
# 19   <keras.layers.convolutional.Conv2D object at 0x7f6a6a990438>
# 20   <keras.layers.normalization.BatchNormalization object at 0x7f6a6a95e4e0>
# 21   <keras.layers.core.Activation object at 0x7f6a6a8be438>
# 22   <keras.layers.convolutional.Conv2D object at 0x7f6a6a8806d8>
# 23   <keras.layers.normalization.BatchNormalization object at 0x7f6a6b984b00>
# 24   <keras.layers.core.Activation object at 0x7f6a6b9af710>
# 25   <keras.layers.convolutional.Conv2D object at 0x7f6a6a7f04a8>
# 26   <keras.layers.normalization.BatchNormalization object at 0x7f6a6a73e668>
# 27   <keras.layers.merge.Add object at 0x7f6a6a73eda0>
# 28   <keras.layers.core.Activation object at 0x7f6a6a6e2358>
# 29   <keras.layers.convolutional.Conv2D object at 0x7f6a6a6e2518>
# ..                                                            ...
# 146  <keras.layers.convolutional.Conv2D object at 0x7f6a684b4da0>
# 147  <keras.layers.normalization.BatchNormalization object at 0x7f6a684665c0>
# 148  <keras.layers.core.Activation object at 0x7f6a68401748>
# 149  <keras.layers.convolutional.Conv2D object at 0x7f6a68389e48>
# 150  <keras.layers.convolutional.Conv2D object at 0x7f6a68371860>
# 151  <keras.layers.normalization.BatchNormalization object at 0x7f6a68351cf8>
# 152  <keras.layers.normalization.BatchNormalization object at 0x7f6a682a28d0>
# 153  <keras.layers.merge.Add object at 0x7f6a6825c400>
# 154  <keras.layers.core.Activation object at 0x7f6a681fd630>
# 155  <keras.layers.convolutional.Conv2D object at 0x7f6a68146550>
# 156  <keras.layers.normalization.BatchNormalization object at 0x7f6a68163470>
# 157  <keras.layers.core.Activation object at 0x7f6a680ca0b8>
# 158  <keras.layers.convolutional.Conv2D object at 0x7f6a68082208>
# 159  <keras.layers.normalization.BatchNormalization object at 0x7f6a6804dd30>
# 160  <keras.layers.core.Activation object at 0x7f6a6804de48>
# 161  <keras.layers.convolutional.Conv2D object at 0x7f6a467b05c0>
# 162  <keras.layers.normalization.BatchNormalization object at 0x7f6a46777198>
# 163  <keras.layers.merge.Add object at 0x7f6a46714320>
# 164  <keras.layers.core.Activation object at 0x7f6a4669e240>
# 165  <keras.layers.convolutional.Conv2D object at 0x7f6a46660780>
# 166  <keras.layers.normalization.BatchNormalization object at 0x7f6a4667b6a0>
# 167  <keras.layers.core.Activation object at 0x7f6a465e72b0>
# 168  <keras.layers.convolutional.Conv2D object at 0x7f6a4659e400>
# 169  <keras.layers.normalization.BatchNormalization object at 0x7f6a465c5128>
# 170  <keras.layers.core.Activation object at 0x7f6a4656a630>
# 171  <keras.layers.convolutional.Conv2D object at 0x7f6a4648a748>
# 172  <keras.layers.normalization.BatchNormalization object at 0x7f6a46454358>
# 173  <keras.layers.merge.Add object at 0x7f6a464704e0>
# 174  <keras.layers.core.Activation object at 0x7f6a463f5400>
# 175  <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f6a463f5ba8>
#
#                      Layer Name  Layer Trainable
# 0    input_1                     False
# 1    conv1_pad                   False
# 2    conv1                       False
# 3    bn_conv1                    False
# 4    activation_1                False
# 5    pool1_pad                   False
# 6    max_pooling2d_38            False
# 7    res2a_branch2a              False
# 8    bn2a_branch2a               False
# 9    activation_2                False
# 10   res2a_branch2b              False
# 11   bn2a_branch2b               False
# 12   activation_3                False
# 13   res2a_branch2c              False
# 14   res2a_branch1               False
# 15   bn2a_branch2c               False
# 16   bn2a_branch1                False
# 17   add_1                       False
# 18   activation_4                False
# 19   res2b_branch2a              False
# 20   bn2b_branch2a               False
# 21   activation_5                False
# 22   res2b_branch2b              False
# 23   bn2b_branch2b               False
# 24   activation_6                False
# 25   res2b_branch2c              False
# 26   bn2b_branch2c               False
# 27   add_2                       False
# 28   activation_7                False
# 29   res2c_branch2a              False
# ..              ...                ...
# 146  res5a_branch2b              False
# 147  bn5a_branch2b               False
# 148  activation_42               False
# 149  res5a_branch2c              False
# 150  res5a_branch1               False
# 151  bn5a_branch2c               False
# 152  bn5a_branch1                False
# 153  add_14                      False
# 154  activation_43               False
# 155  res5b_branch2a              False
# 156  bn5b_branch2a               False
# 157  activation_44               False
# 158  res5b_branch2b              False
# 159  bn5b_branch2b               False
# 160  activation_45               False
# 161  res5b_branch2c              False
# 162  bn5b_branch2c               False
# 163  add_15                      False
# 164  activation_46               False
# 165  res5c_branch2a              False
# 166  bn5c_branch2a               False
# 167  activation_47               False
# 168  res5c_branch2b              False
# 169  bn5c_branch2b               False
# 170  activation_48               False
# 171  res5c_branch2c              False
# 172  bn5c_branch2c               False
# 173  add_16                      False
# 174  activation_49               False
# 175  global_average_pooling2d_8  False
#
# [176 rows x 3 columns]

# %% [markdown]
# The last activation feature map of our ResNet CNN model delivers the bottleneck features. They are the input for the flatten layer and used for our specific, final CNN network layer.

# %%
#
# if you create the bottleneck features the first time, we need this function; but
# if they are already created and stored skip this creation part and go to the part after npzfile.close()
#
def get_bottleneck_features(model, input_imgs):
    features = model.predict(input_imgs, verbose=0)
    return features

# %%
print('--- Create bottleneck features for train tensors images ---')
train_resNet = get_bottleneck_features(basic_resNet_model, train_tensors)
print('--- Create bottleneck features for validation tensors images ---')
valid_resNet = get_bottleneck_features(basic_resNet_model, valid_tensors)
print('--- Create bottleneck features for test tensors images ---')
test_resNet = get_bottleneck_features(basic_resNet_model, test_tensors)
# Out:
# --- Create bottleneck features for train tensors images ---
# --- Create bottleneck features for validation tensors images ---
# --- Create bottleneck features for test tensors images ---

# %%
print('RestNet50 train bottleneck features: {}'.format(train_resNet.shape))
print('RestNet50 validation bottleneck features: {}'.format(valid_resNet.shape))
print('RestNet50 test bottleneck features: {}'.format(test_resNet.shape))
# Out:
# RestNet50 train bottleneck features: (4224, 2048)
# RestNet50 validation bottleneck features: (476, 2048)
# RestNet50 test bottleneck features: (1157, 2048)

# %% [markdown]
# **Note:**<br>
# So, our bottleneck features have a dimension of 1x2048. Our new network architecture is taking this bottleneck vectors as input.

# %%
valid_resNet
# Out:
# array([[0.       , 0.       , 0.       , ..., 1.9842887, 0.       ,
#         0.       ],
#        [0.       , 0.       , 0.       , ..., 2.0337975, 0.       ,
#         0.       ],
#        [0.       , 0.       , 0.       , ..., 1.9719993, 0.       ,
#         0.       ],
#        ...,
#        [0.       , 0.       , 0.       , ..., 1.8648387, 0.       ,
#         0.       ],
#        [0.       , 0.       , 0.       , ..., 2.1463346, 0.       ,
#         0.       ],
#        [0.       , 0.       , 0.       , ..., 1.9260421, 0.       ,
#         0.       ]], dtype=float32)

# %%
# store the bottleneck files
np.savez('./bottleneck_features/chest_ResNet50_features.npz',
         train=train_resNet, valid=valid_resNet, test=test_resNet)

# %%
# test about files, dont' forget to close the file instance
npzfile = np.load('./bottleneck_features/chest_ResNet50_features.npz')
npzfile.files
# Out:
# ['test', 'valid', 'train']

# %%
npzfile['valid']
# Out:
# array([[0.       , 0.       , 0.       , ..., 1.9842887, 0.       ,
#         0.       ],
#        [0.       , 0.       , 0.       , ..., 2.0337975, 0.       ,
#         0.       ],
#        [0.       , 0.       , 0.       , ..., 1.9719993, 0.       ,
#         0.       ],
#        ...,
#        [0.       , 0.       , 0.       , ..., 1.8648387, 0.       ,
#         0.       ],
#        [0.       , 0.       , 0.       , ..., 2.1463346, 0.       ,
#         0.       ],
#        [0.       , 0.       , 0.       , ..., 1.9260421, 0.       ,
#         0.       ]], dtype=float32)

# %%
npzfile.close()

# %% [markdown]
# Now, after having stored the bottleneck features of the train, valid and test tensors, we can build our final CNN architecture, means we add the top layer to the existing ResNet model.
#
# As a top model construction a flatten GlobalAveragePooling2D layer, followed by a BatchNormalization instance and the fully connected Dense layer, which handles the 2 different X-ray chest images categories, are used.

# %%
#
# if the bottleneck feature file is already stored and this python project runs again ... 
# use this lines of code to get the bottleneck features for the train, valid and test samples
#
bottleneck_features = np.load('./bottleneck_features/chest_ResNet50_features.npz')
train_resNet = bottleneck_features['train']
valid_resNet = bottleneck_features['valid']
test_resNet = bottleneck_features['test']
bottleneck_features.close()

# %%
# build the final CNN architecture with added top layer part
basic_resNet_model_class.build_model(basic_resNet_model)
basic_resNet_model = basic_resNet_model_class.get_model()
# Out:
# --- Build model summary of final RestNet Transfer_CNN_Model with top layer: ---
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_1 (Batch (None, 2048)              8192
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 4098
# =================================================================
# Total params: 12,290
# Trainable params: 8,194
# Non-trainable params: 4,096
# _________________________________________________________________

# %%
# let's train the final transfer learning model using Adam with decay 1e-6 for each learning update and 
# a smaller learning rate to avoid to get stuck in a local minimum and to reduce overfitting
basic_resNet_model_class.set_Adam_params(lr=1e-4)
basic_resNet_model_class.compile_model(model=basic_resNet_model, loss='binary_crossentropy',
                                 optimizer='Adam', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
epochs = 300  # fast training compared the previous models
batch_size = 32
basic_resNet_model = basic_resNet_model_class.get_model()
resNet_transfer_model_history = basic_resNet_model_class.train_model(model=basic_resNet_model,
                                  filepath='./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5',
                                           train_tensors=train_resNet, train_targets=train_targets,
                                           valid_tensors=valid_resNet, valid_targets=valid_targets,
                                           epochs=epochs, batch_size=batch_size)
# Out:
# Train on 4224 samples, validate on 476 samples
# Epoch 1/300
#  - 2s - loss: 0.5199 - acc: 0.7474 - val_loss: 0.4065 - val_acc: 0.8193
#
# Epoch 00001: val_loss improved from inf to 0.40654, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 2/300
#  - 0s - loss: 0.3557 - acc: 0.8381 - val_loss: 0.3587 - val_acc: 0.8256
#
# Epoch 00002: val_loss improved from 0.40654 to 0.35865, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 3/300
#  - 0s - loss: 0.3201 - acc: 0.8525 - val_loss: 0.3309 - val_acc: 0.8424
#
# Epoch 00003: val_loss improved from 0.35865 to 0.33085, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 4/300
#  - 0s - loss: 0.2961 - acc: 0.8719 - val_loss: 0.3080 - val_acc: 0.8613
#
# Epoch 00004: val_loss improved from 0.33085 to 0.30799, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 5/300
#  - 0s - loss: 0.2753 - acc: 0.8845 - val_loss: 0.2874 - val_acc: 0.8761
#
# Epoch 00005: val_loss improved from 0.30799 to 0.28741, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 6/300
#  - 0s - loss: 0.2577 - acc: 0.8942 - val_loss: 0.2698 - val_acc: 0.8866
#
# Epoch 00006: val_loss improved from 0.28741 to 0.26981, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 7/300
#  - 0s - loss: 0.2425 - acc: 0.9022 - val_loss: 0.2572 - val_acc: 0.8929
#
# Epoch 00007: val_loss improved from 0.26981 to 0.25723, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 8/300
#  - 0s - loss: 0.2326 - acc: 0.9143 - val_loss: 0.2425 - val_acc: 0.9034
#
# Epoch 00008: val_loss improved from 0.25723 to 0.24252, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 9/300
#  - 0s - loss: 0.2232 - acc: 0.9164 - val_loss: 0.2345 - val_acc: 0.9076
#
# Epoch 00009: val_loss improved from 0.24252 to 0.23447, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 10/300
#  - 0s - loss: 0.2135 - acc: 0.9231 - val_loss: 0.2244 - val_acc: 0.9097
#
# Epoch 00010: val_loss improved from 0.23447 to 0.22445, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 11/300
#  - 0s - loss: 0.2064 - acc: 0.9238 - val_loss: 0.2161 - val_acc: 0.9181
#
# Epoch 00011: val_loss improved from 0.22445 to 0.21609, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 12/300
#  - 0s - loss: 0.1990 - acc: 0.9238 - val_loss: 0.2099 - val_acc: 0.9202
#
# Epoch 00012: val_loss improved from 0.21609 to 0.20991, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 13/300
#  - 0s - loss: 0.1893 - acc: 0.9299 - val_loss: 0.2027 - val_acc: 0.9265
#
# Epoch 00013: val_loss improved from 0.20991 to 0.20267, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 14/300
#  - 0s - loss: 0.1858 - acc: 0.9349 - val_loss: 0.1966 - val_acc: 0.9202
#
# Epoch 00014: val_loss improved from 0.20267 to 0.19661, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 15/300
#  - 0s - loss: 0.1793 - acc: 0.9354 - val_loss: 0.1921 - val_acc: 0.9349
#
# Epoch 00015: val_loss improved from 0.19661 to 0.19205, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 16/300
#  - 0s - loss: 0.1754 - acc: 0.9361 - val_loss: 0.1858 - val_acc: 0.9349
#
# Epoch 00016: val_loss improved from 0.19205 to 0.18576, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 17/300
#  - 0s - loss: 0.1746 - acc: 0.9375 - val_loss: 0.1828 - val_acc: 0.9370
#
# Epoch 00017: val_loss improved from 0.18576 to 0.18276, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 18/300
#  - 0s - loss: 0.1649 - acc: 0.9429 - val_loss: 0.1800 - val_acc: 0.9349
#
# Epoch 00018: val_loss improved from 0.18276 to 0.17999, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 19/300
#  - 0s - loss: 0.1635 - acc: 0.9441 - val_loss: 0.1760 - val_acc: 0.9433
#
# Epoch 00019: val_loss improved from 0.17999 to 0.17598, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 20/300
#  - 0s - loss: 0.1606 - acc: 0.9437 - val_loss: 0.1722 - val_acc: 0.9433
#
# Epoch 00020: val_loss improved from 0.17598 to 0.17219, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 21/300
#  - 0s - loss: 0.1565 - acc: 0.9427 - val_loss: 0.1689 - val_acc: 0.9496
#
# Epoch 00021: val_loss improved from 0.17219 to 0.16894, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 22/300
#  - 0s - loss: 0.1566 - acc: 0.9486 - val_loss: 0.1665 - val_acc: 0.9475
#
# Epoch 00022: val_loss improved from 0.16894 to 0.16650, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 23/300
#  - 0s - loss: 0.1515 - acc: 0.9451 - val_loss: 0.1638 - val_acc: 0.9496
#
# Epoch 00023: val_loss improved from 0.16650 to 0.16382, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 24/300
#  - 0s - loss: 0.1529 - acc: 0.9463 - val_loss: 0.1613 - val_acc: 0.9475
#
# Epoch 00024: val_loss improved from 0.16382 to 0.16126, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 25/300
#  - 0s - loss: 0.1487 - acc: 0.9496 - val_loss: 0.1593 - val_acc: 0.9475
#
# Epoch 00025: val_loss improved from 0.16126 to 0.15933, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 26/300
#  - 0s - loss: 0.1425 - acc: 0.9512 - val_loss: 0.1565 - val_acc: 0.9517
#
# Epoch 00026: val_loss improved from 0.15933 to 0.15652, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 27/300
#  - 0s - loss: 0.1433 - acc: 0.9474 - val_loss: 0.1545 - val_acc: 0.9517
#
# Epoch 00027: val_loss improved from 0.15652 to 0.15448, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 28/300
#  - 0s - loss: 0.1416 - acc: 0.9498 - val_loss: 0.1519 - val_acc: 0.9517
#
# Epoch 00028: val_loss improved from 0.15448 to 0.15190, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 29/300
#  - 0s - loss: 0.1421 - acc: 0.9515 - val_loss: 0.1505 - val_acc: 0.9538
#
# Epoch 00029: val_loss improved from 0.15190 to 0.15054, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 30/300
#  - 0s - loss: 0.1451 - acc: 0.9491 - val_loss: 0.1488 - val_acc: 0.9559
#
# Epoch 00030: val_loss improved from 0.15054 to 0.14882, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 31/300
#  - 0s - loss: 0.1378 - acc: 0.9512 - val_loss: 0.1476 - val_acc: 0.9538
#
# Epoch 00031: val_loss improved from 0.14882 to 0.14763, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 32/300
#  - 0s - loss: 0.1352 - acc: 0.9515 - val_loss: 0.1466 - val_acc: 0.9538
#
# Epoch 00032: val_loss improved from 0.14763 to 0.14665, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 33/300
#  - 0s - loss: 0.1332 - acc: 0.9527 - val_loss: 0.1443 - val_acc: 0.9559
#
# Epoch 00033: val_loss improved from 0.14665 to 0.14429, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 34/300
#  - 0s - loss: 0.1370 - acc: 0.9510 - val_loss: 0.1429 - val_acc: 0.9559
#
# Epoch 00034: val_loss improved from 0.14429 to 0.14293, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 35/300
#  - 0s - loss: 0.1275 - acc: 0.9557 - val_loss: 0.1418 - val_acc: 0.9580
#
# Epoch 00035: val_loss improved from 0.14293 to 0.14179, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 36/300
#  - 0s - loss: 0.1322 - acc: 0.9545 - val_loss: 0.1404 - val_acc: 0.9580
#
# Epoch 00036: val_loss improved from 0.14179 to 0.14037, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 37/300
#  - 0s - loss: 0.1247 - acc: 0.9569 - val_loss: 0.1396 - val_acc: 0.9559
#
# Epoch 00037: val_loss improved from 0.14037 to 0.13957, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 38/300
#  - 0s - loss: 0.1257 - acc: 0.9536 - val_loss: 0.1400 - val_acc: 0.9538
#
# Epoch 00038: val_loss did not improve from 0.13957
# Epoch 39/300
#  - 0s - loss: 0.1251 - acc: 0.9536 - val_loss: 0.1383 - val_acc: 0.9559
#
# Epoch 00039: val_loss improved from 0.13957 to 0.13831, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 40/300
#  - 0s - loss: 0.1224 - acc: 0.9567 - val_loss: 0.1371 - val_acc: 0.9538
#
# Epoch 00040: val_loss improved from 0.13831 to 0.13711, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 41/300
#  - 0s - loss: 0.1193 - acc: 0.9586 - val_loss: 0.1347 - val_acc: 0.9580
#
# Epoch 00041: val_loss improved from 0.13711 to 0.13472, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 42/300
#  - 0s - loss: 0.1240 - acc: 0.9567 - val_loss: 0.1343 - val_acc: 0.9559
#
# Epoch 00042: val_loss improved from 0.13472 to 0.13431, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 43/300
#  - 0s - loss: 0.1248 - acc: 0.9553 - val_loss: 0.1328 - val_acc: 0.9580
#
# Epoch 00043: val_loss improved from 0.13431 to 0.13280, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 44/300
#  - 0s - loss: 0.1193 - acc: 0.9571 - val_loss: 0.1327 - val_acc: 0.9559
#
# Epoch 00044: val_loss improved from 0.13280 to 0.13266, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 45/300
#  - 0s - loss: 0.1250 - acc: 0.9550 - val_loss: 0.1327 - val_acc: 0.9517
#
# Epoch 00045: val_loss did not improve from 0.13266
# Epoch 46/300
#  - 0s - loss: 0.1210 - acc: 0.9555 - val_loss: 0.1308 - val_acc: 0.9559
#
# Epoch 00046: val_loss improved from 0.13266 to 0.13084, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 47/300
#  - 0s - loss: 0.1214 - acc: 0.9588 - val_loss: 0.1293 - val_acc: 0.9580
#
# Epoch 00047: val_loss improved from 0.13084 to 0.12926, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 48/300
#  - 0s - loss: 0.1171 - acc: 0.9571 - val_loss: 0.1297 - val_acc: 0.9559
#
# Epoch 00048: val_loss did not improve from 0.12926
# Epoch 49/300
#  - 0s - loss: 0.1184 - acc: 0.9576 - val_loss: 0.1283 - val_acc: 0.9580
#
# Epoch 00049: val_loss improved from 0.12926 to 0.12832, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 50/300
#  - 0s - loss: 0.1144 - acc: 0.9595 - val_loss: 0.1295 - val_acc: 0.9517
#
# Epoch 00050: val_loss did not improve from 0.12832
# Epoch 51/300
#  - 0s - loss: 0.1191 - acc: 0.9541 - val_loss: 0.1272 - val_acc: 0.9580
#
# Epoch 00051: val_loss improved from 0.12832 to 0.12715, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 52/300
#  - 0s - loss: 0.1119 - acc: 0.9616 - val_loss: 0.1270 - val_acc: 0.9580
#
# Epoch 00052: val_loss improved from 0.12715 to 0.12698, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 53/300
#  - 0s - loss: 0.1141 - acc: 0.9605 - val_loss: 0.1261 - val_acc: 0.9580
#
# Epoch 00053: val_loss improved from 0.12698 to 0.12613, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 54/300
#  - 0s - loss: 0.1098 - acc: 0.9605 - val_loss: 0.1250 - val_acc: 0.9559
#
# Epoch 00054: val_loss improved from 0.12613 to 0.12497, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 55/300
#  - 0s - loss: 0.1141 - acc: 0.9583 - val_loss: 0.1263 - val_acc: 0.9559
#
# Epoch 00055: val_loss did not improve from 0.12497
# Epoch 56/300
#  - 0s - loss: 0.1099 - acc: 0.9616 - val_loss: 0.1244 - val_acc: 0.9580
#
# Epoch 00056: val_loss improved from 0.12497 to 0.12445, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 57/300
#  - 0s - loss: 0.1118 - acc: 0.9583 - val_loss: 0.1235 - val_acc: 0.9580
#
# Epoch 00057: val_loss improved from 0.12445 to 0.12354, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 58/300
#  - 0s - loss: 0.1117 - acc: 0.9616 - val_loss: 0.1222 - val_acc: 0.9580
#
# Epoch 00058: val_loss improved from 0.12354 to 0.12218, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 59/300
#  - 0s - loss: 0.1107 - acc: 0.9607 - val_loss: 0.1217 - val_acc: 0.9580
#
# Epoch 00059: val_loss improved from 0.12218 to 0.12175, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 60/300
#  - 0s - loss: 0.1094 - acc: 0.9612 - val_loss: 0.1212 - val_acc: 0.9559
#
# Epoch 00060: val_loss improved from 0.12175 to 0.12116, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 61/300
#  - 0s - loss: 0.1071 - acc: 0.9619 - val_loss: 0.1208 - val_acc: 0.9580
#
# Epoch 00061: val_loss improved from 0.12116 to 0.12083, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 62/300
#  - 0s - loss: 0.1123 - acc: 0.9562 - val_loss: 0.1204 - val_acc: 0.9580
#
# Epoch 00062: val_loss improved from 0.12083 to 0.12045, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 63/300
#  - 0s - loss: 0.1088 - acc: 0.9579 - val_loss: 0.1197 - val_acc: 0.9580
#
# Epoch 00063: val_loss improved from 0.12045 to 0.11972, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 64/300
#  - 0s - loss: 0.1071 - acc: 0.9614 - val_loss: 0.1191 - val_acc: 0.9580
#
# Epoch 00064: val_loss improved from 0.11972 to 0.11912, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 65/300
#  - 0s - loss: 0.1081 - acc: 0.9616 - val_loss: 0.1188 - val_acc: 0.9580
#
# Epoch 00065: val_loss improved from 0.11912 to 0.11880, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 66/300
#  - 0s - loss: 0.1104 - acc: 0.9590 - val_loss: 0.1191 - val_acc: 0.9559
#
# Epoch 00066: val_loss did not improve from 0.11880
# Epoch 67/300
#  - 0s - loss: 0.1006 - acc: 0.9650 - val_loss: 0.1175 - val_acc: 0.9559
#
# Epoch 00067: val_loss improved from 0.11880 to 0.11748, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 68/300
#  - 0s - loss: 0.1077 - acc: 0.9607 - val_loss: 0.1182 - val_acc: 0.9559
#
# Epoch 00068: val_loss did not improve from 0.11748
# Epoch 69/300
#  - 0s - loss: 0.1062 - acc: 0.9602 - val_loss: 0.1178 - val_acc: 0.9559
#
# Epoch 00069: val_loss did not improve from 0.11748
# Epoch 70/300
#  - 0s - loss: 0.1081 - acc: 0.9588 - val_loss: 0.1165 - val_acc: 0.9580
#
# Epoch 00070: val_loss improved from 0.11748 to 0.11650, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 71/300
#  - 0s - loss: 0.1074 - acc: 0.9616 - val_loss: 0.1159 - val_acc: 0.9580
#
# Epoch 00071: val_loss improved from 0.11650 to 0.11594, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 72/300
#  - 0s - loss: 0.1048 - acc: 0.9624 - val_loss: 0.1167 - val_acc: 0.9559
#
# Epoch 00072: val_loss did not improve from 0.11594
# Epoch 73/300
#  - 0s - loss: 0.1002 - acc: 0.9643 - val_loss: 0.1154 - val_acc: 0.9580
#
# Epoch 00073: val_loss improved from 0.11594 to 0.11535, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 74/300
#  - 0s - loss: 0.1051 - acc: 0.9628 - val_loss: 0.1151 - val_acc: 0.9580
#
# Epoch 00074: val_loss improved from 0.11535 to 0.11510, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 75/300
#  - 0s - loss: 0.1027 - acc: 0.9616 - val_loss: 0.1143 - val_acc: 0.9580
#
# Epoch 00075: val_loss improved from 0.11510 to 0.11429, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 76/300
#  - 0s - loss: 0.1032 - acc: 0.9621 - val_loss: 0.1145 - val_acc: 0.9559
#
# Epoch 00076: val_loss did not improve from 0.11429
# Epoch 77/300
#  - 0s - loss: 0.1015 - acc: 0.9652 - val_loss: 0.1137 - val_acc: 0.9559
#
# Epoch 00077: val_loss improved from 0.11429 to 0.11374, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 78/300
#  - 0s - loss: 0.1011 - acc: 0.9633 - val_loss: 0.1134 - val_acc: 0.9580
#
# Epoch 00078: val_loss improved from 0.11374 to 0.11335, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 79/300
#  - 0s - loss: 0.1015 - acc: 0.9643 - val_loss: 0.1130 - val_acc: 0.9580
#
# Epoch 00079: val_loss improved from 0.11335 to 0.11296, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 80/300
#  - 0s - loss: 0.0992 - acc: 0.9624 - val_loss: 0.1124 - val_acc: 0.9601
#
# Epoch 00080: val_loss improved from 0.11296 to 0.11236, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 81/300
#  - 0s - loss: 0.1006 - acc: 0.9640 - val_loss: 0.1129 - val_acc: 0.9601
#
# Epoch 00081: val_loss did not improve from 0.11236
# Epoch 82/300
#  - 0s - loss: 0.0956 - acc: 0.9661 - val_loss: 0.1118 - val_acc: 0.9601
#
# Epoch 00082: val_loss improved from 0.11236 to 0.11182, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 83/300
#  - 0s - loss: 0.1022 - acc: 0.9638 - val_loss: 0.1114 - val_acc: 0.9601
#
# Epoch 00083: val_loss improved from 0.11182 to 0.11140, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 84/300
#  - 0s - loss: 0.1004 - acc: 0.9631 - val_loss: 0.1107 - val_acc: 0.9601
#
# Epoch 00084: val_loss improved from 0.11140 to 0.11073, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 85/300
#  - 0s - loss: 0.1017 - acc: 0.9631 - val_loss: 0.1108 - val_acc: 0.9601
#
# Epoch 00085: val_loss did not improve from 0.11073
# Epoch 86/300
#  - 0s - loss: 0.0978 - acc: 0.9645 - val_loss: 0.1101 - val_acc: 0.9601
#
# Epoch 00086: val_loss improved from 0.11073 to 0.11013, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 87/300
#  - 0s - loss: 0.0976 - acc: 0.9652 - val_loss: 0.1098 - val_acc: 0.9601
#
# Epoch 00087: val_loss improved from 0.11013 to 0.10979, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 88/300
#  - 0s - loss: 0.0976 - acc: 0.9643 - val_loss: 0.1099 - val_acc: 0.9601
#
# Epoch 00088: val_loss did not improve from 0.10979
# Epoch 89/300
#  - 0s - loss: 0.0968 - acc: 0.9654 - val_loss: 0.1091 - val_acc: 0.9601
#
# Epoch 00089: val_loss improved from 0.10979 to 0.10914, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 90/300
#  - 0s - loss: 0.0968 - acc: 0.9643 - val_loss: 0.1085 - val_acc: 0.9601
#
# Epoch 00090: val_loss improved from 0.10914 to 0.10854, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 91/300
#  - 0s - loss: 0.0937 - acc: 0.9680 - val_loss: 0.1084 - val_acc: 0.9622
#
# Epoch 00091: val_loss improved from 0.10854 to 0.10842, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 92/300
#  - 0s - loss: 0.0970 - acc: 0.9640 - val_loss: 0.1082 - val_acc: 0.9580
#
# Epoch 00092: val_loss improved from 0.10842 to 0.10822, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 93/300
#  - 0s - loss: 0.0936 - acc: 0.9671 - val_loss: 0.1085 - val_acc: 0.9601
#
# Epoch 00093: val_loss did not improve from 0.10822
# Epoch 94/300
#  - 0s - loss: 0.0910 - acc: 0.9678 - val_loss: 0.1081 - val_acc: 0.9601
#
# Epoch 00094: val_loss improved from 0.10822 to 0.10812, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 95/300
#  - 0s - loss: 0.0952 - acc: 0.9650 - val_loss: 0.1073 - val_acc: 0.9601
#
# Epoch 00095: val_loss improved from 0.10812 to 0.10733, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 96/300
#  - 0s - loss: 0.0939 - acc: 0.9647 - val_loss: 0.1075 - val_acc: 0.9601
#
# Epoch 00096: val_loss did not improve from 0.10733
# Epoch 97/300
#  - 0s - loss: 0.0965 - acc: 0.9654 - val_loss: 0.1076 - val_acc: 0.9601
#
# Epoch 00097: val_loss did not improve from 0.10733
# Epoch 98/300
#  - 0s - loss: 0.0964 - acc: 0.9643 - val_loss: 0.1072 - val_acc: 0.9601
#
# Epoch 00098: val_loss improved from 0.10733 to 0.10717, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 99/300
#  - 0s - loss: 0.0937 - acc: 0.9673 - val_loss: 0.1066 - val_acc: 0.9601
#
# Epoch 00099: val_loss improved from 0.10717 to 0.10661, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 100/300
#  - 0s - loss: 0.0896 - acc: 0.9676 - val_loss: 0.1070 - val_acc: 0.9601
#
# Epoch 00100: val_loss did not improve from 0.10661
# Epoch 101/300
#  - 0s - loss: 0.0945 - acc: 0.9669 - val_loss: 0.1067 - val_acc: 0.9601
#
# Epoch 00101: val_loss did not improve from 0.10661
# Epoch 102/300
#  - 0s - loss: 0.0933 - acc: 0.9650 - val_loss: 0.1058 - val_acc: 0.9601
#
# Epoch 00102: val_loss improved from 0.10661 to 0.10577, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 103/300
#  - 0s - loss: 0.0950 - acc: 0.9659 - val_loss: 0.1054 - val_acc: 0.9601
#
# Epoch 00103: val_loss improved from 0.10577 to 0.10545, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 104/300
#  - 0s - loss: 0.0939 - acc: 0.9643 - val_loss: 0.1053 - val_acc: 0.9601
#
# Epoch 00104: val_loss improved from 0.10545 to 0.10528, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 105/300
#  - 0s - loss: 0.0946 - acc: 0.9638 - val_loss: 0.1051 - val_acc: 0.9601
#
# Epoch 00105: val_loss improved from 0.10528 to 0.10511, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 106/300
#  - 0s - loss: 0.0888 - acc: 0.9680 - val_loss: 0.1050 - val_acc: 0.9601
#
# Epoch 00106: val_loss improved from 0.10511 to 0.10498, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 107/300
#  - 0s - loss: 0.0893 - acc: 0.9688 - val_loss: 0.1046 - val_acc: 0.9601
#
# Epoch 00107: val_loss improved from 0.10498 to 0.10455, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 108/300
#  - 0s - loss: 0.0871 - acc: 0.9688 - val_loss: 0.1046 - val_acc: 0.9601
#
# Epoch 00108: val_loss did not improve from 0.10455
# Epoch 109/300
#  - 0s - loss: 0.0919 - acc: 0.9661 - val_loss: 0.1049 - val_acc: 0.9664
#
# Epoch 00109: val_loss did not improve from 0.10455
# Epoch 110/300
#  - 0s - loss: 0.0947 - acc: 0.9628 - val_loss: 0.1042 - val_acc: 0.9643
#
# Epoch 00110: val_loss improved from 0.10455 to 0.10424, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 111/300
#  - 0s - loss: 0.0950 - acc: 0.9628 - val_loss: 0.1037 - val_acc: 0.9601
#
# Epoch 00111: val_loss improved from 0.10424 to 0.10367, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 112/300
#  - 0s - loss: 0.0928 - acc: 0.9659 - val_loss: 0.1036 - val_acc: 0.9643
#
# Epoch 00112: val_loss improved from 0.10367 to 0.10363, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 113/300
#  - 0s - loss: 0.0903 - acc: 0.9671 - val_loss: 0.1032 - val_acc: 0.9643
#
# Epoch 00113: val_loss improved from 0.10363 to 0.10325, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 114/300
#  - 0s - loss: 0.0882 - acc: 0.9671 - val_loss: 0.1035 - val_acc: 0.9664
#
# Epoch 00114: val_loss did not improve from 0.10325
# Epoch 115/300
#  - 0s - loss: 0.0905 - acc: 0.9661 - val_loss: 0.1033 - val_acc: 0.9643
#
# Epoch 00115: val_loss did not improve from 0.10325
# Epoch 116/300
#  - 0s - loss: 0.0908 - acc: 0.9657 - val_loss: 0.1023 - val_acc: 0.9643
#
# Epoch 00116: val_loss improved from 0.10325 to 0.10233, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 117/300
#  - 0s - loss: 0.0873 - acc: 0.9683 - val_loss: 0.1025 - val_acc: 0.9643
#
# Epoch 00117: val_loss did not improve from 0.10233
# Epoch 118/300
#  - 0s - loss: 0.0893 - acc: 0.9680 - val_loss: 0.1023 - val_acc: 0.9664
#
# Epoch 00118: val_loss did not improve from 0.10233
# Epoch 119/300
#  - 0s - loss: 0.0925 - acc: 0.9666 - val_loss: 0.1029 - val_acc: 0.9685
#
# Epoch 00119: val_loss did not improve from 0.10233
# Epoch 120/300
#  - 0s - loss: 0.0932 - acc: 0.9661 - val_loss: 0.1030 - val_acc: 0.9664
#
# Epoch 00120: val_loss did not improve from 0.10233
# Epoch 121/300
#  - 0s - loss: 0.0905 - acc: 0.9669 - val_loss: 0.1024 - val_acc: 0.9685
#
# Epoch 00121: val_loss did not improve from 0.10233
# Epoch 122/300
#  - 0s - loss: 0.0884 - acc: 0.9690 - val_loss: 0.1026 - val_acc: 0.9706
# Epoch 00122: val_loss did not improve from 0.10233
# Epoch 123/300
#  - 0s - loss: 0.0913 - acc: 0.9669 - val_loss: 0.1023 - val_acc: 0.9685
#
# Epoch 00123: val_loss improved from 0.10233 to 0.10230, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 124/300
#  - 0s - loss: 0.0891 - acc: 0.9652 - val_loss: 0.1016 - val_acc: 0.9643
#
# Epoch 00124: val_loss improved from 0.10230 to 0.10159, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 125/300
#  - 0s - loss: 0.0890 - acc: 0.9676 - val_loss: 0.1016 - val_acc: 0.9685
#
# Epoch 00125: val_loss did not improve from 0.10159
# Epoch 126/300
#  - 0s - loss: 0.0855 - acc: 0.9673 - val_loss: 0.1009 - val_acc: 0.9685
#
# Epoch 00126: val_loss improved from 0.10159 to 0.10090, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 127/300
#  - 0s - loss: 0.0856 - acc: 0.9690 - val_loss: 0.1010 - val_acc: 0.9664
#
# Epoch 00127: val_loss did not improve from 0.10090
# Epoch 128/300
#  - 0s - loss: 0.0885 - acc: 0.9673 - val_loss: 0.1008 - val_acc: 0.9685
#
# Epoch 00128: val_loss improved from 0.10090 to 0.10077, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 129/300
#  - 0s - loss: 0.0877 - acc: 0.9676 - val_loss: 0.1011 - val_acc: 0.9685
#
# Epoch 00129: val_loss did not improve from 0.10077
# Epoch 130/300
#  - 0s - loss: 0.0876 - acc: 0.9659 - val_loss: 0.1007 - val_acc: 0.9706
#
# Epoch 00130: val_loss improved from 0.10077 to 0.10074, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 131/300
#  - 0s - loss: 0.0869 - acc: 0.9676 - val_loss: 0.0998 - val_acc: 0.9685
#
# Epoch 00131: val_loss improved from 0.10074 to 0.09984, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 132/300
#  - 0s - loss: 0.0861 - acc: 0.9702 - val_loss: 0.0998 - val_acc: 0.9685
#
# Epoch 00132: val_loss improved from 0.09984 to 0.09983, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 133/300
#  - 0s - loss: 0.0887 - acc: 0.9673 - val_loss: 0.1003 - val_acc: 0.9685
#
# Epoch 00133: val_loss did not improve from 0.09983
# Epoch 134/300
#  - 0s - loss: 0.0888 - acc: 0.9661 - val_loss: 0.1002 - val_acc: 0.9706
#
# Epoch 00134: val_loss did not improve from 0.09983
# Epoch 135/300
#  - 0s - loss: 0.0854 - acc: 0.9702 - val_loss: 0.1002 - val_acc: 0.9685
#
# Epoch 00135: val_loss did not improve from 0.09983
# Epoch 136/300
#  - 0s - loss: 0.0860 - acc: 0.9699 - val_loss: 0.0999 - val_acc: 0.9706
#
# Epoch 00136: val_loss did not improve from 0.09983
# Epoch 137/300
#  - 0s - loss: 0.0856 - acc: 0.9678 - val_loss: 0.0995 - val_acc: 0.9706
#
# Epoch 00137: val_loss improved from 0.09983 to 0.09948, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 138/300
#  - 0s - loss: 0.0887 - acc: 0.9666 - val_loss: 0.0994 - val_acc: 0.9685
#
# Epoch 00138: val_loss improved from 0.09948 to 0.09942, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 139/300
#  - 0s - loss: 0.0847 - acc: 0.9699 - val_loss: 0.0991 - val_acc: 0.9685
#
# Epoch 00139: val_loss improved from 0.09942 to 0.09907, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 140/300
#  - 0s - loss: 0.0892 - acc: 0.9676 - val_loss: 0.0994 - val_acc: 0.9706
#
# Epoch 00140: val_loss did not improve from 0.09907
# Epoch 141/300
#  - 0s - loss: 0.0864 - acc: 0.9706 - val_loss: 0.0990 - val_acc: 0.9727
#
# Epoch 00141: val_loss improved from 0.09907 to 0.09898, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 142/300
#  - 0s - loss: 0.0824 - acc: 0.9685 - val_loss: 0.0987 - val_acc: 0.9748
#
# Epoch 00142: val_loss improved from 0.09898 to 0.09869, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 143/300
#  - 0s - loss: 0.0847 - acc: 0.9695 - val_loss: 0.0984 - val_acc: 0.9706
#
# Epoch 00143: val_loss improved from 0.09869 to 0.09838, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 144/300
#  - 0s - loss: 0.0858 - acc: 0.9702 - val_loss: 0.0986 - val_acc: 0.9727
#
# Epoch 00144: val_loss did not improve from 0.09838
# Epoch 145/300
#  - 0s - loss: 0.0849 - acc: 0.9680 - val_loss: 0.0986 - val_acc: 0.9748
#
# Epoch 00145: val_loss did not improve from 0.09838
# Epoch 146/300
#  - 0s - loss: 0.0855 - acc: 0.9676 - val_loss: 0.0989 - val_acc: 0.9748
#
# Epoch 00146: val_loss did not improve from 0.09838
# Epoch 147/300
#  - 0s - loss: 0.0819 - acc: 0.9702 - val_loss: 0.0982 - val_acc: 0.9727
#
# Epoch 00147: val_loss improved from 0.09838 to 0.09816, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 148/300
#  - 0s - loss: 0.0877 - acc: 0.9647 - val_loss: 0.0985 - val_acc: 0.9727
#
# Epoch 00148: val_loss did not improve from 0.09816
# Epoch 149/300
#  - 0s - loss: 0.0826 - acc: 0.9704 - val_loss: 0.0978 - val_acc: 0.9748
#
# Epoch 00149: val_loss improved from 0.09816 to 0.09784, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 150/300
#  - 0s - loss: 0.0863 - acc: 0.9676 - val_loss: 0.0982 - val_acc: 0.9727
#
# Epoch 00150: val_loss did not improve from 0.09784
# Epoch 151/300
#  - 0s - loss: 0.0863 - acc: 0.9678 - val_loss: 0.0976 - val_acc: 0.9664
#
# Epoch 00151: val_loss improved from 0.09784 to 0.09761, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 152/300
#  - 0s - loss: 0.0833 - acc: 0.9690 - val_loss: 0.0970 - val_acc: 0.9748
#
# Epoch 00152: val_loss improved from 0.09761 to 0.09698, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 153/300
#  - 0s - loss: 0.0804 - acc: 0.9690 - val_loss: 0.0969 - val_acc: 0.9748
#
# Epoch 00153: val_loss improved from 0.09698 to 0.09693, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 154/300
#  - 0s - loss: 0.0811 - acc: 0.9714 - val_loss: 0.0966 - val_acc: 0.9748
#
# Epoch 00154: val_loss improved from 0.09693 to 0.09663, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 155/300
#  - 0s - loss: 0.0795 - acc: 0.9704 - val_loss: 0.0966 - val_acc: 0.9748
#
# Epoch 00155: val_loss improved from 0.09663 to 0.09657, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 156/300
#  - 0s - loss: 0.0834 - acc: 0.9723 - val_loss: 0.0967 - val_acc: 0.9727
#
# Epoch 00156: val_loss did not improve from 0.09657
# Epoch 157/300
#  - 0s - loss: 0.0808 - acc: 0.9714 - val_loss: 0.0963 - val_acc: 0.9748
#
# Epoch 00157: val_loss improved from 0.09657 to 0.09632, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 158/300
#  - 0s - loss: 0.0864 - acc: 0.9699 - val_loss: 0.0964 - val_acc: 0.9748
#
# Epoch 00158: val_loss did not improve from 0.09632
# Epoch 159/300
#  - 0s - loss: 0.0837 - acc: 0.9692 - val_loss: 0.0962 - val_acc: 0.9748
#
# Epoch 00159: val_loss improved from 0.09632 to 0.09618, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 160/300
#  - 0s - loss: 0.0807 - acc: 0.9702 - val_loss: 0.0962 - val_acc: 0.9748
#
# Epoch 00160: val_loss improved from 0.09618 to 0.09617, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 161/300
#  - 0s - loss: 0.0846 - acc: 0.9669 - val_loss: 0.0970 - val_acc: 0.9685
#
# Epoch 00161: val_loss did not improve from 0.09617
# Epoch 162/300
#  - 0s - loss: 0.0785 - acc: 0.9702 - val_loss: 0.0960 - val_acc: 0.9748
#
# Epoch 00162: val_loss improved from 0.09617 to 0.09596, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 163/300
#  - 0s - loss: 0.0830 - acc: 0.9692 - val_loss: 0.0953 - val_acc: 0.9748
#
# Epoch 00163: val_loss improved from 0.09596 to 0.09534, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 164/300
#  - 0s - loss: 0.0820 - acc: 0.9711 - val_loss: 0.0955 - val_acc: 0.9748
#
# Epoch 00164: val_loss did not improve from 0.09534
# Epoch 165/300
#  - 0s - loss: 0.0769 - acc: 0.9716 - val_loss: 0.0955 - val_acc: 0.9748
#
# Epoch 00165: val_loss did not improve from 0.09534
# Epoch 166/300
#  - 0s - loss: 0.0874 - acc: 0.9676 - val_loss: 0.0963 - val_acc: 0.9664
# Epoch 00166: val_loss did not improve from 0.09534
# Epoch 167/300
#  - 0s - loss: 0.0779 - acc: 0.9704 - val_loss: 0.0953 - val_acc: 0.9748
#
# Epoch 00167: val_loss improved from 0.09534 to 0.09527, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 168/300
#  - 0s - loss: 0.0797 - acc: 0.9749 - val_loss: 0.0959 - val_acc: 0.9748
#
# Epoch 00168: val_loss did not improve from 0.09527
# Epoch 169/300
#  - 0s - loss: 0.0751 - acc: 0.9742 - val_loss: 0.0960 - val_acc: 0.9748
#
# Epoch 00169: val_loss did not improve from 0.09527
# Epoch 170/300
#  - 0s - loss: 0.0809 - acc: 0.9706 - val_loss: 0.0958 - val_acc: 0.9748
#
# Epoch 00170: val_loss did not improve from 0.09527
# Epoch 171/300
#  - 0s - loss: 0.0795 - acc: 0.9695 - val_loss: 0.0961 - val_acc: 0.9748
#
# Epoch 00171: val_loss did not improve from 0.09527
# Epoch 172/300
#  - 0s - loss: 0.0851 - acc: 0.9683 - val_loss: 0.0954 - val_acc: 0.9748
#
# Epoch 00172: val_loss did not improve from 0.09527
# Epoch 173/300
#  - 0s - loss: 0.0823 - acc: 0.9690 - val_loss: 0.0960 - val_acc: 0.9706
#
# Epoch 00173: val_loss did not improve from 0.09527
# Epoch 174/300
#  - 0s - loss: 0.0817 - acc: 0.9690 - val_loss: 0.0953 - val_acc: 0.9748
#
# Epoch 00174: val_loss did not improve from 0.09527
# Epoch 175/300
#  - 0s - loss: 0.0831 - acc: 0.9711 - val_loss: 0.0958 - val_acc: 0.9727
#
# Epoch 00175: val_loss did not improve from 0.09527
# Epoch 176/300
#  - 0s - loss: 0.0778 - acc: 0.9704 - val_loss: 0.0961 - val_acc: 0.9727
#
# Epoch 00176: val_loss did not improve from 0.09527
# Epoch 177/300
#  - 0s - loss: 0.0825 - acc: 0.9683 - val_loss: 0.0950 - val_acc: 0.9748
#
# Epoch 00177: val_loss improved from 0.09527 to 0.09503, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 178/300
#  - 0s - loss: 0.0816 - acc: 0.9702 - val_loss: 0.0948 - val_acc: 0.9748
#
# Epoch 00178: val_loss improved from 0.09503 to 0.09481, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 179/300
#  - 0s - loss: 0.0805 - acc: 0.9699 - val_loss: 0.0942 - val_acc: 0.9748
#
# Epoch 00179: val_loss improved from 0.09481 to 0.09424, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 180/300
#  - 0s - loss: 0.0779 - acc: 0.9718 - val_loss: 0.0943 - val_acc: 0.9748
#
# Epoch 00180: val_loss did not improve from 0.09424
# Epoch 181/300
#  - 0s - loss: 0.0800 - acc: 0.9690 - val_loss: 0.0948 - val_acc: 0.9748
#
# Epoch 00181: val_loss did not improve from 0.09424
# Epoch 182/300
#  - 0s - loss: 0.0769 - acc: 0.9730 - val_loss: 0.0937 - val_acc: 0.9748
#
# Epoch 00182: val_loss improved from 0.09424 to 0.09374, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 183/300
#  - 0s - loss: 0.0781 - acc: 0.9704 - val_loss: 0.0950 - val_acc: 0.9664
#
# Epoch 00183: val_loss did not improve from 0.09374
# Epoch 184/300
#  - 0s - loss: 0.0783 - acc: 0.9697 - val_loss: 0.0944 - val_acc: 0.9727
#
# Epoch 00184: val_loss did not improve from 0.09374
# Epoch 185/300
#  - 0s - loss: 0.0847 - acc: 0.9685 - val_loss: 0.0937 - val_acc: 0.9748
#
# Epoch 00185: val_loss improved from 0.09374 to 0.09365, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 186/300
#  - 0s - loss: 0.0795 - acc: 0.9706 - val_loss: 0.0935 - val_acc: 0.9748
#
# Epoch 00186: val_loss improved from 0.09365 to 0.09348, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 187/300
#  - 0s - loss: 0.0786 - acc: 0.9725 - val_loss: 0.0931 - val_acc: 0.9748
#
# Epoch 00187: val_loss improved from 0.09348 to 0.09313, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 188/300
#  - 0s - loss: 0.0766 - acc: 0.9740 - val_loss: 0.0934 - val_acc: 0.9748
#
# Epoch 00188: val_loss did not improve from 0.09313
# Epoch 189/300
#  - 0s - loss: 0.0756 - acc: 0.9723 - val_loss: 0.0930 - val_acc: 0.9748
#
# Epoch 00189: val_loss improved from 0.09313 to 0.09301, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 190/300
#  - 0s - loss: 0.0787 - acc: 0.9714 - val_loss: 0.0927 - val_acc: 0.9748
#
# Epoch 00190: val_loss improved from 0.09301 to 0.09274, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 191/300
#  - 0s - loss: 0.0812 - acc: 0.9709 - val_loss: 0.0932 - val_acc: 0.9748
#
# Epoch 00191: val_loss did not improve from 0.09274
# Epoch 192/300
#  - 0s - loss: 0.0763 - acc: 0.9723 - val_loss: 0.0927 - val_acc: 0.9748
#
# Epoch 00192: val_loss did not improve from 0.09274
# Epoch 193/300
#  - 0s - loss: 0.0742 - acc: 0.9711 - val_loss: 0.0921 - val_acc: 0.9748
#
# Epoch 00193: val_loss improved from 0.09274 to 0.09206, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 194/300
#  - 0s - loss: 0.0783 - acc: 0.9725 - val_loss: 0.0920 - val_acc: 0.9748
#
# Epoch 00194: val_loss improved from 0.09206 to 0.09203, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 195/300
#  - 0s - loss: 0.0734 - acc: 0.9723 - val_loss: 0.0932 - val_acc: 0.9664
#
# Epoch 00195: val_loss did not improve from 0.09203
# Epoch 196/300
#  - 0s - loss: 0.0761 - acc: 0.9704 - val_loss: 0.0924 - val_acc: 0.9748
#
# Epoch 00196: val_loss did not improve from 0.09203
# Epoch 197/300
#  - 0s - loss: 0.0778 - acc: 0.9690 - val_loss: 0.0925 - val_acc: 0.9748
#
# Epoch 00197: val_loss did not improve from 0.09203
# Epoch 198/300
#  - 0s - loss: 0.0768 - acc: 0.9714 - val_loss: 0.0929 - val_acc: 0.9748
#
# Epoch 00198: val_loss did not improve from 0.09203
# Epoch 199/300
#  - 0s - loss: 0.0755 - acc: 0.9716 - val_loss: 0.0925 - val_acc: 0.9748
#
# Epoch 00199: val_loss did not improve from 0.09203
# Epoch 200/300
#  - 0s - loss: 0.0756 - acc: 0.9709 - val_loss: 0.0927 - val_acc: 0.9748
#
# Epoch 00200: val_loss did not improve from 0.09203
# Epoch 201/300
#  - 0s - loss: 0.0783 - acc: 0.9683 - val_loss: 0.0926 - val_acc: 0.9748
#
# Epoch 00201: val_loss did not improve from 0.09203
# Epoch 202/300
#  - 0s - loss: 0.0770 - acc: 0.9716 - val_loss: 0.0929 - val_acc: 0.9727
#
# Epoch 00202: val_loss did not improve from 0.09203
# Epoch 203/300
#  - 0s - loss: 0.0737 - acc: 0.9737 - val_loss: 0.0921 - val_acc: 0.9748
#
# Epoch 00203: val_loss did not improve from 0.09203
# Epoch 204/300
#  - 0s - loss: 0.0767 - acc: 0.9688 - val_loss: 0.0923 - val_acc: 0.9748
#
# Epoch 00204: val_loss did not improve from 0.09203
# Epoch 205/300
#  - 0s - loss: 0.0811 - acc: 0.9680 - val_loss: 0.0919 - val_acc: 0.9748
#
# Epoch 00205: val_loss improved from 0.09203 to 0.09187, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 206/300
#  - 0s - loss: 0.0757 - acc: 0.9716 - val_loss: 0.0924 - val_acc: 0.9748
#
# Epoch 00206: val_loss did not improve from 0.09187
# Epoch 207/300
#  - 0s - loss: 0.0755 - acc: 0.9716 - val_loss: 0.0922 - val_acc: 0.9748
#
# Epoch 00207: val_loss did not improve from 0.09187
# Epoch 208/300
#  - 0s - loss: 0.0797 - acc: 0.9711 - val_loss: 0.0924 - val_acc: 0.9748
#
# Epoch 00208: val_loss did not improve from 0.09187
# Epoch 209/300
#  - 0s - loss: 0.0738 - acc: 0.9723 - val_loss: 0.0919 - val_acc: 0.9748
#
# Epoch 00209: val_loss did not improve from 0.09187
# Epoch 210/300
#  - 0s - loss: 0.0773 - acc: 0.9732 - val_loss: 0.0918 - val_acc: 0.9748
#
# Epoch 00210: val_loss improved from 0.09187 to 0.09181, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 211/300
#  - 0s - loss: 0.0760 - acc: 0.9725 - val_loss: 0.0915 - val_acc: 0.9748
#
# Epoch 00211: val_loss improved from 0.09181 to 0.09152, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 212/300
#  - 0s - loss: 0.0788 - acc: 0.9716 - val_loss: 0.0918 - val_acc: 0.9727
#
# Epoch 00212: val_loss did not improve from 0.09152
# Epoch 213/300
#  - 0s - loss: 0.0758 - acc: 0.9721 - val_loss: 0.0913 - val_acc: 0.9748
#
# Epoch 00213: val_loss improved from 0.09152 to 0.09129, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 214/300
#  - 0s - loss: 0.0755 - acc: 0.9714 - val_loss: 0.0915 - val_acc: 0.9748
#
# Epoch 00214: val_loss did not improve from 0.09129
# Epoch 215/300
#  - 0s - loss: 0.0735 - acc: 0.9742 - val_loss: 0.0912 - val_acc: 0.9748
#
# Epoch 00215: val_loss improved from 0.09129 to 0.09118, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 216/300
#  - 0s - loss: 0.0744 - acc: 0.9702 - val_loss: 0.0906 - val_acc: 0.9748
#
# Epoch 00216: val_loss improved from 0.09118 to 0.09058, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 217/300
#  - 0s - loss: 0.0765 - acc: 0.9709 - val_loss: 0.0902 - val_acc: 0.9748
#
# Epoch 00217: val_loss improved from 0.09058 to 0.09023, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 218/300
#  - 0s - loss: 0.0758 - acc: 0.9728 - val_loss: 0.0902 - val_acc: 0.9748
#
# Epoch 00218: val_loss improved from 0.09023 to 0.09023, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 219/300
#  - 0s - loss: 0.0733 - acc: 0.9725 - val_loss: 0.0902 - val_acc: 0.9748
#
# Epoch 00219: val_loss improved from 0.09023 to 0.09016, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 220/300
#  - 0s - loss: 0.0740 - acc: 0.9723 - val_loss: 0.0906 - val_acc: 0.9748
#
# Epoch 00220: val_loss did not improve from 0.09016
# Epoch 221/300
#  - 0s - loss: 0.0756 - acc: 0.9730 - val_loss: 0.0901 - val_acc: 0.9748
#
# Epoch 00221: val_loss improved from 0.09016 to 0.09015, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 222/300
#  - 0s - loss: 0.0774 - acc: 0.9704 - val_loss: 0.0899 - val_acc: 0.9727
#
# Epoch 00222: val_loss improved from 0.09015 to 0.08992, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 223/300
#  - 0s - loss: 0.0719 - acc: 0.9737 - val_loss: 0.0896 - val_acc: 0.9748
#
# Epoch 00223: val_loss improved from 0.08992 to 0.08963, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 224/300
#  - 0s - loss: 0.0774 - acc: 0.9740 - val_loss: 0.0903 - val_acc: 0.9748
#
# Epoch 00224: val_loss did not improve from 0.08963
# Epoch 225/300
#  - 0s - loss: 0.0778 - acc: 0.9690 - val_loss: 0.0903 - val_acc: 0.9748
#
# Epoch 00225: val_loss did not improve from 0.08963
# Epoch 226/300
#  - 0s - loss: 0.0750 - acc: 0.9725 - val_loss: 0.0907 - val_acc: 0.9748
#
# Epoch 00226: val_loss did not improve from 0.08963
# Epoch 227/300
#  - 0s - loss: 0.0730 - acc: 0.9763 - val_loss: 0.0915 - val_acc: 0.9727
#
# Epoch 00227: val_loss did not improve from 0.08963
# Epoch 228/300
#  - 0s - loss: 0.0719 - acc: 0.9751 - val_loss: 0.0903 - val_acc: 0.9748
#
# Epoch 00228: val_loss did not improve from 0.08963
# Epoch 229/300
#  - 0s - loss: 0.0762 - acc: 0.9718 - val_loss: 0.0897 - val_acc: 0.9748
#
# Epoch 00229: val_loss did not improve from 0.08963
# Epoch 230/300
#  - 0s - loss: 0.0712 - acc: 0.9728 - val_loss: 0.0904 - val_acc: 0.9727
#
# Epoch 00230: val_loss did not improve from 0.08963
# Epoch 231/300
#  - 0s - loss: 0.0742 - acc: 0.9718 - val_loss: 0.0900 - val_acc: 0.9748
#
# Epoch 00231: val_loss did not improve from 0.08963
# Epoch 232/300
#  - 0s - loss: 0.0729 - acc: 0.9728 - val_loss: 0.0900 - val_acc: 0.9727
#
# Epoch 00232: val_loss did not improve from 0.08963
# Epoch 233/300
#  - 0s - loss: 0.0711 - acc: 0.9721 - val_loss: 0.0891 - val_acc: 0.9748
#
# Epoch 00233: val_loss improved from 0.08963 to 0.08914, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 234/300
#  - 0s - loss: 0.0748 - acc: 0.9735 - val_loss: 0.0895 - val_acc: 0.9748
#
# Epoch 00234: val_loss did not improve from 0.08914
# Epoch 235/300
#  - 0s - loss: 0.0753 - acc: 0.9714 - val_loss: 0.0896 - val_acc: 0.9706
#
# Epoch 00235: val_loss did not improve from 0.08914
# Epoch 236/300
#  - 0s - loss: 0.0754 - acc: 0.9704 - val_loss: 0.0894 - val_acc: 0.9748
#
# Epoch 00236: val_loss did not improve from 0.08914
# Epoch 237/300
#  - 0s - loss: 0.0732 - acc: 0.9718 - val_loss: 0.0889 - val_acc: 0.9748
#
# Epoch 00237: val_loss improved from 0.08914 to 0.08890, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 238/300
#  - 0s - loss: 0.0692 - acc: 0.9730 - val_loss: 0.0896 - val_acc: 0.9748
#
# Epoch 00238: val_loss did not improve from 0.08890
# Epoch 239/300
#  - 0s - loss: 0.0767 - acc: 0.9725 - val_loss: 0.0889 - val_acc: 0.9748
#
# Epoch 00239: val_loss did not improve from 0.08890
# Epoch 240/300
#  - 0s - loss: 0.0744 - acc: 0.9718 - val_loss: 0.0894 - val_acc: 0.9727
#
# Epoch 00240: val_loss did not improve from 0.08890
# Epoch 241/300
#  - 0s - loss: 0.0759 - acc: 0.9716 - val_loss: 0.0886 - val_acc: 0.9727
#
# Epoch 00241: val_loss improved from 0.08890 to 0.08859, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 242/300
#  - 0s - loss: 0.0735 - acc: 0.9732 - val_loss: 0.0887 - val_acc: 0.9748
#
# Epoch 00242: val_loss did not improve from 0.08859
# Epoch 243/300
#  - 0s - loss: 0.0736 - acc: 0.9732 - val_loss: 0.0891 - val_acc: 0.9748
#
# Epoch 00243: val_loss did not improve from 0.08859
# Epoch 244/300
#  - 0s - loss: 0.0754 - acc: 0.9716 - val_loss: 0.0887 - val_acc: 0.9748
#
# Epoch 00244: val_loss did not improve from 0.08859
# Epoch 245/300
#  - 0s - loss: 0.0739 - acc: 0.9709 - val_loss: 0.0896 - val_acc: 0.9727
#
# Epoch 00245: val_loss did not improve from 0.08859
# Epoch 246/300
#  - 0s - loss: 0.0759 - acc: 0.9723 - val_loss: 0.0896 - val_acc: 0.9748
#
# Epoch 00246: val_loss did not improve from 0.08859
# Epoch 247/300
#  - 0s - loss: 0.0733 - acc: 0.9728 - val_loss: 0.0894 - val_acc: 0.9748
#
# Epoch 00247: val_loss did not improve from 0.08859
# Epoch 248/300
#  - 0s - loss: 0.0728 - acc: 0.9747 - val_loss: 0.0890 - val_acc: 0.9748
#
# Epoch 00248: val_loss did not improve from 0.08859
# Epoch 249/300
#  - 0s - loss: 0.0769 - acc: 0.9695 - val_loss: 0.0877 - val_acc: 0.9748
#
# Epoch 00249: val_loss improved from 0.08859 to 0.08774, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 250/300
#  - 0s - loss: 0.0670 - acc: 0.9756 - val_loss: 0.0877 - val_acc: 0.9748
#
# Epoch 00250: val_loss improved from 0.08774 to 0.08771, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 251/300
#  - 0s - loss: 0.0713 - acc: 0.9744 - val_loss: 0.0881 - val_acc: 0.9748
#
# Epoch 00251: val_loss did not improve from 0.08771
# Epoch 252/300
#  - 0s - loss: 0.0743 - acc: 0.9725 - val_loss: 0.0886 - val_acc: 0.9748
#
# Epoch 00252: val_loss did not improve from 0.08771
# Epoch 253/300
#  - 0s - loss: 0.0758 - acc: 0.9690 - val_loss: 0.0886 - val_acc: 0.9748
#
# Epoch 00253: val_loss did not improve from 0.08771
# Epoch 254/300
#  - 0s - loss: 0.0727 - acc: 0.9742 - val_loss: 0.0887 - val_acc: 0.9748
#
# Epoch 00254: val_loss did not improve from 0.08771
# Epoch 255/300
#  - 0s - loss: 0.0733 - acc: 0.9711 - val_loss: 0.0891 - val_acc: 0.9748
#
# Epoch 00255: val_loss did not improve from 0.08771
# Epoch 256/300
#  - 0s - loss: 0.0757 - acc: 0.9690 - val_loss: 0.0893 - val_acc: 0.9727
#
# Epoch 00256: val_loss did not improve from 0.08771
# Epoch 257/300
#  - 0s - loss: 0.0690 - acc: 0.9775 - val_loss: 0.0878 - val_acc: 0.9748
#
# Epoch 00257: val_loss did not improve from 0.08771
# Epoch 258/300
#  - 0s - loss: 0.0772 - acc: 0.9723 - val_loss: 0.0882 - val_acc: 0.9748
#
# Epoch 00258: val_loss did not improve from 0.08771
# Epoch 259/300
#  - 0s - loss: 0.0719 - acc: 0.9756 - val_loss: 0.0874 - val_acc: 0.9748
#
# Epoch 00259: val_loss improved from 0.08771 to 0.08742, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 260/300
#  - 0s - loss: 0.0735 - acc: 0.9725 - val_loss: 0.0877 - val_acc: 0.9748
#
# Epoch 00260: val_loss did not improve from 0.08742
# Epoch 261/300
#  - 0s - loss: 0.0746 - acc: 0.9740 - val_loss: 0.0872 - val_acc: 0.9748
#
# Epoch 00261: val_loss improved from 0.08742 to 0.08718, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 262/300
#  - 0s - loss: 0.0679 - acc: 0.9737 - val_loss: 0.0872 - val_acc: 0.9748
#
# Epoch 00262: val_loss did not improve from 0.08718
# Epoch 263/300
#  - 0s - loss: 0.0670 - acc: 0.9740 - val_loss: 0.0872 - val_acc: 0.9748
#
# Epoch 00263: val_loss improved from 0.08718 to 0.08717, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 264/300
#  - 0s - loss: 0.0717 - acc: 0.9732 - val_loss: 0.0868 - val_acc: 0.9748
#
# Epoch 00264: val_loss improved from 0.08717 to 0.08684, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 265/300
#  - 0s - loss: 0.0715 - acc: 0.9737 - val_loss: 0.0863 - val_acc: 0.9748
# Epoch 00265: val_loss improved from 0.08684 to 0.08631, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 266/300
#  - 0s - loss: 0.0713 - acc: 0.9749 - val_loss: 0.0865 - val_acc: 0.9748
#
# Epoch 00266: val_loss did not improve from 0.08631
# Epoch 267/300
#  - 0s - loss: 0.0715 - acc: 0.9728 - val_loss: 0.0870 - val_acc: 0.9748
#
# Epoch 00267: val_loss did not improve from 0.08631
# Epoch 268/300
#  - 0s - loss: 0.0713 - acc: 0.9740 - val_loss: 0.0866 - val_acc: 0.9748
#
# Epoch 00268: val_loss did not improve from 0.08631
# Epoch 269/300
#  - 0s - loss: 0.0698 - acc: 0.9751 - val_loss: 0.0866 - val_acc: 0.9748
#
# Epoch 00269: val_loss did not improve from 0.08631
# Epoch 270/300
#  - 0s - loss: 0.0741 - acc: 0.9706 - val_loss: 0.0875 - val_acc: 0.9748
#
# Epoch 00270: val_loss did not improve from 0.08631
# Epoch 271/300
#  - 0s - loss: 0.0713 - acc: 0.9735 - val_loss: 0.0867 - val_acc: 0.9748
#
# Epoch 00271: val_loss did not improve from 0.08631
# Epoch 272/300
#  - 0s - loss: 0.0687 - acc: 0.9742 - val_loss: 0.0871 - val_acc: 0.9748
#
# Epoch 00272: val_loss did not improve from 0.08631
# Epoch 273/300
#  - 0s - loss: 0.0683 - acc: 0.9751 - val_loss: 0.0866 - val_acc: 0.9748
#
# Epoch 00273: val_loss did not improve from 0.08631
# Epoch 274/300
#  - 0s - loss: 0.0673 - acc: 0.9751 - val_loss: 0.0861 - val_acc: 0.9748
#
# Epoch 00274: val_loss improved from 0.08631 to 0.08615, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 275/300
#  - 0s - loss: 0.0667 - acc: 0.9766 - val_loss: 0.0870 - val_acc: 0.9748
#
# Epoch 00275: val_loss did not improve from 0.08615
# Epoch 276/300
#  - 0s - loss: 0.0679 - acc: 0.9756 - val_loss: 0.0873 - val_acc: 0.9727
#
# Epoch 00276: val_loss did not improve from 0.08615
# Epoch 277/300
#  - 0s - loss: 0.0677 - acc: 0.9749 - val_loss: 0.0868 - val_acc: 0.9748
#
# Epoch 00277: val_loss did not improve from 0.08615
# Epoch 278/300
#  - 0s - loss: 0.0685 - acc: 0.9761 - val_loss: 0.0875 - val_acc: 0.9727
#
# Epoch 00278: val_loss did not improve from 0.08615
# Epoch 279/300
#  - 0s - loss: 0.0697 - acc: 0.9721 - val_loss: 0.0888 - val_acc: 0.9706
#
# Epoch 00279: val_loss did not improve from 0.08615
# Epoch 280/300
#  - 0s - loss: 0.0725 - acc: 0.9721 - val_loss: 0.0870 - val_acc: 0.9748
#
# Epoch 00280: val_loss did not improve from 0.08615
# Epoch 281/300
#  - 0s - loss: 0.0689 - acc: 0.9759 - val_loss: 0.0872 - val_acc: 0.9727
#
# Epoch 00281: val_loss did not improve from 0.08615
# Epoch 282/300
#  - 0s - loss: 0.0709 - acc: 0.9747 - val_loss: 0.0866 - val_acc: 0.9706
#
# Epoch 00282: val_loss did not improve from 0.08615
# Epoch 283/300
#  - 0s - loss: 0.0681 - acc: 0.9747 - val_loss: 0.0865 - val_acc: 0.9748
#
# Epoch 00283: val_loss did not improve from 0.08615
# Epoch 284/300
#  - 0s - loss: 0.0731 - acc: 0.9711 - val_loss: 0.0866 - val_acc: 0.9748
#
# Epoch 00284: val_loss did not improve from 0.08615
# Epoch 285/300
#  - 0s - loss: 0.0711 - acc: 0.9749 - val_loss: 0.0871 - val_acc: 0.9748
#
# Epoch 00285: val_loss did not improve from 0.08615
# Epoch 286/300
#  - 0s - loss: 0.0717 - acc: 0.9744 - val_loss: 0.0864 - val_acc: 0.9748
#
# Epoch 00286: val_loss did not improve from 0.08615
# Epoch 287/300
#  - 0s - loss: 0.0699 - acc: 0.9749 - val_loss: 0.0861 - val_acc: 0.9727
#
# Epoch 00287: val_loss improved from 0.08615 to 0.08605, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 288/300
#  - 0s - loss: 0.0700 - acc: 0.9732 - val_loss: 0.0861 - val_acc: 0.9748
#
# Epoch 00288: val_loss did not improve from 0.08605
# Epoch 289/300
#  - 0s - loss: 0.0720 - acc: 0.9744 - val_loss: 0.0860 - val_acc: 0.9748
#
# Epoch 00289: val_loss improved from 0.08605 to 0.08605, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 290/300
#  - 0s - loss: 0.0668 - acc: 0.9759 - val_loss: 0.0857 - val_acc: 0.9748
#
# Epoch 00290: val_loss improved from 0.08605 to 0.08566, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 291/300
#  - 0s - loss: 0.0675 - acc: 0.9773 - val_loss: 0.0851 - val_acc: 0.9748
#
# Epoch 00291: val_loss improved from 0.08566 to 0.08513, saving model to ./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5
# Epoch 292/300
#  - 0s - loss: 0.0723 - acc: 0.9737 - val_loss: 0.0859 - val_acc: 0.9748
#
# Epoch 00292: val_loss did not improve from 0.08513
# Epoch 293/300
#  - 0s - loss: 0.0681 - acc: 0.9747 - val_loss: 0.0856 - val_acc: 0.9727
#
# Epoch 00293: val_loss did not improve from 0.08513
# Epoch 294/300
#  - 0s - loss: 0.0672 - acc: 0.9737 - val_loss: 0.0866 - val_acc: 0.9727
#
# Epoch 00294: val_loss did not improve from 0.08513
# Epoch 295/300
#  - 0s - loss: 0.0723 - acc: 0.9716 - val_loss: 0.0869 - val_acc: 0.9727
#
# Epoch 00295: val_loss did not improve from 0.08513
# Epoch 296/300
#  - 0s - loss: 0.0661 - acc: 0.9751 - val_loss: 0.0860 - val_acc: 0.9727
#
# Epoch 00296: val_loss did not improve from 0.08513
# Epoch 297/300
#  - 0s - loss: 0.0651 - acc: 0.9785 - val_loss: 0.0859 - val_acc: 0.9727
#
# Epoch 00297: val_loss did not improve from 0.08513
# Epoch 298/300
#  - 0s - loss: 0.0724 - acc: 0.9721 - val_loss: 0.0861 - val_acc: 0.9727
#
# Epoch 00298: val_loss did not improve from 0.08513
# Epoch 299/300
#  - 0s - loss: 0.0681 - acc: 0.9747 - val_loss: 0.0868 - val_acc: 0.9748
#
# Epoch 00299: val_loss did not improve from 0.08513
# Epoch 300/300
#  - 0s - loss: 0.0666 - acc: 0.9749 - val_loss: 0.0864 - val_acc: 0.9748
#
# Epoch 00300: val_loss did not improve from 0.08513

# %%
# plot the top layer of the transfer model to a file and store it for further usage (only first time)
#plot_model(resNet_model, to_file='./saved_models/resNet_transfer_model_topLayer.png')

# %% [markdown]
# <a id='step11'></a>
# ## Step 11: Fine-tuned Transfer Learning ResNet CNN Model with Augmentation
#
# Now, we unfreeze the last res5c layer block of the formerly created transfer learning CNN model build architecture. There, the layer weights will be updated in each epoch as we pass the data batch. The training is implemented to use the augmentation concept with generators as before.

# %%
resNet_model = Model("Transfer", "Transfer_ResNet_CNN_Model", "accuracy")
resNet_ft_model_class = resNet_model.get_class()
input_shape = (224, 224, 3) # see info after tensor creation above
resNet_ft_model = resNet_ft_model_class.build_finetuned_model(input_shape=input_shape)
# Out:
# /usr/local/lib/python3.5/dist-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# --- Build model summary of fine-tuned RestNet Transfer_CNN_Model: ---
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 112, 112, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           activation_50[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_39 (MaxPooling2D) (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 56, 56, 64)   4160        max_pooling2d_39[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 56, 56, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_51[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 56, 56, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_52[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 56, 56, 256)  16640       max_pooling2d_39[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 56, 56, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 56, 56, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 56, 56, 256)  0           add_17[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 56, 56, 64)   16448       activation_53[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 56, 56, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_54[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 56, 56, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_55[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 56, 56, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 56, 56, 256)  0           add_18[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 56, 56, 64)   16448       activation_56[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 56, 56, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_57[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 56, 56, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_58[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 56, 56, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 56, 56, 256)  0           add_19[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 28, 28, 128)  32896       activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 28, 28, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_60[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 28, 28, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_61[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 28, 28, 512)  131584      activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 28, 28, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 28, 28, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 28, 28, 512)  0           add_20[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_62[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 28, 28, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_63[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 28, 28, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_64[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 28, 28, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_62[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 28, 28, 512)  0           add_21[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_65[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 28, 28, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_66[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 28, 28, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_67[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 28, 28, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_65[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 28, 28, 512)  0           add_22[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_68[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 28, 28, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_69[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 28, 28, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_70[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 28, 28, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_68[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 28, 28, 512)  0           add_23[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 14, 14, 256)  131328      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 14, 14, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_72[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 14, 14, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_73[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 14, 14, 1024) 525312      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 14, 14, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 14, 14, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 14, 14, 1024) 0           add_24[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_74[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 14, 14, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_75[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 14, 14, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_76[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 14, 14, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_74[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 14, 14, 1024) 0           add_25[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_77[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 14, 14, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_78[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 14, 14, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_79[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 14, 14, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_77[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 14, 14, 1024) 0           add_26[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_80[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 14, 14, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_81[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 14, 14, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_82[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 14, 14, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 14, 14, 1024) 0           add_27[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_83[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 14, 14, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_84[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 14, 14, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_85[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 14, 14, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 14, 14, 1024) 0           add_28[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_86[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 14, 14, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_87[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 14, 14, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_88[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 14, 14, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_86[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 14, 14, 1024) 0           add_29[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 7, 7, 512)    524800      activation_89[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 7, 7, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_90[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 7, 7, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_91[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 7, 7, 2048)   2099200     activation_89[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 7, 7, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 7, 7, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 7, 7, 2048)   0           add_30[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_92[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 7, 7, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_93[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 7, 7, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_94[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 7, 7, 2048)   0           bn5b_branch2c[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 7, 7, 2048)   0           add_31[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_95[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 7, 7, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_96[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 7, 7, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_97[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 7, 7, 2048)   0           bn5c_branch2c[0][0]
#                                                                  activation_95[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 7, 7, 2048)   0           add_32[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 2048)         0           activation_98[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 4,465,664
# Non-trainable params: 19,122,048
# __________________________________________________________________________________________________

# %%
# print the status        
layers = [(layer, layer.name, layer.trainable) for layer in resNet_ft_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
#                                                                    Layer Type  \
# 0    <keras.engine.input_layer.InputLayer object at 0x7f6a45011320>
# 1    <keras.layers.convolutional.ZeroPadding2D object at 0x7f6a6b6908d0>
# 2    <keras.layers.convolutional.Conv2D object at 0x7f6a6b34a6a0>
# 3    <keras.layers.normalization.BatchNormalization object at 0x7f6a6b37dcf8>
# 4    <keras.layers.core.Activation object at 0x7f6a6b31ec88>
# 5    <keras.layers.convolutional.ZeroPadding2D object at 0x7f6a6b3379e8>
# 6    <keras.layers.pooling.MaxPooling2D object at 0x7f6a6b3378d0>
# 7    <keras.layers.convolutional.Conv2D object at 0x7f6a6b2fb7f0>
# 8    <keras.layers.normalization.BatchNormalization object at 0x7f6a6b21e2b0>
# 9    <keras.layers.core.Activation object at 0x7f6a6b21e5c0>
# 10   <keras.layers.convolutional.Conv2D object at 0x7f6a6b2335c0>
# 11   <keras.layers.normalization.BatchNormalization object at 0x7f6a6b181470>
# 12   <keras.layers.core.Activation object at 0x7f6a6b181da0>
# 13   <keras.layers.convolutional.Conv2D object at 0x7f6a6b124400>
# 14   <keras.layers.convolutional.Conv2D object at 0x7f6a6b0f15c0>
# 15   <keras.layers.normalization.BatchNormalization object at 0x7f6a6b0f1630>
# 16   <keras.layers.normalization.BatchNormalization object at 0x7f6a6b029e48>
# 17   <keras.layers.merge.Add object at 0x7f6a46fdb1d0>
# 18   <keras.layers.core.Activation object at 0x7f6a46f00438>
# 19   <keras.layers.convolutional.Conv2D object at 0x7f6a46f005f8>
# 20   <keras.layers.normalization.BatchNormalization object at 0x7f6a46ec76a0>
# 21   <keras.layers.core.Activation object at 0x7f6a46eae748>
# 22   <keras.layers.convolutional.Conv2D object at 0x7f6a46e04c88>
# 23   <keras.layers.normalization.BatchNormalization object at 0x7f6a46e3b400>
# 24   <keras.layers.core.Activation object at 0x7f6a46dd0588>
# 25   <keras.layers.convolutional.Conv2D object at 0x7f6a46d73e48>
# 26   <keras.layers.normalization.BatchNormalization object at 0x7f6a46d255c0>
# 27   <keras.layers.merge.Add object at 0x7f6a46cc0748>
# 28   <keras.layers.core.Activation object at 0x7f6a46c49550>
# 29   <keras.layers.convolutional.Conv2D object at 0x7f6a46c159b0>
# ..                                                            ...
# 146  <keras.layers.convolutional.Conv2D object at 0x7f6a189916d8>
# 147  <keras.layers.normalization.BatchNormalization object at 0x7f6a189592b0>
# 148  <keras.layers.core.Activation object at 0x7f6a18976438>
# 149  <keras.layers.convolutional.Conv2D object at 0x7f6a18894e10>
# 150  <keras.layers.convolutional.Conv2D object at 0x7f6a188607b8>
# 151  <keras.layers.normalization.BatchNormalization object at 0x7f6a18846d30>
# 152  <keras.layers.normalization.BatchNormalization object at 0x7f6a187905f8>
# 153  <keras.layers.merge.Add object at 0x7f6a18750978>
# 154  <keras.layers.core.Activation object at 0x7f6a186af358>
# 155  <keras.layers.convolutional.Conv2D object at 0x7f6a186af518>
# 156  <keras.layers.normalization.BatchNormalization object at 0x7f6a186746d8>
# 157  <keras.layers.core.Activation object at 0x7f6a185d9f60>
# 158  <keras.layers.convolutional.Conv2D object at 0x7f6a185ae6d8>
# 159  <keras.layers.normalization.BatchNormalization object at 0x7f6a1857cac8>
# 160  <keras.layers.core.Activation object at 0x7f6a1857cc50>
# 161  <keras.layers.convolutional.Conv2D object at 0x7f6a1849d208>
# 162  <keras.layers.normalization.BatchNormalization object at 0x7f6a18469550>
# 163  <keras.layers.merge.Add object at 0x7f6a18469eb8>
# 164  <keras.layers.core.Activation object at 0x7f6a1838d550>
# 165  <keras.layers.convolutional.Conv2D object at 0x7f6a18355470>
# 166  <keras.layers.normalization.BatchNormalization object at 0x7f6a18372390>
# 167  <keras.layers.core.Activation object at 0x7f6a182da4e0>
# 168  <keras.layers.convolutional.Conv2D object at 0x7f6a1828d4e0>
# 169  <keras.layers.normalization.BatchNormalization object at 0x7f6a18258d68>
# 170  <keras.layers.core.Activation object at 0x7f6a18258dd8>
# 171  <keras.layers.convolutional.Conv2D object at 0x7f6a181f5470>
# 172  <keras.layers.normalization.BatchNormalization object at 0x7f6a181bc2b0>
# 173  <keras.layers.merge.Add object at 0x7f6a181bc048>
# 174  <keras.layers.core.Activation object at 0x7f6a180e3710>
# 175  <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f6a180e3fd0>
#
#                      Layer Name  Layer Trainable
# 0    input_3                     False
# 1    conv1_pad                   False
# 2    conv1                       False
# 3    bn_conv1                    False
# 4    activation_50               False
# 5    pool1_pad                   False
# 6    max_pooling2d_39            False
# 7    res2a_branch2a              False
# 8    bn2a_branch2a               False
# 9    activation_51               False
# 10   res2a_branch2b              False
# 11   bn2a_branch2b               False
# 12   activation_52               False
# 13   res2a_branch2c              False
# 14   res2a_branch1               False
# 15   bn2a_branch2c               False
# 16   bn2a_branch1                False
# 17   add_17                      False
# 18   activation_53               False
# 19   res2b_branch2a              False
# 20   bn2b_branch2a               False
# 21   activation_54               False
# 22   res2b_branch2b              False
# 23   bn2b_branch2b               False
# 24   activation_55               False
# 25   res2b_branch2c              False
# 26   bn2b_branch2c               False
# 27   add_18                      False
# 28   activation_56               False
# 29   res2c_branch2a              False
# ..              ...                ...
# 146  res5a_branch2b              False
# 147  bn5a_branch2b               False
# 148  activation_91               False
# 149  res5a_branch2c              False
# 150  res5a_branch1               False
# 151  bn5a_branch2c               False
# 152  bn5a_branch1                False
# 153  add_30                      False
# 154  activation_92               False
# 155  res5b_branch2a              False
# 156  bn5b_branch2a               False
# 157  activation_93               False
# 158  res5b_branch2b              False
# 159  bn5b_branch2b               False
# 160  activation_94               False
# 161  res5b_branch2c              False
# 162  bn5b_branch2c               False
# 163  add_31                      False
# 164  activation_95               False
# 165  res5c_branch2a              True
# 166  bn5c_branch2a               True
# 167  activation_96               True
# 168  res5c_branch2b              True
# 169  bn5c_branch2b               True
# 170  activation_97               True
# 171  res5c_branch2c              True
# 172  bn5c_branch2c               True
# 173  add_32                      True
# 174  activation_98               True
# 175  global_average_pooling2d_9  True
#
# [176 rows x 3 columns]

# %% [markdown]
# ### Compile and Train the Model

# %%
resNet_ft_model_class.build_ResNet_aug_model(resNet_ft_model)
resNet_ft_model = resNet_ft_model_class.get_model()
resNet_ft_model_class.set_Adam_params(lr=1e-4)
resNet_ft_model_class.compile_model(model= resNet_ft_model, loss='binary_crossentropy',
                                 optimizer='Adam', metrics=['accuracy'])
# Out:
# --- Build model summary of augmented RestNet Transfer_CNN_Model: ---
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_2 (Model)              (None, 2048)              23587712
# _________________________________________________________________
# input_4 (InputLayer)         (None, 2048)              0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2048)              8192
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 4098
# =================================================================
# Total params: 23,600,002
# Trainable params: 4,473,858
# Non-trainable params: 19,126,144
# _________________________________________________________________

# %%
epochs = 15  # very slow training, because of experience with original dataset changed from 20 to 15
batch_size = 32
# generator and generator flow data, training and validation data are the same as before;
# because of augmentation concept, bottleneck features are not used

resNet_finetuned_model_aug_history = resNet_ft_model_class.augmentation_train_model(model=resNet_ft_model,
               filepath='./saved_models/transfer_ResNet50_finetuned_model_weights.best.withAugmentation.hdf5', 
                                training_data=training_data, validation_data=validation_data,
                                epochs=epochs, batch_size=batch_size,
                                train_tensors=train_tensors,
                                valid_tensors=valid_tensors)
# Out:
# Epoch 1/15
#  - 2116s - loss: 0.2814 - acc: 0.9051 - val_loss: 0.5557 - val_acc: 0.7725
#
# Epoch 00001: val_loss improved from inf to 0.55575, saving model to ./saved_models/transfer_ResNet50_finetuned_model_weights.best.withAugmentation.hdf5
# Epoch 2/15
#  - 2107s - loss: 0.1636 - acc: 0.9545 - val_loss: 0.6890 - val_acc: 0.7545
#
# Epoch 00002: val_loss did not improve from 0.55575
# Epoch 3/15
#  - 2110s - loss: 0.1261 - acc: 0.9635 - val_loss: 0.5359 - val_acc: 0.7703
#
# Epoch 00003: val_loss improved from 0.55575 to 0.53587, saving model to ./saved_models/transfer_ResNet50_finetuned_model_weights.best.withAugmentation.hdf5
# Epoch 4/15
#  - 2109s - loss: 0.1032 - acc: 0.9690 - val_loss: 0.5462 - val_acc: 0.7703
#
# Epoch 00004: val_loss did not improve from 0.53587
# Epoch 5/15
#  - 2108s - loss: 0.1030 - acc: 0.9697 - val_loss: 0.5687 - val_acc: 0.7635
#
# Epoch 00005: val_loss did not improve from 0.53587
# Epoch 6/15
#  - 2109s - loss: 0.0850 - acc: 0.9718 - val_loss: 0.5749 - val_acc: 0.7455
#
# Epoch 00006: val_loss did not improve from 0.53587
# Epoch 7/15
#  - 2109s - loss: 0.0864 - acc: 0.9711 - val_loss: 0.5333 - val_acc: 0.7838
#
# Epoch 00007: val_loss improved from 0.53587 to 0.53326, saving model to ./saved_models/transfer_ResNet50_finetuned_model_weights.best.withAugmentation.hdf5
# Epoch 8/15
#  - 2113s - loss: 0.0739 - acc: 0.9759 - val_loss: 0.5704 - val_acc: 0.7725
#
# Epoch 00008: val_loss did not improve from 0.53326
# Epoch 9/15
#  - 2112s - loss: 0.0731 - acc: 0.9761 - val_loss: 0.5504 - val_acc: 0.7612
#
# Epoch 00009: val_loss did not improve from 0.53326
# Epoch 10/15
#  - 2114s - loss: 0.0616 - acc: 0.9796 - val_loss: 0.5748 - val_acc: 0.7703
#
# Epoch 00010: val_loss did not improve from 0.53326
# Epoch 11/15
#  - 2101s - loss: 0.0658 - acc: 0.9775 - val_loss: 0.5450 - val_acc: 0.7635
#
# Epoch 00011: val_loss did not improve from 0.53326
# Epoch 12/15
#  - 2105s - loss: 0.0449 - acc: 0.9856 - val_loss: 0.5329 - val_acc: 0.7860
#
# Epoch 00012: val_loss improved from 0.53326 to 0.53287, saving model to ./saved_models/transfer_ResNet50_finetuned_model_weights.best.withAugmentation.hdf5
# Epoch 13/15
#  - 2103s - loss: 0.0540 - acc: 0.9822 - val_loss: 0.5902 - val_acc: 0.7432
#
# Epoch 00013: val_loss did not improve from 0.53287
# Epoch 14/15
#  - 2097s - loss: 0.0570 - acc: 0.9789 - val_loss: 0.5701 - val_acc: 0.7770
#
# Epoch 00014: val_loss did not improve from 0.53287
# Epoch 15/15
#  - 2113s - loss: 0.0411 - acc: 0.9853 - val_loss: 0.6014 - val_acc: 0.7635
#
# Epoch 00015: val_loss did not improve from 0.53287

# %% [markdown]
# **Note:**<br>
# As we can see already now, there is no classification performance improvement by using a fine-tuned model architecture.

# %% [markdown]
# <a id='step12'></a>
# ## Step 12: Create an InceptionV3 CNN Model with Transfer Learning
#
# Keras InceptionV3 model is one of the models to classify images. It has already been trained on the huge image database ImageNet, therefore optimized filter weights ('bottleneck features') are available for input usage of a top model layer. The concept of the inception module focuses on the kernel size of convolutional layers  as e.g. described in the paper ['Going deeper with convolutions'](https://arxiv.org/pdf/1409.4842.pdf).
#
# This concept is much better according test accuracy compared with the results of the creation of a model architecture from the scratch as at the beginning of this project. There for the basic model no pre-trained information is available.<br>
# For this project, the transfer learning concept has been chosen too on an InceptionV3 CNN instance as basic architecture together with its bottleneck features. As a top model construction a flatten GlobalAveragePooling2D layer, followed by a BatchNormalization instance and the fully connected Dense layer, which handles the 2 different chest categories.

# %% [markdown]
# ### Model Implementation and Compilation
#
# Again, we create a pre-trained InceptionV3 CNN model and freeze the convolution blocks, so that we can use it as an image feature extractor to get the bottleneck features.

# %%
inception_model = Model("Transfer", "Transfer_InceptionV3_CNN_Model", "accuracy")
inception_model_class = inception_model.get_class()
input_shape = (224, 224, 3) # see info after tensor creation above
inception_model_class.build_model_feature_extractor(input_shape=input_shape)
# Out:
# --- Build model summary of InceptionV3 Transfer_CNN_Model as feature extractor: ---
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 111, 111, 32) 864         input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 111, 111, 32) 96          conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 111, 111, 32) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 109, 109, 32) 9216        activation_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 109, 109, 32) 96          conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 109, 109, 32) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 109, 109, 64) 18432       activation_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 109, 109, 64) 192         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 109, 109, 64) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_40 (MaxPooling2D) (None, 54, 54, 64)   0           activation_101[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 54, 54, 80)   5120        max_pooling2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 54, 54, 80)   240         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 54, 54, 80)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 52, 52, 192)  138240      activation_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 52, 52, 192)  576         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 52, 52, 192)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_41 (MaxPooling2D) (None, 25, 25, 192)  0           activation_103[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 25, 25, 64)   12288       max_pooling2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 25, 25, 64)   192         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 25, 25, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 25, 25, 48)   9216        max_pooling2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 25, 25, 96)   55296       activation_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 25, 25, 48)   144         conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 25, 25, 96)   288         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 25, 25, 48)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 25, 25, 96)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 25, 25, 192)  0           max_pooling2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 25, 25, 64)   12288       max_pooling2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 25, 25, 64)   76800       activation_105[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 25, 25, 96)   82944       activation_108[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 25, 25, 32)   6144        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 25, 25, 64)   192         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 25, 25, 64)   192         conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 25, 25, 96)   288         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 25, 25, 32)   96          conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 25, 25, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 25, 25, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 25, 25, 96)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 25, 25, 32)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 25, 25, 256)  0           activation_104[0][0]
#                                                                  activation_106[0][0]
#                                                                  activation_109[0][0]
#                                                                  activation_110[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 25, 25, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 25, 25, 64)   192         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 25, 25, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 25, 25, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 25, 25, 96)   55296       activation_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 25, 25, 48)   144         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 25, 25, 96)   288         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 25, 25, 48)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 25, 25, 96)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 25, 25, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 25, 25, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 25, 25, 64)   76800       activation_112[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 25, 25, 96)   82944       activation_115[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 25, 25, 64)   16384       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 25, 25, 64)   192         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 25, 25, 64)   192         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 25, 25, 96)   288         conv2d_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 25, 25, 64)   192         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 25, 25, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 25, 25, 64)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 25, 25, 96)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 25, 25, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 25, 25, 288)  0           activation_111[0][0]
#                                                                  activation_113[0][0]
#                                                                  activation_116[0][0]
#                                                                  activation_117[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 25, 25, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 25, 25, 64)   192         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 25, 25, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 25, 25, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 25, 25, 96)   55296       activation_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 25, 25, 48)   144         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 25, 25, 96)   288         conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 25, 25, 48)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 25, 25, 96)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 25, 25, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 25, 25, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 25, 25, 64)   76800       activation_119[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 25, 25, 96)   82944       activation_122[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 25, 25, 64)   18432       average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 25, 25, 64)   192         conv2d_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 25, 25, 64)   192         conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 25, 25, 96)   288         conv2d_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 25, 25, 64)   192         conv2d_73[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 25, 25, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 25, 25, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 25, 25, 96)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 25, 25, 64)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 25, 25, 288)  0           activation_118[0][0]
#                                                                  activation_120[0][0]
#                                                                  activation_123[0][0]
#                                                                  activation_124[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 25, 25, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 25, 25, 64)   192         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 25, 25, 64)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 25, 25, 96)   55296       activation_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 25, 25, 96)   288         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 25, 25, 96)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 12, 12, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 12, 12, 96)   82944       activation_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 12, 12, 384)  1152        conv2d_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 12, 12, 96)   288         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 12, 12, 384)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 12, 12, 96)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_42 (MaxPooling2D) (None, 12, 12, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 12, 12, 768)  0           activation_125[0][0]
#                                                                  activation_128[0][0]
#                                                                  max_pooling2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 12, 12, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 12, 12, 128)  384         conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 12, 12, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 12, 12, 128)  114688      activation_133[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 12, 12, 128)  384         conv2d_83[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 12, 12, 128)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 12, 12, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 12, 12, 128)  114688      activation_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 12, 12, 128)  384         conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 12, 12, 128)  384         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 12, 12, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 12, 12, 128)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 12, 12, 128)  114688      activation_130[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 12, 12, 128)  114688      activation_135[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 12, 12, 128)  384         conv2d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 12, 12, 128)  384         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 12, 12, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 12, 12, 128)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 12, 12, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 12, 12, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 12, 12, 192)  172032      activation_131[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 12, 12, 192)  172032      activation_136[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 12, 12, 192)  576         conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 12, 12, 192)  576         conv2d_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 12, 12, 192)  576         conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 12, 12, 192)  576         conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 12, 12, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 12, 12, 192)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, 12, 12, 192)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 12, 12, 192)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 12, 12, 768)  0           activation_129[0][0]
#                                                                  activation_132[0][0]
#                                                                  activation_137[0][0]
#                                                                  activation_138[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 12, 12, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 12, 12, 160)  480         conv2d_92[0][0]
# __________________________________________________________________________________________________
# activation_143 (Activation)     (None, 12, 12, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 12, 12, 160)  179200      activation_143[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 12, 12, 160)  480         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 12, 12, 160)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 12, 12, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 12, 12, 160)  179200      activation_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 12, 12, 160)  480         conv2d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 12, 12, 160)  480         conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, 12, 12, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 12, 12, 160)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 12, 12, 160)  179200      activation_140[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 12, 12, 160)  179200      activation_145[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 12, 12, 160)  480         conv2d_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 12, 12, 160)  480         conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, 12, 12, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, 12, 12, 160)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 12, 12, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 12, 12, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 12, 12, 192)  215040      activation_141[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 12, 12, 192)  215040      activation_146[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 12, 12, 192)  576         conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 12, 12, 192)  576         conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 12, 12, 192)  576         conv2d_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 12, 12, 192)  576         conv2d_97[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, 12, 12, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 12, 12, 192)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, 12, 12, 192)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 12, 12, 192)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 12, 12, 768)  0           activation_139[0][0]
#                                                                  activation_142[0][0]
#                                                                  activation_147[0][0]
#                                                                  activation_148[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 12, 12, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 12, 12, 160)  480         conv2d_102[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, 12, 12, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 12, 12, 160)  179200      activation_153[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 12, 12, 160)  480         conv2d_103[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, 12, 12, 160)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 12, 12, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 12, 12, 160)  179200      activation_154[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 12, 12, 160)  480         conv2d_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 12, 12, 160)  480         conv2d_104[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, 12, 12, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, 12, 12, 160)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 12, 12, 160)  179200      activation_150[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 12, 12, 160)  179200      activation_155[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 12, 12, 160)  480         conv2d_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 12, 12, 160)  480         conv2d_105[0][0]
# __________________________________________________________________________________________________
# activation_151 (Activation)     (None, 12, 12, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, 12, 12, 160)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 12, 12, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 12, 12, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 12, 12, 192)  215040      activation_151[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 12, 12, 192)  215040      activation_156[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 12, 12, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 12, 12, 192)  576         conv2d_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 12, 12, 192)  576         conv2d_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 12, 12, 192)  576         conv2d_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 12, 12, 192)  576         conv2d_107[0][0]
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, 12, 12, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, 12, 12, 192)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, 12, 12, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 12, 12, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 12, 12, 768)  0           activation_149[0][0]
#                                                                  activation_152[0][0]
#                                                                  activation_157[0][0]
#                                                                  activation_158[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 12, 12, 192)  576         conv2d_112[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 12, 12, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 12, 12, 192)  258048      activation_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 12, 12, 192)  576         conv2d_113[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 12, 12, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 12, 12, 192)  258048      activation_164[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 12, 12, 192)  576         conv2d_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 12, 12, 192)  576         conv2d_114[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, 12, 12, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 12, 12, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 12, 12, 192)  258048      activation_160[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 12, 12, 192)  258048      activation_165[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 12, 12, 192)  576         conv2d_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 12, 12, 192)  576         conv2d_115[0][0]
# __________________________________________________________________________________________________
# activation_161 (Activation)     (None, 12, 12, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 12, 12, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 12, 12, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 12, 12, 192)  258048      activation_161[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 12, 12, 192)  258048      activation_166[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 12, 12, 192)  147456      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 12, 12, 192)  576         conv2d_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 12, 12, 192)  576         conv2d_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 12, 12, 192)  576         conv2d_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 12, 12, 192)  576         conv2d_117[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, 12, 12, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_162 (Activation)     (None, 12, 12, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# activation_167 (Activation)     (None, 12, 12, 192)  0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_168 (Activation)     (None, 12, 12, 192)  0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 12, 12, 768)  0           activation_159[0][0]
#                                                                  activation_162[0][0]
#                                                                  activation_167[0][0]
#                                                                  activation_168[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_169 (Activation)     (None, 12, 12, 192)  0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# activation_173 (Activation)     (None, 12, 12, 192)  0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 5, 5, 320)    552960      activation_169[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 5, 5, 192)    331776      activation_173[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 5, 5, 320)    960         conv2d_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 5, 5, 192)    576         conv2d_123[0][0]
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, 5, 5, 320)    0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 5, 5, 192)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_43 (MaxPooling2D) (None, 5, 5, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 5, 5, 1280)   0           activation_170[0][0]
#                                                                  activation_174[0][0]
#                                                                  max_pooling2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 5, 5, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 5, 5, 448)    1344        conv2d_128[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 5, 5, 448)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 5, 5, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 5, 5, 384)    1548288     activation_179[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 5, 5, 384)    1152        conv2d_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 5, 5, 384)    1152        conv2d_129[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 5, 5, 384)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 5, 5, 384)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 5, 5, 384)    442368      activation_176[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 5, 5, 384)    442368      activation_176[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 5, 5, 384)    442368      activation_180[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 5, 5, 384)    442368      activation_180[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 5, 5, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 5, 5, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 5, 5, 384)    1152        conv2d_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 5, 5, 384)    1152        conv2d_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 5, 5, 384)    1152        conv2d_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 5, 5, 384)    1152        conv2d_131[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 5, 5, 192)    245760      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 5, 5, 320)    960         conv2d_124[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 5, 5, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 5, 5, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 5, 5, 384)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 5, 5, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 5, 5, 192)    576         conv2d_132[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 5, 5, 320)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 5, 5, 768)    0           activation_177[0][0]
#                                                                  activation_178[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 5, 5, 768)    0           activation_181[0][0]
#                                                                  activation_182[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 5, 5, 192)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 5, 5, 2048)   0           activation_175[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_183[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 5, 5, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 5, 5, 448)    1344        conv2d_137[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 5, 5, 448)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 5, 5, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 5, 5, 384)    1548288     activation_188[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 5, 5, 384)    1152        conv2d_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 5, 5, 384)    1152        conv2d_138[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 5, 5, 384)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 5, 5, 384)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 5, 5, 384)    442368      activation_185[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 5, 5, 384)    442368      activation_185[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 5, 5, 384)    442368      activation_189[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 5, 5, 384)    442368      activation_189[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 5, 5, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 5, 5, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 5, 5, 384)    1152        conv2d_135[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 5, 5, 384)    1152        conv2d_136[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 5, 5, 384)    1152        conv2d_139[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 5, 5, 384)    1152        conv2d_140[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 5, 5, 192)    393216      average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 5, 5, 320)    960         conv2d_133[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 5, 5, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 5, 5, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 5, 5, 384)    0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 5, 5, 384)    0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 5, 5, 192)    576         conv2d_141[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 5, 5, 320)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 5, 5, 768)    0           activation_186[0][0]
#                                                                  activation_187[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 5, 5, 768)    0           activation_190[0][0]
#                                                                  activation_191[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 5, 5, 192)    0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 5, 5, 2048)   0           activation_184[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  activation_192[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_10 (Gl (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
# plot the transfer model to a file and store it for further usage
inception_model = inception_model_class.get_model()

# plotting the model only first time
#plot_model(inception_model, to_file='./saved_models/inception_transfer_model_withoutTopLayer.png')

# %%
# print the status
pd.set_option('max_colwidth', -1)
layers = [(layer, layer.name, layer.trainable) for layer in inception_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
#                                                                    Layer Type  \
# 0    <keras.engine.input_layer.InputLayer object at 0x7f6a13a83c18>
# 1    <keras.layers.convolutional.Conv2D object at 0x7f6a10f66d30>
# 2    <keras.layers.normalization.BatchNormalization object at 0x7f6a10ee4400>
# 3    <keras.layers.core.Activation object at 0x7f6a10ee43c8>
# 4    <keras.layers.convolutional.Conv2D object at 0x7f6a10ef8978>
# 5    <keras.layers.normalization.BatchNormalization object at 0x7f6a10e42da0>
# 6    <keras.layers.core.Activation object at 0x7f6a10dc7d30>
# 7    <keras.layers.convolutional.Conv2D object at 0x7f6a10d83be0>
# 8    <keras.layers.normalization.BatchNormalization object at 0x7f6a10db37b8>
# 9    <keras.layers.core.Activation object at 0x7f6a10db35f8>
# 10   <keras.layers.pooling.MaxPooling2D object at 0x7f6a10cd47f0>
# 11   <keras.layers.convolutional.Conv2D object at 0x7f6a10d37ba8>
# 12   <keras.layers.normalization.BatchNormalization object at 0x7f6a10c28828>
# 13   <keras.layers.core.Activation object at 0x7f6a10c28978>
# 14   <keras.layers.convolutional.Conv2D object at 0x7f6a10bc7668>
# 15   <keras.layers.normalization.BatchNormalization object at 0x7f6a10b956d8>
# 16   <keras.layers.core.Activation object at 0x7f6a10b95a20>
# 17   <keras.layers.pooling.MaxPooling2D object at 0x7f6a10b1e668>
# 18   <keras.layers.convolutional.Conv2D object at 0x7f6a10866780>
# 19   <keras.layers.normalization.BatchNormalization object at 0x7f6a10834080>
# 20   <keras.layers.core.Activation object at 0x7f6a10795f98>
# 21   <keras.layers.convolutional.Conv2D object at 0x7f6a10a0a4a8>
# 22   <keras.layers.convolutional.Conv2D object at 0x7f6a107409e8>
# 23   <keras.layers.normalization.BatchNormalization object at 0x7f6a109d0c88>
# 24   <keras.layers.normalization.BatchNormalization object at 0x7f6a106f0278>
# 25   <keras.layers.core.Activation object at 0x7f6a109579e8>
# 26   <keras.layers.core.Activation object at 0x7f6a10724c50>
# 27   <keras.layers.pooling.AveragePooling2D object at 0x7f6a1059c908>
# 28   <keras.layers.convolutional.Conv2D object at 0x7f6a10b1e320>
# 29   <keras.layers.convolutional.Conv2D object at 0x7f6a10913320>
# ..                                                            ...
# 282  <keras.layers.core.Activation object at 0x7f69ffddc2e8>
# 283  <keras.layers.convolutional.Conv2D object at 0x7f6a040d3828>
# 284  <keras.layers.convolutional.Conv2D object at 0x7f69ffd7e5f8>
# 285  <keras.layers.normalization.BatchNormalization object at 0x7f6a040a0400>
# 286  <keras.layers.normalization.BatchNormalization object at 0x7f69ffcd1fd0>
# 287  <keras.layers.core.Activation object at 0x7f6a040a0240>
# 288  <keras.layers.core.Activation object at 0x7f69ffcd1630>
# 289  <keras.layers.convolutional.Conv2D object at 0x7f6a04023b00>
# 290  <keras.layers.convolutional.Conv2D object at 0x7f69fff1d518>
# 291  <keras.layers.convolutional.Conv2D object at 0x7f69ffc5c5c0>
# 292  <keras.layers.convolutional.Conv2D object at 0x7f69ffb66d30>
# 293  <keras.layers.pooling.AveragePooling2D object at 0x7f69ffa9b9e8>
# 294  <keras.layers.convolutional.Conv2D object at 0x7f6a0415af98>
# 295  <keras.layers.normalization.BatchNormalization object at 0x7f69fffbcc50>
# 296  <keras.layers.normalization.BatchNormalization object at 0x7f69ffeb77f0>
# 297  <keras.layers.normalization.BatchNormalization object at 0x7f69ffbc1c50>
# 298  <keras.layers.normalization.BatchNormalization object at 0x7f69ffb15908>
# 299  <keras.layers.convolutional.Conv2D object at 0x7f69ffa55a58>
# 300  <keras.layers.normalization.BatchNormalization object at 0x7f6a041b29b0>
# 301  <keras.layers.core.Activation object at 0x7f6a0439e438>
# 302  <keras.layers.core.Activation object at 0x7f69ffeeaef0>
# 303  <keras.layers.core.Activation object at 0x7f69ffbc13c8>
# 304  <keras.layers.core.Activation object at 0x7f69ffb15c50>
# 305  <keras.layers.normalization.BatchNormalization object at 0x7f69ff9eb9e8>
# 306  <keras.layers.core.Activation object at 0x7f6a04135be0>
# 307  <keras.layers.merge.Concatenate object at 0x7f69ffe0f908>
# 308  <keras.layers.merge.Concatenate object at 0x7f69ffaba828>
# 309  <keras.layers.core.Activation object at 0x7f69ff98e898>
# 310  <keras.layers.merge.Concatenate object at 0x7f69ff9ac780>
# 311  <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f69ff9ac668>
#
#                       Layer Name  Layer Trainable
# 0    input_5                      False
# 1    conv2d_48                    False
# 2    batch_normalization_3        False
# 3    activation_99                False
# 4    conv2d_49                    False
# 5    batch_normalization_4        False
# 6    activation_100               False
# 7    conv2d_50                    False
# 8    batch_normalization_5        False
# 9    activation_101               False
# 10   max_pooling2d_40             False
# 11   conv2d_51                    False
# 12   batch_normalization_6        False
# 13   activation_102               False
# 14   conv2d_52                    False
# 15   batch_normalization_7        False
# 16   activation_103               False
# 17   max_pooling2d_41             False
# 18   conv2d_56                    False
# 19   batch_normalization_11       False
# 20   activation_107               False
# 21   conv2d_54                    False
# 22   conv2d_57                    False
# 23   batch_normalization_9        False
# 24   batch_normalization_12       False
# 25   activation_105               False
# 26   activation_108               False
# 27   average_pooling2d_1          False
# 28   conv2d_53                    False
# 29   conv2d_55                    False
# ..         ...                      ...
# 282  activation_188               False
# 283  conv2d_134                   False
# 284  conv2d_138                   False
# 285  batch_normalization_89       False
# 286  batch_normalization_93       False
# 287  activation_185               False
# 288  activation_189               False
# 289  conv2d_135                   False
# 290  conv2d_136                   False
# 291  conv2d_139                   False
# 292  conv2d_140                   False
# 293  average_pooling2d_9          False
# 294  conv2d_133                   False
# 295  batch_normalization_90       False
# 296  batch_normalization_91       False
# 297  batch_normalization_94       False
# 298  batch_normalization_95       False
# 299  conv2d_141                   False
# 300  batch_normalization_88       False
# 301  activation_186               False
# 302  activation_187               False
# 303  activation_190               False
# 304  activation_191               False
# 305  batch_normalization_96       False
# 306  activation_184               False
# 307  mixed9_1                     False
# 308  concatenate_2                False
# 309  activation_192               False
# 310  mixed10                      False
# 311  global_average_pooling2d_10  False
#
# [312 rows x 3 columns]

# %%
# bottleneck feature function is already defined above
print('--- Create bottleneck features for train tensors images ---')
train_inception = get_bottleneck_features(inception_model, train_tensors)
print('--- Create bottleneck features for validation tensors images ---')
valid_inception = get_bottleneck_features(inception_model, valid_tensors)
print('--- Create bottleneck features for test tensors images ---')
test_inception = get_bottleneck_features(inception_model, test_tensors)
# Out:
# --- Create bottleneck features for train tensors images ---
# --- Create bottleneck features for validation tensors images ---
# --- Create bottleneck features for test tensors images ---

# %%
# store the bottleneck files
np.savez('./bottleneck_features/chest_InceptionV3_features.npz',
         train=train_inception, valid=valid_inception, test=test_inception)

# %%
# test about files, dont' forget to close the file instance
npzfile = np.load('./bottleneck_features/chest_InceptionV3_features.npz')
npzfile.files
# Out:
# ['test', 'valid', 'train']

# %%
print('InceptionV3 train bottleneck features: {}'.format(train_inception.shape))
print('InceptionV3 validation bottleneck features: {}'.format(valid_inception.shape))
print('InceptionV3 test bottleneck features: {}'.format(test_inception.shape))
# Out:
# InceptionV3 train bottleneck features: (4224, 2048)
# InceptionV3 validation bottleneck features: (476, 2048)
# InceptionV3 test bottleneck features: (1157, 2048)

# %%
npzfile['valid']
# Out:
# array([[0.04149254, 0.02143389, 0.07014471, ..., 0.72523445, 0.00815512,
#         0.6475021 ],
#        [0.60490245, 0.19177254, 0.07130157, ..., 1.4047043 , 0.00752642,
#         1.4182472 ],
#        [0.28629407, 0.12939903, 0.1722032 , ..., 1.4242824 , 0.01743034,
#         1.5057127 ],
#        ...,
#        [0.18016848, 0.31614107, 0.252179  , ..., 0.3488479 , 0.18888097,
#         1.1440028 ],
#        [0.12893488, 0.06343155, 0.00950074, ..., 0.12461788, 0.07241744,
#         0.9016065 ],
#        [0.9970694 , 0.09112889, 0.03029995, ..., 1.2414454 , 0.16149639,
#         2.1375    ]], dtype=float32)

# %%
npzfile.close()

# %%
#
# if the bottleneck feature file is already stored and this python project runs again ... 
# use this lines of code to get the bottleneck features for the train, valid and test samples
#
bottleneck_features = np.load('./bottleneck_features/chest_InceptionV3_features.npz')
train_inception = bottleneck_features['train']
valid_inception = bottleneck_features['valid']
test_inception = bottleneck_features['test']
bottleneck_features.close()

# %%
# build the final CNN architecture with added top layer part
inception_model_class.build_model(inception_model)
inception_model = inception_model_class.get_model()
# Out:
# --- Build model summary of final RestNet Transfer_CNN_Model with top layer: ---
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_97 (Batc (None, 2048)              8192
# _________________________________________________________________
# dense_10 (Dense)             (None, 2)                 4098
# =================================================================
# Total params: 12,290
# Trainable params: 8,194
# Non-trainable params: 4,096
# _________________________________________________________________

# %%
# let's train the final transfer learning model using Adam with decay 1e-6 for each learning update and 
# a smaller learning rate than before to avoid to get stuck in a local minimum and to reduce overfitting;
inception_model_class.set_Adam_params(lr=1e-4)
inception_model_class.compile_model(model= inception_model, loss='binary_crossentropy',
                                 optimizer='Adam', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
epochs = 300  # fast training compared the previous ones
batch_size = 32
inception_model = inception_model_class.get_model()
inception_transfer_model_history = inception_model_class.train_model(model=inception_model,
                               filepath='./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5',
                                           train_tensors=train_inception, train_targets=train_targets,
                                           valid_tensors=valid_inception, valid_targets=valid_targets,
                                           epochs=epochs, batch_size=batch_size)
# Out:
# Train on 4224 samples, validate on 476 samples
# Epoch 1/300
#  - 7s - loss: 0.5375 - acc: 0.7386 - val_loss: 0.3325 - val_acc: 0.8697
#
# Epoch 00001: val_loss improved from inf to 0.33250, saving model to ./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5
# Epoch 2/300
#  - 0s - loss: 0.2692 - acc: 0.8949 - val_loss: 0.2447 - val_acc: 0.9034
#
# Epoch 00002: val_loss improved from 0.33250 to 0.24468, saving model to ./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5
# Epoch 3/300
#  - 0s - loss: 0.2007 - acc: 0.9259 - val_loss: 0.1982 - val_acc: 0.9202
#
# Epoch 00003: val_loss improved from 0.24468 to 0.19820, saving model to ./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5
# Epoch 4/300
#  - 0s - loss: 0.1717 - acc: 0.9387 - val_loss: 0.1789 - val_acc: 0.9307
#
# Epoch 00004: val_loss improved from 0.19820 to 0.17893, saving model to ./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5
# Epoch 5/300
#  - 0s - loss: 0.1482 - acc: 0.9493 - val_loss: 0.1661 - val_acc: 0.9370
#
# Epoch 00005: val_loss improved from 0.17893 to 0.16608, saving model to ./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5
# Epoch 6/300
#  - 0s - loss: 0.1391 - acc: 0.9515 - val_loss: 0.1579 - val_acc: 0.9328
#
# Epoch 00006: val_loss improved from 0.16608 to 0.15791, saving model to ./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5
# Epoch 7/300
#  - 0s - loss: 0.1288 - acc: 0.9527 - val_loss: 0.1515 - val_acc: 0.9307
#
# Epoch 00007: val_loss improved from 0.15791 to 0.15150, saving model to ./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5
# Epoch 8/300
#  - 0s - loss: 0.1169 - acc: 0.9602 - val_loss: 0.1467 - val_acc: 0.9370
#
# Epoch 00008: val_loss improved from 0.15150 to 0.14670, saving model to ./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5
# Epoch 9/300
#  - 0s - loss: 0.1119 - acc: 0.9612 - val_loss: 0.1476 - val_acc: 0.9307
#
# Epoch 00009: val_loss did not improve from 0.14670
# Epoch 10/300
#  - 0s - loss: 0.1059 - acc: 0.9602 - val_loss: 0.1444 - val_acc: 0.9349
#
# Epoch 00010: val_loss improved from 0.14670 to 0.14439, saving model to ./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5
# Epoch 11/300
#  - 0s - loss: 0.1040 - acc: 0.9612 - val_loss: 0.1430 - val_acc: 0.9349
#
# Epoch 00011: val_loss improved from 0.14439 to 0.14300, saving model to ./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5
# Epoch 12/300
#  - 0s - loss: 0.0969 - acc: 0.9666 - val_loss: 0.1427 - val_acc: 0.9391
#
# Epoch 00012: val_loss improved from 0.14300 to 0.14271, saving model to ./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5
# Epoch 13/300
#  - 0s - loss: 0.0947 - acc: 0.9661 - val_loss: 0.1370 - val_acc: 0.9391
#
# Epoch 00013: val_loss improved from 0.14271 to 0.13698, saving model to ./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5
# Epoch 14/300
#  - 0s - loss: 0.0881 - acc: 0.9699 - val_loss: 0.1388 - val_acc: 0.9370
#
# Epoch 00014: val_loss did not improve from 0.13698
# Epoch 15/300
#  - 0s - loss: 0.0866 - acc: 0.9685 - val_loss: 0.1395 - val_acc: 0.9349
#
# Epoch 00015: val_loss did not improve from 0.13698
# Epoch 16/300
#  - 0s - loss: 0.0894 - acc: 0.9669 - val_loss: 0.1433 - val_acc: 0.9328
#
# Epoch 00016: val_loss did not improve from 0.13698
# Epoch 17/300
#  - 0s - loss: 0.0831 - acc: 0.9711 - val_loss: 0.1381 - val_acc: 0.9349
#
# Epoch 00017: val_loss did not improve from 0.13698
# Epoch 18/300
#  - 0s - loss: 0.0809 - acc: 0.9730 - val_loss: 0.1387 - val_acc: 0.9370
#
# Epoch 00018: val_loss did not improve from 0.13698
# Epoch 19/300
#  - 0s - loss: 0.0763 - acc: 0.9732 - val_loss: 0.1368 - val_acc: 0.9349
#
# Epoch 00019: val_loss improved from 0.13698 to 0.13676, saving model to ./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5
# Epoch 20/300
#  - 0s - loss: 0.0811 - acc: 0.9716 - val_loss: 0.1370 - val_acc: 0.9412
#
# Epoch 00020: val_loss did not improve from 0.13676
# Epoch 21/300
#  - 0s - loss: 0.0781 - acc: 0.9714 - val_loss: 0.1415 - val_acc: 0.9370
#
# Epoch 00021: val_loss did not improve from 0.13676
# Epoch 22/300
#  - 0s - loss: 0.0775 - acc: 0.9728 - val_loss: 0.1410 - val_acc: 0.9349
#
# Epoch 00022: val_loss did not improve from 0.13676
# Epoch 23/300
#  - 0s - loss: 0.0788 - acc: 0.9723 - val_loss: 0.1366 - val_acc: 0.9454
#
# Epoch 00023: val_loss improved from 0.13676 to 0.13660, saving model to ./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5
# Epoch 24/300
#  - 0s - loss: 0.0687 - acc: 0.9773 - val_loss: 0.1362 - val_acc: 0.9412
#
# Epoch 00024: val_loss improved from 0.13660 to 0.13617, saving model to ./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5
# Epoch 25/300
#  - 0s - loss: 0.0715 - acc: 0.9730 - val_loss: 0.1349 - val_acc: 0.9475
#
# Epoch 00025: val_loss improved from 0.13617 to 0.13495, saving model to ./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5
# Epoch 26/300
#  - 0s - loss: 0.0714 - acc: 0.9749 - val_loss: 0.1386 - val_acc: 0.9391
#
# Epoch 00026: val_loss did not improve from 0.13495
# Epoch 27/300
#  - 0s - loss: 0.0682 - acc: 0.9763 - val_loss: 0.1350 - val_acc: 0.9454
#
# Epoch 00027: val_loss did not improve from 0.13495
# Epoch 28/300
#  - 0s - loss: 0.0696 - acc: 0.9742 - val_loss: 0.1376 - val_acc: 0.9433
#
# Epoch 00028: val_loss did not improve from 0.13495
# Epoch 29/300
#  - 0s - loss: 0.0655 - acc: 0.9761 - val_loss: 0.1363 - val_acc: 0.9454
#
# Epoch 00029: val_loss did not improve from 0.13495
# Epoch 30/300
#  - 0s - loss: 0.0626 - acc: 0.9796 - val_loss: 0.1352 - val_acc: 0.9412
#
# Epoch 00030: val_loss did not improve from 0.13495
# Epoch 31/300
#  - 0s - loss: 0.0623 - acc: 0.9777 - val_loss: 0.1358 - val_acc: 0.9475
#
# Epoch 00031: val_loss did not improve from 0.13495
# Epoch 32/300
#  - 0s - loss: 0.0618 - acc: 0.9773 - val_loss: 0.1359 - val_acc: 0.9454
#
# Epoch 00032: val_loss did not improve from 0.13495
# Epoch 33/300
#  - 0s - loss: 0.0609 - acc: 0.9789 - val_loss: 0.1335 - val_acc: 0.9412
#
# Epoch 00033: val_loss improved from 0.13495 to 0.13346, saving model to ./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5
# Epoch 34/300
#  - 0s - loss: 0.0584 - acc: 0.9804 - val_loss: 0.1379 - val_acc: 0.9454
#
# Epoch 00034: val_loss did not improve from 0.13346
# Epoch 35/300
#  - 0s - loss: 0.0565 - acc: 0.9815 - val_loss: 0.1380 - val_acc: 0.9454
#
# Epoch 00035: val_loss did not improve from 0.13346
# Epoch 36/300
#  - 0s - loss: 0.0637 - acc: 0.9759 - val_loss: 0.1378 - val_acc: 0.9454
#
# Epoch 00036: val_loss did not improve from 0.13346
# Epoch 37/300
#  - 0s - loss: 0.0600 - acc: 0.9785 - val_loss: 0.1395 - val_acc: 0.9433
#
# Epoch 00037: val_loss did not improve from 0.13346
# Epoch 38/300
#  - 0s - loss: 0.0555 - acc: 0.9813 - val_loss: 0.1379 - val_acc: 0.9475
#
# Epoch 00038: val_loss did not improve from 0.13346
# Epoch 39/300
#  - 0s - loss: 0.0564 - acc: 0.9808 - val_loss: 0.1328 - val_acc: 0.9496
#
# Epoch 00039: val_loss improved from 0.13346 to 0.13279, saving model to ./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5
# Epoch 40/300
#  - 0s - loss: 0.0552 - acc: 0.9796 - val_loss: 0.1347 - val_acc: 0.9475
#
# Epoch 00040: val_loss did not improve from 0.13279
# Epoch 41/300
#  - 0s - loss: 0.0541 - acc: 0.9815 - val_loss: 0.1357 - val_acc: 0.9496
#
# Epoch 00041: val_loss did not improve from 0.13279
# Epoch 42/300
#  - 0s - loss: 0.0507 - acc: 0.9841 - val_loss: 0.1450 - val_acc: 0.9496
#
# Epoch 00042: val_loss did not improve from 0.13279
# Epoch 43/300
#  - 0s - loss: 0.0522 - acc: 0.9837 - val_loss: 0.1385 - val_acc: 0.9517
#
# Epoch 00043: val_loss did not improve from 0.13279
# Epoch 44/300
#  - 0s - loss: 0.0559 - acc: 0.9813 - val_loss: 0.1353 - val_acc: 0.9475
#
# Epoch 00044: val_loss did not improve from 0.13279
# Epoch 45/300
#  - 0s - loss: 0.0468 - acc: 0.9848 - val_loss: 0.1424 - val_acc: 0.9496
#
# Epoch 00045: val_loss did not improve from 0.13279
# Epoch 46/300
#  - 0s - loss: 0.0523 - acc: 0.9820 - val_loss: 0.1339 - val_acc: 0.9454
#
# Epoch 00046: val_loss did not improve from 0.13279
# Epoch 47/300
#  - 0s - loss: 0.0544 - acc: 0.9806 - val_loss: 0.1368 - val_acc: 0.9517
#
# Epoch 00047: val_loss did not improve from 0.13279
# Epoch 48/300
#  - 0s - loss: 0.0499 - acc: 0.9825 - val_loss: 0.1362 - val_acc: 0.9475
#
# Epoch 00048: val_loss did not improve from 0.13279
# Epoch 49/300
#  - 0s - loss: 0.0565 - acc: 0.9770 - val_loss: 0.1427 - val_acc: 0.9517
#
# Epoch 00049: val_loss did not improve from 0.13279
# Epoch 50/300
#  - 0s - loss: 0.0485 - acc: 0.9825 - val_loss: 0.1369 - val_acc: 0.9496
#
# Epoch 00050: val_loss did not improve from 0.13279
# Epoch 51/300
#  - 0s - loss: 0.0470 - acc: 0.9841 - val_loss: 0.1380 - val_acc: 0.9475
#
# Epoch 00051: val_loss did not improve from 0.13279
# Epoch 52/300
#  - 0s - loss: 0.0488 - acc: 0.9839 - val_loss: 0.1372 - val_acc: 0.9475
#
# Epoch 00052: val_loss did not improve from 0.13279
# Epoch 53/300
#  - 0s - loss: 0.0509 - acc: 0.9841 - val_loss: 0.1367 - val_acc: 0.9454
#
# Epoch 00053: val_loss did not improve from 0.13279
# Epoch 54/300
#  - 0s - loss: 0.0479 - acc: 0.9844 - val_loss: 0.1348 - val_acc: 0.9454
#
# Epoch 00054: val_loss did not improve from 0.13279
# Epoch 55/300
#  - 0s - loss: 0.0443 - acc: 0.9856 - val_loss: 0.1386 - val_acc: 0.9475
#
# Epoch 00055: val_loss did not improve from 0.13279
# Epoch 56/300
#  - 0s - loss: 0.0452 - acc: 0.9865 - val_loss: 0.1386 - val_acc: 0.9433
#
# Epoch 00056: val_loss did not improve from 0.13279
# Epoch 57/300
#  - 0s - loss: 0.0402 - acc: 0.9877 - val_loss: 0.1414 - val_acc: 0.9433
#
# Epoch 00057: val_loss did not improve from 0.13279
# Epoch 58/300
#  - 0s - loss: 0.0456 - acc: 0.9851 - val_loss: 0.1320 - val_acc: 0.9496
#
# Epoch 00058: val_loss improved from 0.13279 to 0.13205, saving model to ./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5
# Epoch 59/300
#  - 0s - loss: 0.0409 - acc: 0.9867 - val_loss: 0.1387 - val_acc: 0.9496
#
# Epoch 00059: val_loss did not improve from 0.13205
# Epoch 60/300
#  - 0s - loss: 0.0430 - acc: 0.9884 - val_loss: 0.1375 - val_acc: 0.9496
#
# Epoch 00060: val_loss did not improve from 0.13205
# Epoch 61/300
#  - 0s - loss: 0.0432 - acc: 0.9875 - val_loss: 0.1374 - val_acc: 0.9496
#
# Epoch 00061: val_loss did not improve from 0.13205
# Epoch 62/300
#  - 0s - loss: 0.0402 - acc: 0.9877 - val_loss: 0.1434 - val_acc: 0.9412
#
# Epoch 00062: val_loss did not improve from 0.13205
# Epoch 63/300
#  - 0s - loss: 0.0411 - acc: 0.9886 - val_loss: 0.1351 - val_acc: 0.9496
#
# Epoch 00063: val_loss did not improve from 0.13205
# Epoch 64/300
#  - 0s - loss: 0.0367 - acc: 0.9875 - val_loss: 0.1335 - val_acc: 0.9496
#
# Epoch 00064: val_loss did not improve from 0.13205
# Epoch 65/300
#  - 0s - loss: 0.0412 - acc: 0.9884 - val_loss: 0.1390 - val_acc: 0.9433
#
# Epoch 00065: val_loss did not improve from 0.13205
# Epoch 66/300
#  - 0s - loss: 0.0414 - acc: 0.9875 - val_loss: 0.1458 - val_acc: 0.9433
#
# Epoch 00066: val_loss did not improve from 0.13205
# Epoch 67/300
#  - 0s - loss: 0.0410 - acc: 0.9877 - val_loss: 0.1423 - val_acc: 0.9412
#
# Epoch 00067: val_loss did not improve from 0.13205
# Epoch 68/300
#  - 0s - loss: 0.0403 - acc: 0.9879 - val_loss: 0.1391 - val_acc: 0.9433
#
# Epoch 00068: val_loss did not improve from 0.13205
# Epoch 69/300
#  - 0s - loss: 0.0431 - acc: 0.9837 - val_loss: 0.1403 - val_acc: 0.9433
#
# Epoch 00069: val_loss did not improve from 0.13205
# Epoch 70/300
#  - 0s - loss: 0.0384 - acc: 0.9901 - val_loss: 0.1461 - val_acc: 0.9454
#
# Epoch 00070: val_loss did not improve from 0.13205
# Epoch 71/300
#  - 0s - loss: 0.0362 - acc: 0.9905 - val_loss: 0.1401 - val_acc: 0.9454
#
# Epoch 00071: val_loss did not improve from 0.13205
# Epoch 72/300
#  - 0s - loss: 0.0385 - acc: 0.9884 - val_loss: 0.1394 - val_acc: 0.9454
#
# Epoch 00072: val_loss did not improve from 0.13205
# Epoch 73/300
#  - 0s - loss: 0.0341 - acc: 0.9908 - val_loss: 0.1387 - val_acc: 0.9454
#
# Epoch 00073: val_loss did not improve from 0.13205
# Epoch 74/300
#  - 0s - loss: 0.0376 - acc: 0.9898 - val_loss: 0.1418 - val_acc: 0.9433
#
# Epoch 00074: val_loss did not improve from 0.13205
# Epoch 75/300
#  - 0s - loss: 0.0409 - acc: 0.9872 - val_loss: 0.1452 - val_acc: 0.9433
#
# Epoch 00075: val_loss did not improve from 0.13205
# Epoch 76/300
#  - 0s - loss: 0.0397 - acc: 0.9882 - val_loss: 0.1419 - val_acc: 0.9454
#
# Epoch 00076: val_loss did not improve from 0.13205
# Epoch 77/300
#  - 0s - loss: 0.0377 - acc: 0.9891 - val_loss: 0.1392 - val_acc: 0.9412
#
# Epoch 00077: val_loss did not improve from 0.13205
# Epoch 78/300
#  - 0s - loss: 0.0310 - acc: 0.9912 - val_loss: 0.1362 - val_acc: 0.9496
#
# Epoch 00078: val_loss did not improve from 0.13205
# Epoch 79/300
#  - 0s - loss: 0.0365 - acc: 0.9889 - val_loss: 0.1474 - val_acc: 0.9433
#
# Epoch 00079: val_loss did not improve from 0.13205
# Epoch 80/300
#  - 0s - loss: 0.0390 - acc: 0.9872 - val_loss: 0.1471 - val_acc: 0.9412
#
# Epoch 00080: val_loss did not improve from 0.13205
# Epoch 81/300
#  - 0s - loss: 0.0334 - acc: 0.9898 - val_loss: 0.1437 - val_acc: 0.9412
#
# Epoch 00081: val_loss did not improve from 0.13205
# Epoch 82/300
#  - 0s - loss: 0.0373 - acc: 0.9877 - val_loss: 0.1404 - val_acc: 0.9433
#
# Epoch 00082: val_loss did not improve from 0.13205
# Epoch 83/300
#  - 0s - loss: 0.0382 - acc: 0.9882 - val_loss: 0.1381 - val_acc: 0.9475
#
# Epoch 00083: val_loss did not improve from 0.13205
# Epoch 84/300
#  - 0s - loss: 0.0390 - acc: 0.9853 - val_loss: 0.1435 - val_acc: 0.9454
#
# Epoch 00084: val_loss did not improve from 0.13205
# Epoch 85/300
#  - 0s - loss: 0.0379 - acc: 0.9872 - val_loss: 0.1416 - val_acc: 0.9433
#
# Epoch 00085: val_loss did not improve from 0.13205
# Epoch 86/300
#  - 0s - loss: 0.0317 - acc: 0.9917 - val_loss: 0.1349 - val_acc: 0.9412
#
# Epoch 00086: val_loss did not improve from 0.13205
# Epoch 87/300
#  - 0s - loss: 0.0313 - acc: 0.9922 - val_loss: 0.1421 - val_acc: 0.9454
#
# Epoch 00087: val_loss did not improve from 0.13205
# Epoch 88/300
#  - 0s - loss: 0.0339 - acc: 0.9901 - val_loss: 0.1483 - val_acc: 0.9391
#
# Epoch 00088: val_loss did not improve from 0.13205
# Epoch 89/300
#  - 0s - loss: 0.0347 - acc: 0.9893 - val_loss: 0.1466 - val_acc: 0.9391
#
# Epoch 00089: val_loss did not improve from 0.13205
# Epoch 90/300
#  - 0s - loss: 0.0299 - acc: 0.9922 - val_loss: 0.1443 - val_acc: 0.9454
#
# Epoch 00090: val_loss did not improve from 0.13205
# Epoch 91/300
#  - 0s - loss: 0.0317 - acc: 0.9910 - val_loss: 0.1439 - val_acc: 0.9391
#
# Epoch 00091: val_loss did not improve from 0.13205
# Epoch 92/300
#  - 0s - loss: 0.0319 - acc: 0.9908 - val_loss: 0.1499 - val_acc: 0.9433
#
# Epoch 00092: val_loss did not improve from 0.13205
# Epoch 93/300
#  - 0s - loss: 0.0342 - acc: 0.9882 - val_loss: 0.1398 - val_acc: 0.9454
#
# Epoch 00093: val_loss did not improve from 0.13205
# Epoch 94/300
#  - 0s - loss: 0.0357 - acc: 0.9898 - val_loss: 0.1426 - val_acc: 0.9433
#
# Epoch 00094: val_loss did not improve from 0.13205
# Epoch 95/300
#  - 0s - loss: 0.0315 - acc: 0.9908 - val_loss: 0.1477 - val_acc: 0.9433
#
# Epoch 00095: val_loss did not improve from 0.13205
# Epoch 96/300
#  - 0s - loss: 0.0283 - acc: 0.9938 - val_loss: 0.1364 - val_acc: 0.9454
#
# Epoch 00096: val_loss did not improve from 0.13205
# Epoch 97/300
#  - 0s - loss: 0.0328 - acc: 0.9901 - val_loss: 0.1420 - val_acc: 0.9412
#
# Epoch 00097: val_loss did not improve from 0.13205
# Epoch 98/300
#  - 0s - loss: 0.0277 - acc: 0.9931 - val_loss: 0.1407 - val_acc: 0.9412
#
# Epoch 00098: val_loss did not improve from 0.13205
# Epoch 99/300
#  - 0s - loss: 0.0315 - acc: 0.9903 - val_loss: 0.1465 - val_acc: 0.9454
#
# Epoch 00099: val_loss did not improve from 0.13205
# Epoch 100/300
#  - 0s - loss: 0.0279 - acc: 0.9920 - val_loss: 0.1459 - val_acc: 0.9454
#
# Epoch 00100: val_loss did not improve from 0.13205
# Epoch 101/300
#  - 0s - loss: 0.0286 - acc: 0.9915 - val_loss: 0.1451 - val_acc: 0.9454
#
# Epoch 00101: val_loss did not improve from 0.13205
# Epoch 102/300
#  - 0s - loss: 0.0282 - acc: 0.9910 - val_loss: 0.1465 - val_acc: 0.9412
#
# Epoch 00102: val_loss did not improve from 0.13205
# Epoch 103/300
#  - 0s - loss: 0.0281 - acc: 0.9917 - val_loss: 0.1436 - val_acc: 0.9412
#
# Epoch 00103: val_loss did not improve from 0.13205
# Epoch 104/300
#  - 0s - loss: 0.0305 - acc: 0.9898 - val_loss: 0.1463 - val_acc: 0.9475
#
# Epoch 00104: val_loss did not improve from 0.13205
# Epoch 105/300
#  - 0s - loss: 0.0309 - acc: 0.9884 - val_loss: 0.1431 - val_acc: 0.9433
#
# Epoch 00105: val_loss did not improve from 0.13205
# Epoch 106/300
#  - 0s - loss: 0.0285 - acc: 0.9922 - val_loss: 0.1438 - val_acc: 0.9496
#
# Epoch 00106: val_loss did not improve from 0.13205
# Epoch 107/300
#  - 0s - loss: 0.0263 - acc: 0.9929 - val_loss: 0.1538 - val_acc: 0.9391
#
# Epoch 00107: val_loss did not improve from 0.13205
# Epoch 108/300
#  - 0s - loss: 0.0263 - acc: 0.9938 - val_loss: 0.1443 - val_acc: 0.9475
# Epoch 00108: val_loss did not improve from 0.13205
# Epoch 109/300
#  - 0s - loss: 0.0254 - acc: 0.9950 - val_loss: 0.1396 - val_acc: 0.9433
#
# Epoch 00109: val_loss did not improve from 0.13205
# Epoch 110/300
#  - 0s - loss: 0.0278 - acc: 0.9927 - val_loss: 0.1443 - val_acc: 0.9454
#
# Epoch 00110: val_loss did not improve from 0.13205
# Epoch 111/300
#  - 0s - loss: 0.0299 - acc: 0.9905 - val_loss: 0.1419 - val_acc: 0.9454
#
# Epoch 00111: val_loss did not improve from 0.13205
# Epoch 112/300
#  - 0s - loss: 0.0249 - acc: 0.9936 - val_loss: 0.1368 - val_acc: 0.9496
#
# Epoch 00112: val_loss did not improve from 0.13205
# Epoch 113/300
#  - 0s - loss: 0.0276 - acc: 0.9917 - val_loss: 0.1413 - val_acc: 0.9412
#
# Epoch 00113: val_loss did not improve from 0.13205
# Epoch 114/300
#  - 0s - loss: 0.0265 - acc: 0.9941 - val_loss: 0.1445 - val_acc: 0.9433
#
# Epoch 00114: val_loss did not improve from 0.13205
# Epoch 115/300
#  - 0s - loss: 0.0268 - acc: 0.9936 - val_loss: 0.1440 - val_acc: 0.9433
#
# Epoch 00115: val_loss did not improve from 0.13205
# Epoch 116/300
#  - 0s - loss: 0.0235 - acc: 0.9941 - val_loss: 0.1420 - val_acc: 0.9454
#
# Epoch 00116: val_loss did not improve from 0.13205
# Epoch 117/300
#  - 0s - loss: 0.0274 - acc: 0.9927 - val_loss: 0.1422 - val_acc: 0.9475
#
# Epoch 00117: val_loss did not improve from 0.13205
# Epoch 118/300
#  - 0s - loss: 0.0300 - acc: 0.9901 - val_loss: 0.1433 - val_acc: 0.9433
#
# Epoch 00118: val_loss did not improve from 0.13205
# Epoch 119/300
#  - 0s - loss: 0.0263 - acc: 0.9920 - val_loss: 0.1481 - val_acc: 0.9433
#
# Epoch 00119: val_loss did not improve from 0.13205
# Epoch 120/300
#  - 0s - loss: 0.0268 - acc: 0.9917 - val_loss: 0.1457 - val_acc: 0.9475
#
# Epoch 00120: val_loss did not improve from 0.13205
# Epoch 121/300
#  - 0s - loss: 0.0243 - acc: 0.9943 - val_loss: 0.1500 - val_acc: 0.9391
#
# Epoch 00121: val_loss did not improve from 0.13205
# Epoch 122/300
#  - 0s - loss: 0.0284 - acc: 0.9917 - val_loss: 0.1538 - val_acc: 0.9433
#
# Epoch 00122: val_loss did not improve from 0.13205
# Epoch 123/300
#  - 0s - loss: 0.0308 - acc: 0.9908 - val_loss: 0.1541 - val_acc: 0.9412
#
# Epoch 00123: val_loss did not improve from 0.13205
# Epoch 124/300
#  - 0s - loss: 0.0269 - acc: 0.9912 - val_loss: 0.1518 - val_acc: 0.9391
#
# Epoch 00124: val_loss did not improve from 0.13205
# Epoch 125/300
#  - 0s - loss: 0.0267 - acc: 0.9927 - val_loss: 0.1491 - val_acc: 0.9454
#
# Epoch 00125: val_loss did not improve from 0.13205
# Epoch 126/300
#  - 0s - loss: 0.0216 - acc: 0.9960 - val_loss: 0.1487 - val_acc: 0.9412
#
# Epoch 00126: val_loss did not improve from 0.13205
# Epoch 127/300
#  - 0s - loss: 0.0255 - acc: 0.9934 - val_loss: 0.1462 - val_acc: 0.9454
#
# Epoch 00127: val_loss did not improve from 0.13205
# Epoch 128/300
#  - 0s - loss: 0.0235 - acc: 0.9943 - val_loss: 0.1422 - val_acc: 0.9433
#
# Epoch 00128: val_loss did not improve from 0.13205
# Epoch 129/300
#  - 0s - loss: 0.0219 - acc: 0.9943 - val_loss: 0.1489 - val_acc: 0.9412
#
# Epoch 00129: val_loss did not improve from 0.13205
# Epoch 130/300
#  - 0s - loss: 0.0271 - acc: 0.9927 - val_loss: 0.1479 - val_acc: 0.9412
#
# Epoch 00130: val_loss did not improve from 0.13205
# Epoch 131/300
#  - 0s - loss: 0.0265 - acc: 0.9917 - val_loss: 0.1443 - val_acc: 0.9433
#
# Epoch 00131: val_loss did not improve from 0.13205
# Epoch 132/300
#  - 0s - loss: 0.0243 - acc: 0.9924 - val_loss: 0.1516 - val_acc: 0.9433
#
# Epoch 00132: val_loss did not improve from 0.13205
# Epoch 133/300
#  - 0s - loss: 0.0279 - acc: 0.9920 - val_loss: 0.1521 - val_acc: 0.9412
#
# Epoch 00133: val_loss did not improve from 0.13205
# Epoch 134/300
#  - 0s - loss: 0.0191 - acc: 0.9969 - val_loss: 0.1466 - val_acc: 0.9454
#
# Epoch 00134: val_loss did not improve from 0.13205
# Epoch 135/300
#  - 0s - loss: 0.0312 - acc: 0.9893 - val_loss: 0.1422 - val_acc: 0.9475
#
# Epoch 00135: val_loss did not improve from 0.13205
# Epoch 136/300
#  - 0s - loss: 0.0237 - acc: 0.9948 - val_loss: 0.1481 - val_acc: 0.9454
#
# Epoch 00136: val_loss did not improve from 0.13205
# Epoch 137/300
#  - 0s - loss: 0.0249 - acc: 0.9929 - val_loss: 0.1550 - val_acc: 0.9454
#
# Epoch 00137: val_loss did not improve from 0.13205
# Epoch 138/300
#  - 0s - loss: 0.0240 - acc: 0.9924 - val_loss: 0.1555 - val_acc: 0.9412
#
# Epoch 00138: val_loss did not improve from 0.13205
# Epoch 139/300
#  - 0s - loss: 0.0264 - acc: 0.9917 - val_loss: 0.1557 - val_acc: 0.9391
#
# Epoch 00139: val_loss did not improve from 0.13205
# Epoch 140/300
#  - 0s - loss: 0.0203 - acc: 0.9955 - val_loss: 0.1520 - val_acc: 0.9412
#
# Epoch 00140: val_loss did not improve from 0.13205
# Epoch 141/300
#  - 0s - loss: 0.0249 - acc: 0.9929 - val_loss: 0.1601 - val_acc: 0.9433
#
# Epoch 00141: val_loss did not improve from 0.13205
# Epoch 142/300
#  - 0s - loss: 0.0271 - acc: 0.9910 - val_loss: 0.1497 - val_acc: 0.9433
#
# Epoch 00142: val_loss did not improve from 0.13205
# Epoch 143/300
#  - 0s - loss: 0.0235 - acc: 0.9946 - val_loss: 0.1494 - val_acc: 0.9433
#
# Epoch 00143: val_loss did not improve from 0.13205
# Epoch 144/300
#  - 0s - loss: 0.0223 - acc: 0.9936 - val_loss: 0.1536 - val_acc: 0.9433
#
# Epoch 00144: val_loss did not improve from 0.13205
# Epoch 145/300
#  - 0s - loss: 0.0218 - acc: 0.9941 - val_loss: 0.1477 - val_acc: 0.9412
#
# Epoch 00145: val_loss did not improve from 0.13205
# Epoch 146/300
#  - 0s - loss: 0.0289 - acc: 0.9901 - val_loss: 0.1496 - val_acc: 0.9454
#
# Epoch 00146: val_loss did not improve from 0.13205
# Epoch 147/300
#  - 0s - loss: 0.0258 - acc: 0.9917 - val_loss: 0.1545 - val_acc: 0.9391
#
# Epoch 00147: val_loss did not improve from 0.13205
# Epoch 148/300
#  - 0s - loss: 0.0206 - acc: 0.9964 - val_loss: 0.1549 - val_acc: 0.9412
#
# Epoch 00148: val_loss did not improve from 0.13205
# Epoch 149/300
#  - 0s - loss: 0.0256 - acc: 0.9915 - val_loss: 0.1546 - val_acc: 0.9433
#
# Epoch 00149: val_loss did not improve from 0.13205
# Epoch 150/300
#  - 0s - loss: 0.0250 - acc: 0.9929 - val_loss: 0.1532 - val_acc: 0.9475
#
# Epoch 00150: val_loss did not improve from 0.13205
# Epoch 151/300
#  - 0s - loss: 0.0290 - acc: 0.9915 - val_loss: 0.1620 - val_acc: 0.9391
#
# Epoch 00151: val_loss did not improve from 0.13205
# Epoch 152/300
#  - 0s - loss: 0.0267 - acc: 0.9924 - val_loss: 0.1577 - val_acc: 0.9433
#
# Epoch 00152: val_loss did not improve from 0.13205
# Epoch 153/300
#  - 0s - loss: 0.0202 - acc: 0.9955 - val_loss: 0.1528 - val_acc: 0.9475
#
# Epoch 00153: val_loss did not improve from 0.13205
# Epoch 154/300
#  - 0s - loss: 0.0216 - acc: 0.9948 - val_loss: 0.1538 - val_acc: 0.9517
#
# Epoch 00154: val_loss did not improve from 0.13205
# Epoch 155/300
#  - 0s - loss: 0.0231 - acc: 0.9941 - val_loss: 0.1550 - val_acc: 0.9433
#
# Epoch 00155: val_loss did not improve from 0.13205
# Epoch 156/300
#  - 0s - loss: 0.0210 - acc: 0.9946 - val_loss: 0.1468 - val_acc: 0.9496
#
# Epoch 00156: val_loss did not improve from 0.13205
# Epoch 157/300
#  - 0s - loss: 0.0259 - acc: 0.9905 - val_loss: 0.1569 - val_acc: 0.9475
#
# Epoch 00157: val_loss did not improve from 0.13205
# Epoch 158/300
#  - 0s - loss: 0.0221 - acc: 0.9953 - val_loss: 0.1485 - val_acc: 0.9475
#
# Epoch 00158: val_loss did not improve from 0.13205
# Epoch 159/300
#  - 0s - loss: 0.0226 - acc: 0.9929 - val_loss: 0.1529 - val_acc: 0.9391
#
# Epoch 00159: val_loss did not improve from 0.13205
# Epoch 160/300
#  - 0s - loss: 0.0213 - acc: 0.9941 - val_loss: 0.1459 - val_acc: 0.9517
#
# Epoch 00160: val_loss did not improve from 0.13205
# Epoch 161/300
#  - 0s - loss: 0.0195 - acc: 0.9948 - val_loss: 0.1561 - val_acc: 0.9433
#
# Epoch 00161: val_loss did not improve from 0.13205
# Epoch 162/300
#  - 0s - loss: 0.0235 - acc: 0.9922 - val_loss: 0.1469 - val_acc: 0.9517
#
# Epoch 00162: val_loss did not improve from 0.13205
# Epoch 163/300
#  - 0s - loss: 0.0202 - acc: 0.9962 - val_loss: 0.1483 - val_acc: 0.9391
#
# Epoch 00163: val_loss did not improve from 0.13205
# Epoch 164/300
#  - 0s - loss: 0.0195 - acc: 0.9953 - val_loss: 0.1466 - val_acc: 0.9496
#
# Epoch 00164: val_loss did not improve from 0.13205
# Epoch 165/300
#  - 0s - loss: 0.0195 - acc: 0.9943 - val_loss: 0.1507 - val_acc: 0.9454
#
# Epoch 00165: val_loss did not improve from 0.13205
# Epoch 166/300
#  - 0s - loss: 0.0199 - acc: 0.9953 - val_loss: 0.1472 - val_acc: 0.9433
#
# Epoch 00166: val_loss did not improve from 0.13205
# Epoch 167/300
#  - 0s - loss: 0.0195 - acc: 0.9938 - val_loss: 0.1496 - val_acc: 0.9412
#
# Epoch 00167: val_loss did not improve from 0.13205
# Epoch 168/300
#  - 0s - loss: 0.0216 - acc: 0.9946 - val_loss: 0.1457 - val_acc: 0.9454
#
# Epoch 00168: val_loss did not improve from 0.13205
# Epoch 169/300
#  - 0s - loss: 0.0204 - acc: 0.9953 - val_loss: 0.1461 - val_acc: 0.9433
#
# Epoch 00169: val_loss did not improve from 0.13205
# Epoch 170/300
#  - 0s - loss: 0.0199 - acc: 0.9946 - val_loss: 0.1482 - val_acc: 0.9454
#
# Epoch 00170: val_loss did not improve from 0.13205
# Epoch 171/300
#  - 0s - loss: 0.0210 - acc: 0.9936 - val_loss: 0.1453 - val_acc: 0.9475
#
# Epoch 00171: val_loss did not improve from 0.13205
# Epoch 172/300
#  - 0s - loss: 0.0232 - acc: 0.9927 - val_loss: 0.1457 - val_acc: 0.9475
#
# Epoch 00172: val_loss did not improve from 0.13205
# Epoch 173/300
#  - 0s - loss: 0.0226 - acc: 0.9924 - val_loss: 0.1519 - val_acc: 0.9412
#
# Epoch 00173: val_loss did not improve from 0.13205
# Epoch 174/300
#  - 0s - loss: 0.0168 - acc: 0.9953 - val_loss: 0.1522 - val_acc: 0.9475
#
# Epoch 00174: val_loss did not improve from 0.13205
# Epoch 175/300
#  - 0s - loss: 0.0193 - acc: 0.9946 - val_loss: 0.1494 - val_acc: 0.9433
#
# Epoch 00175: val_loss did not improve from 0.13205
# Epoch 176/300
#  - 0s - loss: 0.0223 - acc: 0.9941 - val_loss: 0.1564 - val_acc: 0.9412
#
# Epoch 00176: val_loss did not improve from 0.13205
# Epoch 177/300
#  - 0s - loss: 0.0212 - acc: 0.9950 - val_loss: 0.1570 - val_acc: 0.9412
#
# Epoch 00177: val_loss did not improve from 0.13205
# Epoch 178/300
#  - 0s - loss: 0.0196 - acc: 0.9946 - val_loss: 0.1596 - val_acc: 0.9433
#
# Epoch 00178: val_loss did not improve from 0.13205
# Epoch 179/300
#  - 0s - loss: 0.0196 - acc: 0.9950 - val_loss: 0.1530 - val_acc: 0.9391
#
# Epoch 00179: val_loss did not improve from 0.13205
# Epoch 180/300
#  - 0s - loss: 0.0178 - acc: 0.9950 - val_loss: 0.1555 - val_acc: 0.9391
#
# Epoch 00180: val_loss did not improve from 0.13205
# Epoch 181/300
#  - 0s - loss: 0.0242 - acc: 0.9924 - val_loss: 0.1526 - val_acc: 0.9412
#
# Epoch 00181: val_loss did not improve from 0.13205
# Epoch 182/300
#  - 0s - loss: 0.0181 - acc: 0.9960 - val_loss: 0.1507 - val_acc: 0.9391
#
# Epoch 00182: val_loss did not improve from 0.13205
# Epoch 183/300
#  - 0s - loss: 0.0207 - acc: 0.9950 - val_loss: 0.1521 - val_acc: 0.9454
#
# Epoch 00183: val_loss did not improve from 0.13205
# Epoch 184/300
#  - 0s - loss: 0.0234 - acc: 0.9924 - val_loss: 0.1566 - val_acc: 0.9433
#
# Epoch 00184: val_loss did not improve from 0.13205
# Epoch 185/300
#  - 0s - loss: 0.0189 - acc: 0.9943 - val_loss: 0.1573 - val_acc: 0.9412
#
# Epoch 00185: val_loss did not improve from 0.13205
# Epoch 186/300
#  - 0s - loss: 0.0201 - acc: 0.9941 - val_loss: 0.1449 - val_acc: 0.9454
#
# Epoch 00186: val_loss did not improve from 0.13205
# Epoch 187/300
#  - 0s - loss: 0.0217 - acc: 0.9920 - val_loss: 0.1607 - val_acc: 0.9370
#
# Epoch 00187: val_loss did not improve from 0.13205
# Epoch 188/300
#  - 0s - loss: 0.0189 - acc: 0.9948 - val_loss: 0.1685 - val_acc: 0.9433
#
# Epoch 00188: val_loss did not improve from 0.13205
# Epoch 189/300
#  - 0s - loss: 0.0255 - acc: 0.9927 - val_loss: 0.1494 - val_acc: 0.9454
#
# Epoch 00189: val_loss did not improve from 0.13205
# Epoch 190/300
#  - 0s - loss: 0.0211 - acc: 0.9936 - val_loss: 0.1548 - val_acc: 0.9433
#
# Epoch 00190: val_loss did not improve from 0.13205
# Epoch 191/300
#  - 0s - loss: 0.0194 - acc: 0.9941 - val_loss: 0.1545 - val_acc: 0.9433
#
# Epoch 00191: val_loss did not improve from 0.13205
# Epoch 192/300
#  - 0s - loss: 0.0180 - acc: 0.9953 - val_loss: 0.1583 - val_acc: 0.9433
#
# Epoch 00192: val_loss did not improve from 0.13205
# Epoch 193/300
#  - 0s - loss: 0.0163 - acc: 0.9967 - val_loss: 0.1536 - val_acc: 0.9433
#
# Epoch 00193: val_loss did not improve from 0.13205
# Epoch 194/300
#  - 0s - loss: 0.0219 - acc: 0.9931 - val_loss: 0.1571 - val_acc: 0.9349
#
# Epoch 00194: val_loss did not improve from 0.13205
# Epoch 195/300
#  - 0s - loss: 0.0171 - acc: 0.9953 - val_loss: 0.1538 - val_acc: 0.9433
#
# Epoch 00195: val_loss did not improve from 0.13205
# Epoch 196/300
#  - 0s - loss: 0.0167 - acc: 0.9964 - val_loss: 0.1613 - val_acc: 0.9412
#
# Epoch 00196: val_loss did not improve from 0.13205
# Epoch 197/300
#  - 0s - loss: 0.0182 - acc: 0.9957 - val_loss: 0.1670 - val_acc: 0.9391
#
# Epoch 00197: val_loss did not improve from 0.13205
# Epoch 198/300
#  - 0s - loss: 0.0204 - acc: 0.9943 - val_loss: 0.1572 - val_acc: 0.9454
#
# Epoch 00198: val_loss did not improve from 0.13205
# Epoch 199/300
#  - 0s - loss: 0.0176 - acc: 0.9964 - val_loss: 0.1549 - val_acc: 0.9496
#
# Epoch 00199: val_loss did not improve from 0.13205
# Epoch 200/300
#  - 0s - loss: 0.0186 - acc: 0.9950 - val_loss: 0.1600 - val_acc: 0.9370
#
# Epoch 00200: val_loss did not improve from 0.13205
# Epoch 201/300
#  - 0s - loss: 0.0177 - acc: 0.9957 - val_loss: 0.1538 - val_acc: 0.9412
#
# Epoch 00201: val_loss did not improve from 0.13205
# Epoch 202/300
#  - 0s - loss: 0.0158 - acc: 0.9960 - val_loss: 0.1564 - val_acc: 0.9370
#
# Epoch 00202: val_loss did not improve from 0.13205
# Epoch 203/300
#  - 0s - loss: 0.0193 - acc: 0.9962 - val_loss: 0.1584 - val_acc: 0.9391
#
# Epoch 00203: val_loss did not improve from 0.13205
# Epoch 204/300
#  - 0s - loss: 0.0176 - acc: 0.9953 - val_loss: 0.1597 - val_acc: 0.9391
#
# Epoch 00204: val_loss did not improve from 0.13205
# Epoch 205/300
#  - 0s - loss: 0.0148 - acc: 0.9969 - val_loss: 0.1650 - val_acc: 0.9391
#
# Epoch 00205: val_loss did not improve from 0.13205
# Epoch 206/300
#  - 0s - loss: 0.0150 - acc: 0.9967 - val_loss: 0.1694 - val_acc: 0.9370
#
# Epoch 00206: val_loss did not improve from 0.13205
# Epoch 207/300
#  - 0s - loss: 0.0181 - acc: 0.9955 - val_loss: 0.1590 - val_acc: 0.9391
#
# Epoch 00207: val_loss did not improve from 0.13205
# Epoch 208/300
#  - 0s - loss: 0.0210 - acc: 0.9943 - val_loss: 0.1584 - val_acc: 0.9454
#
# Epoch 00208: val_loss did not improve from 0.13205
# Epoch 209/300
#  - 0s - loss: 0.0160 - acc: 0.9960 - val_loss: 0.1668 - val_acc: 0.9391
#
# Epoch 00209: val_loss did not improve from 0.13205
# Epoch 210/300
#  - 0s - loss: 0.0157 - acc: 0.9979 - val_loss: 0.1620 - val_acc: 0.9454
#
# Epoch 00210: val_loss did not improve from 0.13205
# Epoch 211/300
#  - 0s - loss: 0.0211 - acc: 0.9927 - val_loss: 0.1709 - val_acc: 0.9433
#
# Epoch 00211: val_loss did not improve from 0.13205
# Epoch 212/300
#  - 0s - loss: 0.0162 - acc: 0.9957 - val_loss: 0.1593 - val_acc: 0.9433
#
# Epoch 00212: val_loss did not improve from 0.13205
# Epoch 213/300
#  - 0s - loss: 0.0160 - acc: 0.9957 - val_loss: 0.1611 - val_acc: 0.9454
#
# Epoch 00213: val_loss did not improve from 0.13205
# Epoch 214/300
#  - 0s - loss: 0.0151 - acc: 0.9972 - val_loss: 0.1581 - val_acc: 0.9433
#
# Epoch 00214: val_loss did not improve from 0.13205
# Epoch 215/300
#  - 0s - loss: 0.0169 - acc: 0.9957 - val_loss: 0.1631 - val_acc: 0.9412
#
# Epoch 00215: val_loss did not improve from 0.13205
# Epoch 216/300
#  - 0s - loss: 0.0156 - acc: 0.9953 - val_loss: 0.1564 - val_acc: 0.9454
#
# Epoch 00216: val_loss did not improve from 0.13205
# Epoch 217/300
#  - 0s - loss: 0.0167 - acc: 0.9946 - val_loss: 0.1730 - val_acc: 0.9433
#
# Epoch 00217: val_loss did not improve from 0.13205
# Epoch 218/300
#  - 0s - loss: 0.0221 - acc: 0.9912 - val_loss: 0.1677 - val_acc: 0.9412
#
# Epoch 00218: val_loss did not improve from 0.13205
# Epoch 219/300
#  - 0s - loss: 0.0178 - acc: 0.9953 - val_loss: 0.1710 - val_acc: 0.9433
#
# Epoch 00219: val_loss did not improve from 0.13205
# Epoch 220/300
#  - 0s - loss: 0.0197 - acc: 0.9950 - val_loss: 0.1693 - val_acc: 0.9454
#
# Epoch 00220: val_loss did not improve from 0.13205
# Epoch 221/300
#  - 0s - loss: 0.0145 - acc: 0.9979 - val_loss: 0.1651 - val_acc: 0.9433
#
# Epoch 00221: val_loss did not improve from 0.13205
# Epoch 222/300
#  - 0s - loss: 0.0184 - acc: 0.9941 - val_loss: 0.1605 - val_acc: 0.9454
#
# Epoch 00222: val_loss did not improve from 0.13205
# Epoch 223/300
#  - 0s - loss: 0.0178 - acc: 0.9941 - val_loss: 0.1734 - val_acc: 0.9412
#
# Epoch 00223: val_loss did not improve from 0.13205
# Epoch 224/300
#  - 0s - loss: 0.0171 - acc: 0.9946 - val_loss: 0.1628 - val_acc: 0.9454
#
# Epoch 00224: val_loss did not improve from 0.13205
# Epoch 225/300
#  - 0s - loss: 0.0147 - acc: 0.9972 - val_loss: 0.1716 - val_acc: 0.9391
#
# Epoch 00225: val_loss did not improve from 0.13205
# Epoch 226/300
#  - 0s - loss: 0.0158 - acc: 0.9962 - val_loss: 0.1685 - val_acc: 0.9391
#
# Epoch 00226: val_loss did not improve from 0.13205
# Epoch 227/300
#  - 0s - loss: 0.0159 - acc: 0.9960 - val_loss: 0.1634 - val_acc: 0.9391
# Epoch 00227: val_loss did not improve from 0.13205
# Epoch 228/300
#  - 0s - loss: 0.0146 - acc: 0.9972 - val_loss: 0.1656 - val_acc: 0.9328
#
# Epoch 00228: val_loss did not improve from 0.13205
# Epoch 229/300
#  - 0s - loss: 0.0173 - acc: 0.9948 - val_loss: 0.1673 - val_acc: 0.9370
#
# Epoch 00229: val_loss did not improve from 0.13205
# Epoch 230/300
#  - 0s - loss: 0.0167 - acc: 0.9950 - val_loss: 0.1597 - val_acc: 0.9454
#
# Epoch 00230: val_loss did not improve from 0.13205
# Epoch 231/300
#  - 0s - loss: 0.0181 - acc: 0.9957 - val_loss: 0.1711 - val_acc: 0.9433
#
# Epoch 00231: val_loss did not improve from 0.13205
# Epoch 232/300
#  - 0s - loss: 0.0161 - acc: 0.9964 - val_loss: 0.1781 - val_acc: 0.9328
#
# Epoch 00232: val_loss did not improve from 0.13205
# Epoch 233/300
#  - 0s - loss: 0.0165 - acc: 0.9960 - val_loss: 0.1733 - val_acc: 0.9454
#
# Epoch 00233: val_loss did not improve from 0.13205
# Epoch 234/300
#  - 0s - loss: 0.0208 - acc: 0.9946 - val_loss: 0.1631 - val_acc: 0.9433
#
# Epoch 00234: val_loss did not improve from 0.13205
# Epoch 235/300
#  - 0s - loss: 0.0163 - acc: 0.9960 - val_loss: 0.1716 - val_acc: 0.9433
#
# Epoch 00235: val_loss did not improve from 0.13205
# Epoch 236/300
#  - 0s - loss: 0.0160 - acc: 0.9957 - val_loss: 0.1640 - val_acc: 0.9475
#
# Epoch 00236: val_loss did not improve from 0.13205
# Epoch 237/300
#  - 0s - loss: 0.0153 - acc: 0.9955 - val_loss: 0.1700 - val_acc: 0.9391
#
# Epoch 00237: val_loss did not improve from 0.13205
# Epoch 238/300
#  - 0s - loss: 0.0181 - acc: 0.9950 - val_loss: 0.1572 - val_acc: 0.9433
#
# Epoch 00238: val_loss did not improve from 0.13205
# Epoch 239/300
#  - 0s - loss: 0.0147 - acc: 0.9964 - val_loss: 0.1699 - val_acc: 0.9412
#
# Epoch 00239: val_loss did not improve from 0.13205
# Epoch 240/300
#  - 0s - loss: 0.0175 - acc: 0.9950 - val_loss: 0.1868 - val_acc: 0.9307
#
# Epoch 00240: val_loss did not improve from 0.13205
# Epoch 241/300
#  - 0s - loss: 0.0162 - acc: 0.9950 - val_loss: 0.1688 - val_acc: 0.9370
#
# Epoch 00241: val_loss did not improve from 0.13205
# Epoch 242/300
#  - 0s - loss: 0.0152 - acc: 0.9960 - val_loss: 0.1663 - val_acc: 0.9454
#
# Epoch 00242: val_loss did not improve from 0.13205
# Epoch 243/300
#  - 0s - loss: 0.0174 - acc: 0.9936 - val_loss: 0.1606 - val_acc: 0.9433
#
# Epoch 00243: val_loss did not improve from 0.13205
# Epoch 244/300
#  - 0s - loss: 0.0144 - acc: 0.9962 - val_loss: 0.1669 - val_acc: 0.9412
#
# Epoch 00244: val_loss did not improve from 0.13205
# Epoch 245/300
#  - 0s - loss: 0.0150 - acc: 0.9960 - val_loss: 0.1685 - val_acc: 0.9412
#
# Epoch 00245: val_loss did not improve from 0.13205
# Epoch 246/300
#  - 0s - loss: 0.0144 - acc: 0.9974 - val_loss: 0.1676 - val_acc: 0.9391
#
# Epoch 00246: val_loss did not improve from 0.13205
# Epoch 247/300
#  - 0s - loss: 0.0152 - acc: 0.9955 - val_loss: 0.1682 - val_acc: 0.9433
#
# Epoch 00247: val_loss did not improve from 0.13205
# Epoch 248/300
#  - 0s - loss: 0.0165 - acc: 0.9960 - val_loss: 0.1563 - val_acc: 0.9370
#
# Epoch 00248: val_loss did not improve from 0.13205
# Epoch 249/300
#  - 0s - loss: 0.0189 - acc: 0.9934 - val_loss: 0.1644 - val_acc: 0.9391
#
# Epoch 00249: val_loss did not improve from 0.13205
# Epoch 250/300
#  - 0s - loss: 0.0196 - acc: 0.9924 - val_loss: 0.1639 - val_acc: 0.9433
#
# Epoch 00250: val_loss did not improve from 0.13205
# Epoch 251/300
#  - 0s - loss: 0.0188 - acc: 0.9943 - val_loss: 0.1685 - val_acc: 0.9391
#
# Epoch 00251: val_loss did not improve from 0.13205
# Epoch 252/300
#  - 0s - loss: 0.0135 - acc: 0.9969 - val_loss: 0.1693 - val_acc: 0.9412
#
# Epoch 00252: val_loss did not improve from 0.13205
# Epoch 253/300
#  - 0s - loss: 0.0117 - acc: 0.9974 - val_loss: 0.1699 - val_acc: 0.9454
#
# Epoch 00253: val_loss did not improve from 0.13205
# Epoch 254/300
#  - 0s - loss: 0.0130 - acc: 0.9972 - val_loss: 0.1698 - val_acc: 0.9433
#
# Epoch 00254: val_loss did not improve from 0.13205
# Epoch 255/300
#  - 0s - loss: 0.0149 - acc: 0.9957 - val_loss: 0.1686 - val_acc: 0.9433
#
# Epoch 00255: val_loss did not improve from 0.13205
# Epoch 256/300
#  - 0s - loss: 0.0171 - acc: 0.9960 - val_loss: 0.1686 - val_acc: 0.9412
#
# Epoch 00256: val_loss did not improve from 0.13205
# Epoch 257/300
#  - 0s - loss: 0.0165 - acc: 0.9950 - val_loss: 0.1680 - val_acc: 0.9391
#
# Epoch 00257: val_loss did not improve from 0.13205
# Epoch 258/300
#  - 0s - loss: 0.0147 - acc: 0.9962 - val_loss: 0.1644 - val_acc: 0.9454
#
# Epoch 00258: val_loss did not improve from 0.13205
# Epoch 259/300
#  - 0s - loss: 0.0149 - acc: 0.9967 - val_loss: 0.1709 - val_acc: 0.9412
#
# Epoch 00259: val_loss did not improve from 0.13205
# Epoch 260/300
#  - 0s - loss: 0.0169 - acc: 0.9946 - val_loss: 0.1628 - val_acc: 0.9454
#
# Epoch 00260: val_loss did not improve from 0.13205
# Epoch 261/300
#  - 0s - loss: 0.0154 - acc: 0.9946 - val_loss: 0.1718 - val_acc: 0.9412
#
# Epoch 00261: val_loss did not improve from 0.13205
# Epoch 262/300
#  - 0s - loss: 0.0119 - acc: 0.9972 - val_loss: 0.1707 - val_acc: 0.9391
#
# Epoch 00262: val_loss did not improve from 0.13205
# Epoch 263/300
#  - 0s - loss: 0.0142 - acc: 0.9953 - val_loss: 0.1680 - val_acc: 0.9391
#
# Epoch 00263: val_loss did not improve from 0.13205
# Epoch 264/300
#  - 0s - loss: 0.0127 - acc: 0.9962 - val_loss: 0.1704 - val_acc: 0.9328
#
# Epoch 00264: val_loss did not improve from 0.13205
# Epoch 265/300
#  - 0s - loss: 0.0139 - acc: 0.9974 - val_loss: 0.1634 - val_acc: 0.9391
#
# Epoch 00265: val_loss did not improve from 0.13205
# Epoch 266/300
#  - 0s - loss: 0.0138 - acc: 0.9967 - val_loss: 0.1579 - val_acc: 0.9475
#
# Epoch 00266: val_loss did not improve from 0.13205
# Epoch 267/300
#  - 0s - loss: 0.0186 - acc: 0.9946 - val_loss: 0.1749 - val_acc: 0.9349
#
# Epoch 00267: val_loss did not improve from 0.13205
# Epoch 268/300
#  - 0s - loss: 0.0177 - acc: 0.9938 - val_loss: 0.1635 - val_acc: 0.9454
#
# Epoch 00268: val_loss did not improve from 0.13205
# Epoch 269/300
#  - 0s - loss: 0.0123 - acc: 0.9967 - val_loss: 0.1688 - val_acc: 0.9328
#
# Epoch 00269: val_loss did not improve from 0.13205
# Epoch 270/300
#  - 0s - loss: 0.0177 - acc: 0.9934 - val_loss: 0.1705 - val_acc: 0.9412
#
# Epoch 00270: val_loss did not improve from 0.13205
# Epoch 271/300
#  - 0s - loss: 0.0149 - acc: 0.9960 - val_loss: 0.1710 - val_acc: 0.9370
#
# Epoch 00271: val_loss did not improve from 0.13205
# Epoch 272/300
#  - 0s - loss: 0.0134 - acc: 0.9974 - val_loss: 0.1693 - val_acc: 0.9391
#
# Epoch 00272: val_loss did not improve from 0.13205
# Epoch 273/300
#  - 0s - loss: 0.0141 - acc: 0.9960 - val_loss: 0.1749 - val_acc: 0.9370
#
# Epoch 00273: val_loss did not improve from 0.13205
# Epoch 274/300
#  - 0s - loss: 0.0131 - acc: 0.9967 - val_loss: 0.1746 - val_acc: 0.9391
#
# Epoch 00274: val_loss did not improve from 0.13205
# Epoch 275/300
#  - 0s - loss: 0.0167 - acc: 0.9950 - val_loss: 0.1809 - val_acc: 0.9349
#
# Epoch 00275: val_loss did not improve from 0.13205
# Epoch 276/300
#  - 0s - loss: 0.0159 - acc: 0.9946 - val_loss: 0.1771 - val_acc: 0.9412
#
# Epoch 00276: val_loss did not improve from 0.13205
# Epoch 277/300
#  - 0s - loss: 0.0176 - acc: 0.9938 - val_loss: 0.1633 - val_acc: 0.9433
#
# Epoch 00277: val_loss did not improve from 0.13205
# Epoch 278/300
#  - 0s - loss: 0.0159 - acc: 0.9948 - val_loss: 0.1711 - val_acc: 0.9475
#
# Epoch 00278: val_loss did not improve from 0.13205
# Epoch 279/300
#  - 0s - loss: 0.0156 - acc: 0.9955 - val_loss: 0.1783 - val_acc: 0.9370
#
# Epoch 00279: val_loss did not improve from 0.13205
# Epoch 280/300
#  - 0s - loss: 0.0156 - acc: 0.9957 - val_loss: 0.1678 - val_acc: 0.9433
#
# Epoch 00280: val_loss did not improve from 0.13205
# Epoch 281/300
#  - 0s - loss: 0.0149 - acc: 0.9955 - val_loss: 0.1615 - val_acc: 0.9433
#
# Epoch 00281: val_loss did not improve from 0.13205
# Epoch 282/300
#  - 0s - loss: 0.0129 - acc: 0.9967 - val_loss: 0.1696 - val_acc: 0.9391
#
# Epoch 00282: val_loss did not improve from 0.13205
# Epoch 283/300
#  - 0s - loss: 0.0128 - acc: 0.9964 - val_loss: 0.1615 - val_acc: 0.9433
#
# Epoch 00283: val_loss did not improve from 0.13205
# Epoch 284/300
#  - 0s - loss: 0.0149 - acc: 0.9972 - val_loss: 0.1641 - val_acc: 0.9433
#
# Epoch 00284: val_loss did not improve from 0.13205
# Epoch 285/300
#  - 0s - loss: 0.0154 - acc: 0.9950 - val_loss: 0.1673 - val_acc: 0.9391
#
# Epoch 00285: val_loss did not improve from 0.13205
# Epoch 286/300
#  - 0s - loss: 0.0135 - acc: 0.9967 - val_loss: 0.1742 - val_acc: 0.9433
#
# Epoch 00286: val_loss did not improve from 0.13205
# Epoch 287/300
#  - 0s - loss: 0.0202 - acc: 0.9936 - val_loss: 0.1709 - val_acc: 0.9391
#
# Epoch 00287: val_loss did not improve from 0.13205
# Epoch 288/300
#  - 0s - loss: 0.0174 - acc: 0.9948 - val_loss: 0.1687 - val_acc: 0.9370
#
# Epoch 00288: val_loss did not improve from 0.13205
# Epoch 289/300
#  - 0s - loss: 0.0139 - acc: 0.9962 - val_loss: 0.1736 - val_acc: 0.9370
#
# Epoch 00289: val_loss did not improve from 0.13205
# Epoch 290/300
#  - 0s - loss: 0.0164 - acc: 0.9941 - val_loss: 0.1740 - val_acc: 0.9412
#
# Epoch 00290: val_loss did not improve from 0.13205
# Epoch 291/300
#  - 0s - loss: 0.0129 - acc: 0.9967 - val_loss: 0.1735 - val_acc: 0.9370
#
# Epoch 00291: val_loss did not improve from 0.13205
# Epoch 292/300
#  - 0s - loss: 0.0119 - acc: 0.9979 - val_loss: 0.1640 - val_acc: 0.9433
#
# Epoch 00292: val_loss did not improve from 0.13205
# Epoch 293/300
#  - 0s - loss: 0.0145 - acc: 0.9957 - val_loss: 0.1695 - val_acc: 0.9454
#
# Epoch 00293: val_loss did not improve from 0.13205
# Epoch 294/300
#  - 0s - loss: 0.0146 - acc: 0.9955 - val_loss: 0.1718 - val_acc: 0.9391
#
# Epoch 00294: val_loss did not improve from 0.13205
# Epoch 295/300
#  - 0s - loss: 0.0169 - acc: 0.9948 - val_loss: 0.1703 - val_acc: 0.9370
#
# Epoch 00295: val_loss did not improve from 0.13205
# Epoch 296/300
#  - 0s - loss: 0.0136 - acc: 0.9964 - val_loss: 0.1748 - val_acc: 0.9370
#
# Epoch 00296: val_loss did not improve from 0.13205
# Epoch 297/300
#  - 0s - loss: 0.0104 - acc: 0.9983 - val_loss: 0.1618 - val_acc: 0.9412
#
# Epoch 00297: val_loss did not improve from 0.13205
# Epoch 298/300
#  - 0s - loss: 0.0132 - acc: 0.9969 - val_loss: 0.1635 - val_acc: 0.9328
#
# Epoch 00298: val_loss did not improve from 0.13205
# Epoch 299/300
#  - 0s - loss: 0.0150 - acc: 0.9948 - val_loss: 0.1672 - val_acc: 0.9370
#
# Epoch 00299: val_loss did not improve from 0.13205
# Epoch 300/300
#  - 0s - loss: 0.0151 - acc: 0.9960 - val_loss: 0.1725 - val_acc: 0.9349
#
# Epoch 00300: val_loss did not improve from 0.13205

# %%
# plot the transfer model to a file and store it for further usage (only first time)
#plot_model(inception_model, to_file='./saved_models/inception_transfer_model_topLayer.png')

# %% [markdown]
# <a id='step13'></a>
# ## Step 13: Evaluation
#
# ### Load the Models with the Best Validation Loss

# %%
base_model_class.load_best_weights(model=base_model,
                                   filepath='./saved_models/base_model_weights.best.from_scratch.hdf5')
aug_base_model_class.load_best_weights(model=aug_base_model,
                                   filepath='./saved_models/base_model_weights.best.withAugmentation.hdf5')
adam_base_model_class.load_best_weights(model=adam_base_model,
                                   filepath='./saved_models/base_model_weights_withAdam.best.from_scratch.hdf5')
adam_aug_base_model_class.load_best_weights(model=adam_aug_base_model,
                                   filepath='./saved_models/Adam_base_model_weights.best.withAugmentation.hdf5')
improved_model_class.load_best_weights(model=improved_model_adam,
                                       filepath='./saved_models/improved_model_weights.best.withAdam.hdf5')
improved_model_aug_class.load_best_weights(model=improved_model_aug,
                                  filepath='./saved_models/improved_model_weights.best.withAugmentation.hdf5')
basic_resNet_model_class.load_best_weights(model=basic_resNet_model,
                                  filepath='./saved_models/transfer_ResNet50_model_weights.best.withAdam.hdf5')
resNet_ft_model_class.load_best_weights(model=resNet_ft_model,
                filepath='./saved_models/transfer_ResNet50_finetuned_model_weights.best.withAugmentation.hdf5')
inception_model_class.load_best_weights(model=inception_model,
                               filepath='./saved_models/transfer_InceptionV3_model_weights.best.withAdam.hdf5')

# %% [markdown]
# ### Testing for all the Models

# %% [markdown]
# Try out this basic model on the test chest images dataset.  What is its test accuracy?

# %%
# get index of predicted pneumonia for each image in the testset
# simple base model
base_model = base_model_class.get_model()
chest_pneumonia_predictions = base_model.predict_classes(test_tensors, verbose=0)

# report test accuracy
Evaluation_Class.print_test_accuracy(model_name="Basic Model with rmsprop optimiser",
                                   predictions=chest_pneumonia_predictions,
                                   test_targets=test_targets)
# Out:
# Basic Model with rmsprop optimiser: Test Accuracy: 63.44%

# %%
# augmented base model
aug_base_model = aug_base_model_class.get_model()
aug_chest_pneumonia_predictions = aug_base_model.predict_classes(test_tensors, verbose=0)

# report test accuracy
Evaluation_Class.print_test_accuracy(model_name="Basic Model with Augmentation",
                                   predictions=aug_chest_pneumonia_predictions,
                                   test_targets=test_targets)
# Out:
# Basic Model with Augmentation: Test Accuracy: 63.44%

# %%
# base model with Adam optimiser
adam_base_model = adam_base_model_class.get_model()
adam_chest_pneumonia_predictions = adam_base_model.predict_classes(test_tensors, verbose=0)

# report test accuracy
Evaluation_Class.print_test_accuracy(model_name="Basic Model with Adam optimiser",
                                   predictions=adam_chest_pneumonia_predictions,
                                   test_targets=test_targets)
# Out:
# Basic Model with Adam optimiser: Test Accuracy: 84.62%

# %%
# basic, augmented model with Adam optimiser
adam_aug_base_model = adam_aug_base_model_class.get_model()
adam_aug_chest_pneumonia_predict = adam_aug_base_model.predict_classes(test_tensors, verbose=0)

# report test accuracy
Evaluation_Class.print_test_accuracy(model_name="Basic Model with Adam optimiser and Augmentation",
                                   predictions=adam_aug_chest_pneumonia_predict,
                                   test_targets=test_targets)
# Out:
# Basic Model with Adam optimiser and Augmentation: Test Accuracy: 83.75%

# %%
# improved model with Adam optimiser
improved_model_adam = improved_model_class.get_model()
improved_chest_pneumonia_predict_adam = improved_model_adam.predict_classes(test_tensors, verbose=0)

# report test accuracy
Evaluation_Class.print_test_accuracy(model_name="Improved model with Adam optimiser",
                                   predictions=improved_chest_pneumonia_predict_adam,
                                   test_targets=test_targets)
# Out:
# Improved model with Adam optimiser: Test Accuracy: 63.44%

# %%
# improved, augmented model with Adam optimiser
improved_model_aug = improved_model_aug_class.get_model()
improved_chest_pneumonia_predict_aug = improved_model_aug.predict_classes(test_tensors, verbose=0)

# report test accuracy
Evaluation_Class.print_test_accuracy(model_name="Improved model with Adam optimiser and Augmentation",
                                   predictions=improved_chest_pneumonia_predict_aug,
                                   test_targets=test_targets)
# Out:
# Improved model with Adam optimiser and Augmentation: Test Accuracy: 82.80%

# %%
# ResNet50 transfer learning model with Adam optimiser and bottleneck features
basic_resNet_model = basic_resNet_model_class.get_model()
resNet_chest_pneumonia_predict = basic_resNet_model.predict_classes(test_resNet, verbose=0)

# report test accuracy
Evaluation_Class.print_test_accuracy(model_name="ResNet transfer model with Adam optimiser and bottleneck features",
                                   predictions=resNet_chest_pneumonia_predict,
                                   test_targets=test_targets)
# Out:
# ResNet transfer model with Adam optimiser and bottleneck features: Test Accuracy: 85.91%

# %%
# Fine-tuned ResNet50 transfer learning model with adam optimiser and Augmentation
resNet_ft_model = resNet_ft_model_class.get_model()
resNet_ft_transfer_chest_pneumonia_predict = resNet_ft_model.predict_classes(test_tensors, verbose=0)

# report test accuracy
Evaluation_Class.print_test_accuracy(model_name="Fine-tuned ResNet50 transfer model with Adam optimiser and Augmentation",
                                   predictions=resNet_ft_transfer_chest_pneumonia_predict,
                                   test_targets=test_targets)
# Out:
# Fine-tuned ResNet50 transfer model with Adam optimiser and Augmentation: Test Accuracy: 63.44%

# %%
# InceptionV3 model with Adam optimiser and bottleneck features
inception_model = inception_model_class.get_model()
inception_chest_pneumonia_predict = inception_model.predict_classes(test_inception, verbose=0)

# report test accuracy
Evaluation_Class.print_test_accuracy(model_name="Inception transfer model with Adam optimiser and bottleneck features",
                                   predictions=inception_chest_pneumonia_predict,
                                   test_targets=test_targets)
# Out:
# Inception transfer model with Adam optimiser and bottleneck features: Test Accuracy: 86.34%

# %% [markdown]
# ### Metrics of the Models

# %% [markdown]
# Calculates and shows several metrics of the models. Start with evaluated classification accuracy for training and testing (must be the same as before, only as a decimal number instead of percentage).
#
# **Accuracy** is the correctness of the binary classification: it measures how often the classifier makes the correct prediction. It’s the ratio of the number of correct predictions to the total number of predictions
#
# (TP + TN) / (TP + TN + FP + FN)
#
# where: TP = TruePositive; FP = FalsePositive; TN = TrueNegative; FN = FalseNegative

# %%
# simple basic model
_, train_acc = base_model.evaluate(train_tensors, train_targets, verbose=0)  # train X, train y
_, test_acc = base_model.evaluate(test_tensors, test_targets, verbose=0)     # test X, test y
print("\nAccuracy for training and testing of the basic model with rmsprop optimiser:")
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Accuracy for training and testing of the basic model with rmsprop optimiser:
# Train: 0.752, Test: 0.634

# %%
# augmented basic model
_, aug_base_train_acc = aug_base_model.evaluate(train_tensors, train_targets, verbose=0)  
_, aug_base_test_acc = aug_base_model.evaluate(test_tensors, test_targets, verbose=0)    
print("\nAccuracy for training and testing of the basic model with Augmentation:")
print('Train: %.3f, Test: %.3f' % (aug_base_train_acc, aug_base_test_acc))
# Out:
# Accuracy for training and testing of the basic model with Augmentation:
# Train: 0.752, Test: 0.634

# %%
# basic model with adam optimiser
_, adam_base_train_acc = adam_base_model.evaluate(train_tensors, train_targets, verbose=0)  
_, adam_base_test_acc = adam_base_model.evaluate(test_tensors, test_targets, verbose=0)    
print("\nAccuracy for training and testing of the basic model with Adam optimiser:")
print('Train: %.3f, Test: %.3f' % (adam_base_train_acc, adam_base_test_acc))
# Out:
# Accuracy for training and testing of the basic model with Adam optimiser:
# Train: 0.955, Test: 0.846

# %%
# basic model with adam optimiser and augmentation
_, adam_aug_train_acc = adam_aug_base_model.evaluate(train_tensors, train_targets, verbose=0)  
_, adam_aug_test_acc = adam_aug_base_model.evaluate(test_tensors, test_targets, verbose=0)    
print("\nAccuracy for training and testing of the basic, augmented model with Adam optimiser:")
print('Train: %.3f, Test: %.3f' % (adam_aug_train_acc, adam_aug_test_acc))
# Out:
# Accuracy for training and testing of the basic, augmented model with Adam optimiser:
# Train: 0.895, Test: 0.838

# %%
# improved model with adam optimiser
_, improved_train_acc_adam = improved_model_adam.evaluate(train_tensors, train_targets, verbose=0)  
_, improved_test_acc_adam = improved_model_adam.evaluate(test_tensors, test_targets, verbose=0) 
print("\nAccuracy for training and testing of the improved model with Adam optimiser:")
print('Train: %.3f, Test: %.3f' % (improved_train_acc_adam, improved_test_acc_adam))
# Out:
# Accuracy for training and testing of the improved model with Adam optimiser:
# Train: 0.752, Test: 0.634

# %%
# improved, augmented model with adam optimiser
_, improved_train_acc = improved_model_aug.evaluate(train_tensors, train_targets, verbose=0)  
_, improved_test_acc = improved_model_aug.evaluate(test_tensors, test_targets, verbose=0)  
print("\nAccuracy for training and testing of the improved, augmented model with Adam optimiser:")
print('Train: %.3f, Test: %.3f' % (improved_train_acc, improved_test_acc))
# Out:
# Accuracy for training and testing of the improved, augmented model with Adam optimiser:
# Train: 0.842, Test: 0.828

# %%
# ResNet50 transfer model with adam optimiser and bottleneck features
_, resNet_transfer_train_acc = basic_resNet_model.evaluate(train_resNet, train_targets, verbose=0) 
_, resNet_transfer_test_acc = basic_resNet_model.evaluate(test_resNet, test_targets, verbose=0)    
print("\nAccuracy for training and testing of ResNet50 transfer model with Adam optimiser and bottleneck features:")
print('Train: %.3f, Test: %.3f' % (resNet_transfer_train_acc, resNet_transfer_test_acc))
# Out:
# Accuracy for training and testing of ResNet50 transfer model with Adam optimiser and bottleneck features:
# Train: 0.979, Test: 0.859

# %%
# Fine-tuned ResNet50 transfer model with adam optimiser and augmentation;
# without bottleneck features
#
_, resNet_transfer_train_acc_ft = resNet_ft_model.evaluate(train_tensors, train_targets, verbose=0)  
_, resNet_transfer_test_acc_ft = resNet_ft_model.evaluate(test_tensors, test_targets, verbose=0)   
print("\nAccuracy for training and testing of the fine-tuned ResNet50 transfer model with Adam optimiser and Augmentation:")
print('Train: %.3f, Test: %.3f' % (resNet_transfer_train_acc_ft, resNet_transfer_test_acc_ft))
# Out:
# Accuracy for training and testing of the fine-tuned ResNet50 transfer model with Adam optimiser and Augmentation:
# Train: 0.752, Test: 0.634

# %%
# InceptionV3 model with Adam optimiser and bottleneck features
_, transfer_train_acc = inception_model.evaluate(train_inception, train_targets, verbose=0) 
_, transfer_test_acc = inception_model.evaluate(test_inception, test_targets, verbose=0) 
print("\nAccuracy for training and testing of the InceptionV3 transfer model with Adam optimiser:")
print('Train: %.3f, Test: %.3f' % (transfer_train_acc, transfer_test_acc))
# Out:
# Accuracy for training and testing of the InceptionV3 transfer model with Adam optimiser:
# Train: 0.994, Test: 0.863

# %% [markdown]
# #### Accuracy during Training
#
# Show the history diagram for epochs and associated accuracy results ...

# %%
# model history is the resulting instance of the base model fit() function
# simple base model
print("\nSimple base model with rmsprop optimiser:")
Evaluation_Class.show_history_accuracy(base_model_history)
# Out:
# Simple base model with rmsprop optimiser:

# %% [markdown]
# **Note:**<br>
# Regarding the result of the dataset V2 having a training-validation-testing distribution of 70-10-20:<br>
# The validation curve is much higher compared to the training one, it seems to be a generalisation issue (underfitting) having a biased dataset distribution.<br>
# The final accuracy value is already reached with the first epoch. So, this model architecture doesn't fit to the classification task.
#
# In this project as one consequence, we are using the augmentation concept to get much more training images which fits better to the amount of training parameters of the network, afterwards the Keras Adam optimiser with decay is used without and with augmentation.
#
# But in general, it has been expected to have a better result with this modified dataset V2, which is not the case.

# %%
# augmented base model
print("\nBase model with rmsprop optimiser and augmentation:")
Evaluation_Class.show_history_accuracy(aug_base_model_history)
# Out:
# Base model with rmsprop optimiser and augmentation:

# %% [markdown]
# **Note:**<br>
# By using the augmentation concept there is already a good improvement visible, but it is still a biased dataset distribution. So, this concept is not enough to get rid of the underfitting issue.

# %%
# base model with adam optimiser
print("\nBase model with Adam optimiser:")
Evaluation_Class.show_history_accuracy(adam_base_model_history)
# Out:
# Base model with Adam optimiser:

# %% [markdown]
# **Note:**<br>
# The Adam optimiser showed a big improvement compared to the former optimiser, but there is still some underfitting at the end, starting after epoch 11. Additionally, some overfitting exists between epoch 8 and 11. From epoch 1 up to epoch 8 the accuracy of both is nearly the same.

# %%
# base model with adam optimiser and augmentation
print("\nBasic, augmented model with Adam optimiser:")
Evaluation_Class.show_history_accuracy(adam_aug_base_model_history)
# Out:
# Basic, augmented model with Adam optimiser:

# %% [markdown]
# **Note:**<br>
# Using both concepts - Adam optimiser and augmentation - the situation changes after epoch 3. Then the opposite, means overfitting is available.

# %%
# improved model with adam optimiser
print("\nImproved model with Adam optimiser:")
Evaluation_Class.show_history_accuracy(improved_model_history)
# Out:
# Improved model with Adam optimiser:

# %% [markdown]
# **Note:**<br>
# Again, the diagramm shows an underfitting situation of a biased dataset.

# %%
# improved, augmented model with adam optimiser
print("\nImproved, augmented model with Adam optimiser:")
Evaluation_Class.show_history_accuracy(improved_model_aug_history)
# Out:
# Improved, augmented model with Adam optimiser:

# %% [markdown]
# **Note:**<br>
# The validation started to decrease with epoch 5 and between epochs 10 and 13 it decreases fast again. Starting with epoch 5 there is mainly an overfitting visible.

# %%
# ResNet50 transfer model
print("\nResNet50 transfer model with Adam optimiser and bottleneck features:")
Evaluation_Class.show_history_accuracy(resNet_transfer_model_history)
# Out:
# ResNet50 transfer model with Adam optimiser and bottleneck features:

# %% [markdown]
# **Note:**<br>
# With the RestNet50 transfer model using bottleneck features a fast high training accuracy appeared and the validation accuracy follows in the same way.

# %%
# Fine-tuned, augmented ResNet50 transfer  with adam optimiser
print("\nFine-tuned ResNet50 transfer model with Adam optimiser and augmentation:")
Evaluation_Class.show_history_accuracy(resNet_finetuned_model_aug_history)
# Out:
# Fine-tuned ResNet50 transfer model with Adam optimiser and augmentation:

# %% [markdown]
# **Note:**<br>
# This result showed that there is no general rule always having an accuracy improvement by using a fine-tuned transfer model. A high overfitting exists during all the epochs.

# %%
# InceptionV3 model with Adam optimiser and bottleneck features
print("\nInceptionV3 transfer model with Adam optimiser and bottleneck features:")
Evaluation_Class.show_history_accuracy(inception_transfer_model_history)
# Out:
# InceptionV3 transfer model with Adam optimiser and bottleneck features:

# %% [markdown]
# **Note:**<br>
# A high accuracy appeared already for both datasets, but the validation does not follow in the same way as the training learned. There is some overfitting.

# %% [markdown]
# #### Learning during Training
#
# Show the learning curves of loss function for training and validation.

# %%
print("\nSimple base model with rmsprop optimiser:")
Evaluation_Class.show_history_loss(base_model_history)
# Out:
# Simple base model with rmsprop optimiser:

# %% [markdown]
# **Note:**<br>
# In general, the training loss is the average of the losses over each batch of training data. There are 32 samples in each batch, which are processed independently. The model 'learns' over time, so regarding an epoch, at the beginning the learning loss value from the first batch is higher compared to the loss value of the final batch at the end. During validation, only the loss value of the epochs end is created, means a lower value shall exist.<br>
# For this dataset distribution this is not the case. It is increasing instead of decreasing.

# %%
print("\nBase model with rmsprop optimiser and augmentation:")
Evaluation_Class.show_history_loss(aug_base_model_history)
# Out:
# Base model with rmsprop optimiser and augmentation:

# %%
print("\nBase model with Adam optimiser:")
Evaluation_Class.show_history_loss(adam_base_model_history)
# Out:
# Base model with Adam optimiser:

# %% [markdown]
# **Note:**<br>
# Both curves are decreasing nearly the same way during the epochs sequence, in other words, again the Adam optimiser has a big improvement effect according the models classification task.

# %%
print("\nBasic, augmented model with Adam optimiser:")
Evaluation_Class.show_history_loss(adam_aug_base_model_history)
# Out:
# Basic, augmented model with Adam optimiser:

# %% [markdown]
# **Note:**<br>
# As expected with the given accuracy results, using both concepts - Adam optimiser and augmentation - on the basic model does not have an improvement effect compared by using the Adam optimiser only.

# %%
print("\nImproved model with Adam optimiser:")
Evaluation_Class.show_history_loss(improved_model_history)
# Out:
# Improved model with Adam optimiser:

# %%
print("\nImproved, augmented model with Adam optimiser:")
Evaluation_Class.show_history_loss(improved_model_aug_history)
# Out:
# Improved, augmented model with Adam optimiser:

# %%
print("\nResNet50 transfer model with Adam optimiser and bottleneck features:")
Evaluation_Class.show_history_loss(resNet_transfer_model_history)
# Out:
# ResNet50 transfer model with Adam optimiser and bottleneck features:

# %% [markdown]
# **Note:**<br>
# Both learning curves show a smooth, constant loss value decrease with the biggest effect from the beginning up to epoch 50.

# %%
print("\nFine-tuned ResNet50 transfer model with Adam optimiser and augmentation:")
Evaluation_Class.show_history_loss(resNet_finetuned_model_aug_history)
# Out:
# Fine-tuned ResNet50 transfer model with Adam optimiser and augmentation:

# %% [markdown]
# **Note:**<br>
# The learning curves show no good results during the whole epoch sequence, so, this model and its used parameters don't fit for the given distribution and the models classification task.

# %%
print("\nInceptionV3 transfer model with Adam optimiser and bottleneck features:")
Evaluation_Class.show_history_loss(inception_transfer_model_history)
# Out:
# InceptionV3 transfer model with Adam optimiser and bottleneck features:

# %% [markdown]
# **Note:**<br>
# The learning for both datasets is nearly the same up to epoch 10, afterwards the validation curve is higher up to the epochs end and slowly increasing.

# %% [markdown]
# #### But first, some other metrics needed to compare all model results during the benchmark chapter ...

# %% [markdown]
# We need further metrics describing the performance, because a model may have a very good overall test accuracy, but the model is inadequate for the given classification task, because it is not taking care of the tasks domain properties. We would not realise this by using the overall accuracy value as only, single prediction metric.
#
# **Precision** quantifies the binary precision. It is a ratio of true positives (images classified as pneumonia ones, and which are actually pneumonia) to all positives (all images classified as pneumonia ones, irrespective of whether that was the correct classification), in other words it is theratio of
#
# TruePositives / (TruePositives + FalsePositives)
#
# **Recall (sensitivity)** tells us what proportion of images that actually were pneumonia ones were classified by us as pneumonis ones. It is a ratio of true positives to all the images that were actually pneumonia ones, in other words it is the ratio of
#
# TruePositives / (TruePositives + FalseNegatives)
#
# A model's ability to precisely predict those that have a pneumonia is more important than the model's ability to recall those individuals. We can use **F-beta score** as a metric that considers both precision and recall. According scikit-learn, the F-beta score is the weighted harmonic mean of precision and recall, reaching its optimal value at 1 and its worst value at 0. F – Measure is nothing but the harmonic mean of Precision and Recall.
#
# Fβ=(1 + β2)  (precision⋅recall / ((β2⋅precision) + recall))
#
# In particular, when β=0.5, more emphasis is placed on precision.

# %%
# The scikit-learn metrics API expects a 1D array of actual and predicted values for comparison,
# therefore we must reduce the 2D target arrays to 1D arrays.
# How do the data arrays look like? 
#test_targets[:,1]
#chest_pneumonia_predictions

# %%
print("\nSimple base model with rmsprop optimiser:")
Evaluation_Class.get_other_metrics(test_targets, chest_pneumonia_predictions)
# Out:
# Simple base model with rmsprop optimiser:
# Precision: 0.634
# Recall: 1.000
# F1 score: 0.776
# F-beta score: 0.434  with beta=0.5
#
# Cohens kappa: 0.000
# Confusion matrix of the test data:
# [[  0 423]
#  [  0 734]]
# /usr/local/lib/python3.5/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# **Note:**<br>
# According the sklearn documentation, the resulting values of 0 and the given _UndefinedMetricWarning_ show that there are vector elements of the _test_targets_ parameter which don't appear in the _chest_pneumonia_predictions_ parameter. Why is this here the case, it shouldn't be? But it can be realised, that this always happened, if the model architecture and the associated hyperparameters don't show a proper training and learning (see model accuracy and learning diagrams of the training and validation sets). So, such values are already a hint, that the model architecture with its used configuration doesn't fit for the classification task.

# %% [markdown]
# **Note:**<br>
# Regarding this metrics some more explanations are necessary:
#
# - **Cohen's Kappa**<br>
#   Its value is a statistical measure of the  inter-rater agreement. It can be used to get information about the imbalance of the dataset. Means in general, Cohen's Kappa takes the class distributions of the training data into account.
#
#
# - **Confusion matrix**<br>
#   In general, its architecture looks like
#   ![confusion matrix](./images/ConfusionMatrix_architecture.png)
#
#   It is a common method to get information about the classification performance.
#
#
# - **Type 1 and Type 2 Errors**<br>
#   There are two types of errors that can be identified here:
#
#     Type 1 Error: The model predicted the instance to be a Positive class, but it is incorrect. This is False Positive (FP).<br>
#     Type 2 Error: The model predicted the instance to be the Negative class, but it is incorrect. This is False Negative (FN).
#
#     Having a medical diagnostic prediction task, this type 2 error is most important, because of its severe consequence for the patient, not getting the needed therapy and being unmedicated.
#
#
# - **ROC AUC curves**<br>
#   The ROC – Receiver Operating Characteristic - curve is a curve between true positive rate and false positive rate for various threshold values. So, it is telling us about the 2 types of errors for all thresholds.  The more the area under the curve (AUC), the better is the performance of our model to distinguish the classes. Means, it is a prediction probability curve for the different classes. It informs us how good or bad our overall model performance is, mapping the _conditional_ measures sensitivity and specificity into one value. The ROC AUC diagram is used to compare the different classifier models comparing it with a random option existing by chance and visualised by a diagonal, dotted line.
#
#   A typical ROC curve has False Positive Rate (FPR) on the X-axis and True Positive Rate (TPR) on the Y-axis. And the ideal value for AUC is 1. In general, such best case scenario will not be reached, means we don't have a clear distinction between the two classes NORMAL and PNEUMONIA. In other words, we have some overlapping of the class predictions and that introduces Type 1 and Type 2 errors to the model prediction. As mentioned, the diagonal line visualises the random prediction.

# %%
# ROC AUC
# predict probabilities for the test set
yhat_probs = base_model.predict(test_tensors, verbose=0)  # arrays of chest normal and pneumonia probabilities
#yhat_probs
auc = metrics.roc_auc_score(y_true=test_targets[:,1], y_score=yhat_probs[:,1]) # pneumonia probability values
print('ROC AUC Pneumonia class prediction of basic model with rmsprop optimiser: %.3f' % auc)
# Out:
# ROC AUC Pneumonia class prediction of basic model with rmsprop optimiser: 0.239

# %% [markdown]
# In our case, we are looking to the 'positive' Pneumonia class. So, how does the ROC AUC diagram looks like to the given ROC AUC value above?

# %%
# see:
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html#sklearn.metrics.roc_curve
fpr, tpr, threshold = metrics.roc_curve(y_true=test_targets[:,1], y_score=yhat_probs[:,1])
# plot ROC Curve using the defined function
Evaluation_Class.plot_ROC_AUC(fpr=fpr, tpr=tpr, modelname="Basic CNN Model")
# Out:
# --- associated ROC AUC diagram of model type Basic CNN Model ---

# %% [markdown]
# **Note:**<br>
# The ROC AUC curve is a worse one compared to the random, green dotted line which appeared by chance.

# %%
print("\nBase model with rmsprop optimiser and augmentation:")
Evaluation_Class.get_other_metrics(test_targets, aug_chest_pneumonia_predictions)
# Out:
# Base model with rmsprop optimiser and augmentation:
# Precision: 0.634
# Recall: 1.000
# F1 score: 0.776
# F-beta score: 0.434  with beta=0.5
#
# Cohens kappa: 0.000
# Confusion matrix of the test data:
# [[  0 423]
#  [  0 734]]
# /usr/local/lib/python3.5/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# ROC AUC
# predict probabilities for the test set
yhat_probs = aug_base_model.predict(test_tensors, verbose=0)  
auc = metrics.roc_auc_score(y_true=test_targets[:,1], y_score=yhat_probs[:,1]) 
print('ROC AUC Pneumonia class prediction of basic model with rmsprop optimiser and augmentation: %.3f' % auc)
# Out:
# ROC AUC Pneumonia class prediction of basic model with rmsprop optimiser and augmentation: 0.232

# %%
fpr, tpr, threshold = metrics.roc_curve(y_true=test_targets[:,1], y_score=yhat_probs[:,1])
Evaluation_Class.plot_ROC_AUC(fpr=fpr, tpr=tpr, modelname="Basic CNN Model with Augmentation")
# Out:
# --- associated ROC AUC diagram of model type Basic CNN Model with Augmentation ---

# %%
print("\nBase model with Adam as optimiser:")
Evaluation_Class.get_other_metrics(test_targets, adam_chest_pneumonia_predictions)
# Out:
# Base model with Adam as optimiser:
# Precision: 0.814
# Recall: 0.982
# F1 score: 0.890
# F-beta score: 0.848  with beta=0.5
#
# Cohens kappa: 0.641
# Confusion matrix of the test data:
# [[258 165]
#  [ 13 721]]

# %%
# ROC AUC
# predict probabilities for the test set
yhat_probs = adam_base_model.predict(test_tensors, verbose=0)  
auc = metrics.roc_auc_score(y_true=test_targets[:,1], y_score=yhat_probs[:,1]) 
print('ROC AUC Pneumonia class prediction of basic model with Adam optimiser: %.3f' % auc)
# Out:
# ROC AUC Pneumonia class prediction of basic model with Adam optimiser: 0.951

# %%
fpr, tpr, threshold = metrics.roc_curve(y_true=test_targets[:,1], y_score=yhat_probs[:,1])
Evaluation_Class.plot_ROC_AUC(fpr=fpr, tpr=tpr, modelname="Basic CNN Model with Adam optimiser")
# Out:
# --- associated ROC AUC diagram of model type Basic CNN Model with Adam optimiser ---

# %%
print("\nBasic, augmented model with Adam optimiser:")
Evaluation_Class.get_other_metrics(test_targets, adam_aug_chest_pneumonia_predict)
# Out:
# Basic, augmented model with Adam optimiser:
# Precision: 0.826
# Recall: 0.943
# F1 score: 0.880
# F-beta score: 0.835  with beta=0.5
#
# Cohens kappa: 0.630
# Confusion matrix of the test data:
# [[277 146]
#  [ 42 692]]

# %%
# ROC AUC
# predict probabilities for test set
yhat_probs = adam_aug_base_model.predict(test_tensors, verbose=0)  
auc = metrics.roc_auc_score(test_targets[:,1], yhat_probs[:,1]) 
print('ROC AUC Pneumonia class prediction of basic, augmented model with Adam optimiser: %.3f' % auc)
# Out:
# ROC AUC Pneumonia class prediction of basic, augmented model with Adam optimiser: 0.941

# %%
fpr, tpr, threshold = metrics.roc_curve(y_true=test_targets[:,1], y_score=yhat_probs[:,1])
Evaluation_Class.plot_ROC_AUC(fpr=fpr, tpr=tpr,
                              modelname="Basic CNN Model with Adam optimiser and Augmentation")
# Out:
# --- associated ROC AUC diagram of model type Basic CNN Model with Adam optimiser and Augmentation ---

# %%
print("\nImproved model with Adam as optimiser:")
Evaluation_Class.get_other_metrics(test_targets, improved_chest_pneumonia_predict_adam)
# Out:
# Improved model with Adam as optimiser:
# Precision: 0.634
# Recall: 1.000
# F1 score: 0.776
# F-beta score: 0.434  with beta=0.5
#
# Cohens kappa: 0.000
# Confusion matrix of the test data:
# [[  0 423]
#  [  0 734]]
# /usr/local/lib/python3.5/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# ROC AUC
# predict probabilities for test set
yhat_probs = improved_model_adam.predict(test_tensors, verbose=0)  
auc = metrics.roc_auc_score(test_targets[:,1], yhat_probs[:,1])
print('ROC AUC Pneumonia class prediction of improved model with Adam optimiser: %.3f' % auc)
# Out:
# ROC AUC Pneumonia class prediction of improved model with Adam optimiser: 0.500

# %%
fpr, tpr, threshold = metrics.roc_curve(y_true=test_targets[:,1], y_score=yhat_probs[:,1])
Evaluation_Class.plot_ROC_AUC(fpr=fpr, tpr=tpr, modelname="Improved CNN Model with Adam optimiser")
# Out:
# --- associated ROC AUC diagram of model type Improved CNN Model with Adam optimiser ---

# %% [markdown]
# **Note:**<br>
# The own created 'improved' labelled model architecture using convolutional layers with the used hyperparameters has the same prediction as it exits by chance.

# %%
print("\nImproved, augmented model with Adam as optimiser:")
Evaluation_Class.get_other_metrics(test_targets, improved_chest_pneumonia_predict_aug)
# Out:
# Improved, augmented model with Adam as optimiser:
# Precision: 0.843
# Recall: 0.895
# F1 score: 0.868
# F-beta score: 0.826  with beta=0.5
#
# Cohens kappa: 0.621
# Confusion matrix of the test data:
# [[301 122]
#  [ 77 657]]

# %% [markdown]
# **Note:**<br>
# The confusion matrix shows an unacceptable high value of false negatives: 60.

# %%
# ROC AUC
# predict probabilities for test set
yhat_probs = improved_model_aug.predict(test_tensors, verbose=0)  
auc = metrics.roc_auc_score(test_targets[:,1], yhat_probs[:,1]) 
print('ROC AUC Pneumonia class prediction of improved, augmented model with Adam optimiser: %.3f' % auc)
# Out:
# ROC AUC Pneumonia class prediction of improved, augmented model with Adam optimiser: 0.911

# %%
fpr, tpr, threshold = metrics.roc_curve(y_true=test_targets[:,1], y_score=yhat_probs[:,1])
Evaluation_Class.plot_ROC_AUC(fpr=fpr, tpr=tpr,
                              modelname="Improved CNN Model with Adam optimiser and Augmentation")
# Out:
# --- associated ROC AUC diagram of model type Improved CNN Model with Adam optimiser and Augmentation ---

# %%
print("\nResNet50 transfer model with Adam optimiser and bottleneck features:")
Evaluation_Class.get_other_metrics(test_targets, resNet_chest_pneumonia_predict)
# Out:
# ResNet50 transfer model with Adam optimiser and bottleneck features:
# Precision: 0.822
# Recall: 0.993
# F1 score: 0.899
# F-beta score: 0.862  with beta=0.5
#
# Cohens kappa: 0.671
# Confusion matrix of the test data:
# [[265 158]
#  [  5 729]]

# %%
# ROC AUC
# predict probabilities for test set
yhat_probs = basic_resNet_model.predict(test_resNet, verbose=0)  
auc = metrics.roc_auc_score(test_targets[:,1], yhat_probs[:,1]) 
print('ROC AUC Pneumonia class prediction of ResNet50 transfer model with Adam optimiser and bottleneck features: %.3f' % auc)
# Out:
# ROC AUC Pneumonia class prediction of ResNet50 transfer model with Adam optimiser and bottleneck features: 0.956

# %%
fpr, tpr, threshold = metrics.roc_curve(y_true=test_targets[:,1], y_score=yhat_probs[:,1])
Evaluation_Class.plot_ROC_AUC(fpr=fpr, tpr=tpr,
                           modelname="CNN Model with ResNet50 transfer learning, Adam optimiser and bottleneck features")
# Out:
# --- associated ROC AUC diagram of model type CNN Model with ResNet50 transfer learning, Adam optimiser and bottleneck features ---

# %%
print("\nFine-tuned ResNet50 transfer model with Adam optimiser and Augmentation:")
Evaluation_Class.get_other_metrics(test_targets, resNet_ft_transfer_chest_pneumonia_predict)
# Out:
# Fine-tuned ResNet50 transfer model with Adam optimiser and Augmentation:
# Precision: 0.634
# Recall: 1.000
# F1 score: 0.776
# F-beta score: 0.434  with beta=0.5
#
# Cohens kappa: 0.000
# Confusion matrix of the test data:
# [[  0 423]
#  [  0 734]]
# /usr/local/lib/python3.5/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# ROC AUC
# predict probabilities for test set
yhat_probs = resNet_ft_model.predict(test_tensors, verbose=0) 
auc = metrics.roc_auc_score(test_targets[:,1], yhat_probs[:,1]) 
print('ROC AUC Pneumonia class prediction of fine-tuned ResNet50 transfer model with Adam optimiser and Augmentation: %.3f' % auc)
# Out:
# ROC AUC Pneumonia class prediction of fine-tuned ResNet50 transfer model with Adam optimiser and Augmentation: 0.469

# %%
fpr, tpr, threshold = metrics.roc_curve(y_true=test_targets[:,1], y_score=yhat_probs[:,1])
Evaluation_Class.plot_ROC_AUC(fpr=fpr, tpr=tpr,
             modelname="CNN Model with fine-tuned ResNet50 transfer learning, Adam optimiser and Augmentation")
# Out:
# --- associated ROC AUC diagram of model type CNN Model with fine-tuned ResNet50 transfer learning, Adam optimiser and Augmentation ---

# %% [markdown]
# **Note:**<br>
# It seemed as if a general conclusion that fine-tuned transfer learning models specific for image classification, like the ResNet50 architecture, used with augmentation are always a very good solution for the given image classification task is wrong. By now, it is unclear if the training get stucked in a local minimum or if the chosen model and the selected parameters are simply not optimal and don't fit.
# As a future open topic, this could be evaluated more precisly by changing the parameters, always having in mind that the sample distribution has a big effect on the training result of the models (see future to do comment of the last project chapter).
#
# Compared to the ResNet transfer model used with bottleneck features this fine-tuned one with augmentation is nearly the same as the random case (green dotted line).
#
# By now, we will have a look if there is at least one possible pre-trained transfer learning model that leads to better training results - the Inception3 model. We use it with bottleneck features.

# %%
print("\nInceptionV3 transfer model with Adam optimiser and bottleneck features:")
Evaluation_Class.get_other_metrics(test_targets, inception_chest_pneumonia_predict)
# Out:
# InceptionV3 transfer model with Adam optimiser and bottleneck features:
# Precision: 0.834
# Recall: 0.980
# F1 score: 0.901
# F-beta score: 0.865  with beta=0.5
#
# Cohens kappa: 0.685
# Confusion matrix of the test data:
# [[280 143]
#  [ 15 719]]

# %%
# ROC AUC
# predict probabilities for test set
yhat_probs = inception_model.predict(test_inception, verbose=0)  
auc = metrics.roc_auc_score(test_targets[:,1], yhat_probs[:,1]) 
print('ROC AUC Pneumonia class prediction of InceptionV3 transfer model with Adam optimiser: %.3f' % auc)
# Out:
# ROC AUC Pneumonia class prediction of InceptionV3 transfer model with Adam optimiser: 0.955

# %%
fpr, tpr, threshold = metrics.roc_curve(y_true=test_targets[:,1], y_score=yhat_probs[:,1])
Evaluation_Class.plot_ROC_AUC(fpr=fpr, tpr=tpr,
             modelname="CNN Model with InceptionV3 transfer learning with Adam optimiser and Augmentation")
# Out:
# --- associated ROC AUC diagram of model type CNN Model with InceptionV3 transfer learning with Adam optimiser and Augmentation ---

# %% [markdown]
# <a id='step14'></a>
# ## Step 14: Benchmark and Conclusion
#
# Regarding the different evaluation results according test accuracy and because having a medical diagnosis prediction task the number of false negatives, it can be realised that 2 different models can be chosen for the classification issue of this given original data distribution.
#
# If it is decided to have a higher prio on the lowest number of false negatives (type 2 error), the ResNet50 transfer model with Adam optimiser and bottleneck features - having only 5 false negatives and a test accuracy of 85.91%.
#
# If the decision is taken to have the model with the highest test accuracy, then the InceptionV3 transfer model with Adam optimiser and bottleneck features should be chosen: Its value is 86.34%. But is has detected 15 false negatives.
#
# Another insight of this evaluation is, that using a fine-tuned transfer learning model architecture with augmentation is no general, overall guarantee of having a better performance.
#
# An overall description of the benchmark and conclusion, e.g. reagarding the insights by comparing all the models with the different distributions, is given in the final project document.
#
# As a **future to do:** Better hyperparameter values must be found by having a better environment for machine learning algorithms (batch and epoch sizes together with the initialisation, changing learning rate and early stopping). My own hardware (not made for machine learning tasks) needed a whole week to do the calculations of this file and the local internet environment of the provider is an old standard compared to the one of the Silicon Valley and it is unstable. Means the AWS EC2 service has been disconnected few times a week and a lot of restarts were necessary. If the AWS service connection worked fine, the caculations of this file with random started hyperparameters needed approximately 2 days to be finished. So, hyperparameter tuning from Scikit-Learn with GridSearchCV or RandomizedCV as an alternative has not been done, because it is computational expensive having such a lot of parameters for the neural networks. With neural network optimisation, it is expected to get better prediction results.
#
# As already mentioned, having more pneumonia chest images with further root causes (not only virus and bacteria root causes exist), the algorithm can be improved doing a multi-class classification between normal and pneumonia ones, where the pneumonia ones are differentiated by their root cause from the scratch.<br>
# The same is valid by including the whole variety of ages, because this dataset is focussed on children images.
#
# Furthermore, because of project deadline, the applicational algorithm accepting a file path to an unknown, future X-ray .jpg image and determine if it is a pneumonia image or not together with its testing code, has not been implemented yet. This would be possible, e.g. by usage of the [skimage](https://scikit-image.org/docs/dev/api/api.html) package or the [OpenCV cv2](https://docs.opencv.org/trunk/index.html) implementation.
